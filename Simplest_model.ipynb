# %% [markdown]
# <a href="https://colab.research.google.com/github/gpetrini/Dissertacao/blob/master/Simplest_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# Jupyter notebook for the simplest model scratch. By convention, all exogenous variables are presented with a overline line (*e.g.* $\overline a$) and the parameters are represented by greek letters (*e.g.* $\alpha$). The code in this document is executable and is strongly recommend to do the follow to ensure that the output is corrected and updated:
#
# Run time > Restart and run all...

# %% [markdown]
# ## Variables list
#
# - $C$ Consumption
# - $CG$: Capital gains
# - $FT$: Total profits
# - $FD$: Distributed profits
# - $FU$: Retained profits
# - $g_i$: Growth rate of variable $i$
# - $g^e_i$: Expected growth rate of variable $i$
# - $h$: Marginal propensity to invest
# - $I$: Total investment
# - $I_f$: Non-residential investment
# - $I_h$: Residential investment
# - $K_f$: Non-residential fixed capital
# - $K_h$: Residential capital
# - $K_{HD}$: Demand for houses
# - $K_{HU}$: Unsold houses
# - $K_H$: Houses supply
# - $L$: Loans
# - $morp$: Mortgages repayments
# - $M$: Money deposits
# - $MO$: Mortgages
# - $p_h$ Housing prices
# - $r_l$: Interest rates on Loans
# - $r_m$: Interest rates on money deposits
# - $r_H$: Housing own interest rates
# - $S_i$: Sector $i$ savings
# - $u$: Capacity utilization ratio
# - $v$: Capacity-Output ratio
# - $V_i$: Net financial Wealth of sector $i$
# - $W$ Total Wage bill
# - $Y$: GDP
# - $Y_K$: Capacity
# - $YD$: Household disposable income
# - $Z$: Autonomous expenditures

# %% [markdown]
# ## Parameters list
#
# - $\alpha$: Propensity to consume out of wages
# - $\beta$: Expectation adjustment parameter
# - $\gamma_F$: % of distributed profits
# - $\gamma_u$: Adjustment parameter for the marginal propensity to invest

# %% [markdown]
# ## Exogenous variables
#
# - $gz$: Autonomous grouth rate
# - $\omega$: Wage share
# - $rm$: Interest rates on money deposits
# - $spread_l$: Spread for loans
# - $spread_{mo}$: Spread for mortgages
# - $un$: Normal capacity utilization ratio
# - $v$: Capitl-Output ratio

# %% [markdown]
# # Assumptions

# %% [markdown]
# ## General
#
# - No inflation
# - Two kinds of capital: Residential and non-Residential
# - No depeciation
# - Non-residential investment is induced

# %% [markdown]
# ## Households
#
# - All savings are accumulated in bank deposits
# - Households do not have access to Loans
# - Residential investment is financed by mortgages

# %% [markdown]
# ## Firms

# %% [markdown]
# ## Banks
#
# - Have any net worth

# %% [markdown]
# # Matrix

# %% [markdown]
# ## Balance sheet
#
# |                	| Households 	|  Firms 	| Banks 	| $\sum$ 	|
# |----------------	|:----------:	|:------:	|:-----:	|:------:	|
# | Money Deposits 	|    $+M$    	|        	|  $-M$ 	|   $0$  	|
# | Loans          	|            	|  $-L$  	|  $+L$ 	|   $0$  	|
# | Mortgages          	| $-MO$           	|   	|  $+MO$ 	|   $0$  	|
# | Capital        	|    |  $K_f$ 	|       	|   $K_f$  	|
# | Houses 	|    $K_{HD}$    	| |  	|   $K_H$  	|
# | Net Worth      	|   $V_h$   	| $V_f$ 	| $V_b$      	|  $K$  	|

# %% [markdown]
# ## Transactions and flow  of funds matrix
#
# |                            	| Households             	| Households  	| Firms                  	| Firms       	| Banks                  	| Banks       	| Sum    	|
# |----------------------------	|------------------------	|-------------	|------------------------	|-------------	|------------------------	|-------------	|--------	|
# |                            	| Current                	| Capital     	| Current                	| Capital     	| Current                	| Capital     	| $\sum$ 	|
# | Consumption                	| $-C$                   	|             	| $+C$                   	|             	|                        	|             	| $0$    	|
# | Investment                 	|                  	|             	| $+I_f$                    	| $-I_f$      	|                        	|             	| $0$    	|
# | Residential Investment                 	|                  	| $-I_h$            	| $+I_h$                    	|       	|                        	|             	| $0$    	|
# | **[Production]**               	|                        	|             	| **[$Y$]**                  	|             	|                        	|             	| $Y$    	|
# | Wages                      	| $+W$                    	|             	| $-W$                   	|             	|                        	|             	| $0$    	|
# | Profits                      	| $+FD$                    	|             	| $-FD$                   	|            	|                        	|             	| $0$    	|
# | Interests on loans         	|                        	|             	| $-r_{l-1}\cdot L_{-1}$ 	|             	| $+r_{l-1}\cdot L_{-1}$ 	|             	| $0$    	|
# | Interests on Bank deposits 	| $+r_{m-1}\cdot M_{-1}$ 	|             	|                        	|             	| $-r_{m-1}\cdot M_{-1}$ 	|             	| $0$    	|
# | Interests on Mortgage 	| $-r_{mo-1}\cdot MO_{-1}$ 	|             	|                        	|             	| $+r_{mo-1}\cdot MO_{-1}$  	|             	| $0$    	|
# | **Subtotal** 	| $S_h$ 	|             	|                        $S_f$	|  $-I_f$           	|  $S_b$	|             	| $0$    	|
# | Change in Loans            	|                        	|             	|                        	| $+\Delta L$ 	|                        	| $-\Delta L$ 	| $0$    	|
# | Change in Bank deposits    	| $-\Delta M$                       	|  	|                        	|             	|                        	| $+\Delta M$ 	| $0$    	|
# | Change in Mortgages    	|                        	| $+\Delta MO$ 	|                        	|             	|                        	| $-\Delta MO$ 	| $0$    	|
# | Sum    	| $0$                        	| $0$ 	| $0$| $0$| $0$| $0$| $0$    	|

# %% [markdown]
# # Equations

# %% [markdown]
# ## General Equations
#
# $$
# Y = C + I
# \tag{1}
# $$
#
# $$
# I = I_f + I_h
# \tag{2}
# $$
#
# $$
# \omega = \overline \omega
# \tag{3}
# $$
#
# $$
# W = \omega \cdot  Y
# \tag{4}
# $$
#
# $$
# Y_K = \frac{K_f}{\overline v}
# \tag{5}
# $$
#
# $$
# u = \frac{Y}{Y_K}
# \tag{6}
# $$
#
# $$
# g_k = \frac{h\cdot u}{v}
# \tag{7}
# $$
#
# $$
# Z = I_h
# \tag{8}
# $$
#
# $$
# K = K_f + K_{HD}
# \tag{9}
# $$

# %% [markdown]
# ## Households
#
# $$
# YD = W + FD + \overline r_{m-1}\cdot M_{-1} - \overline r_{mo-1}\cdot MO
# \tag{10}
# $$
#
# $$
# S_h = YD - C = \Delta M
# \tag{11}
# $$
#
# $$
# \Delta MO = I_h
# \tag{12}
# $$
#
# $$
# C = \alpha\cdot W
# \tag{13}
# $$
#
# $$
# V_h = M + K_H - MO
# \tag{14}
# $$

# %% [markdown]
# ## Firms
#
# $$
# \Delta L = I_f - FU
# \tag{15}
# $$
#
# $$
# FT = Y - W = FU+ FD
# \tag{16}
# $$
#
# $$
# FU = \gamma_F\cdot (FT - r_{L_{-1}}\cdot L_{-1})
# \tag{17}
# $$
#
#
# $$
# FD = (1 - \gamma_F)\cdot (FT - r_{L_{-1}}\cdot L_{-1})
# \tag{18}
# $$
#
# $$
# I_f = h\cdot Y
# \tag{19}
# $$
#
# $$
# \Delta K_f = I_f
# \tag{20}
# $$
#
# $$
# \Delta h =
# h_{-1}\cdot \gamma_u\cdot (u - \overline u_n)
# \tag{21}
# $$
#
# $$
# V_f = K_f  - L
# \tag{22}
# $$
#
# $$
# S_f = FU
# \tag{23}
# $$

# %% [markdown]
# ## Banks
#
# $$
# \Delta M = \Delta L + \Delta MO
# \tag{24}
# $$
#
# $$
# S_b = rl_{-1}\cdot L_{-1} + rmo_{-1}\cdot MO_{-1} - rm_{-1}\cdot M_{-1}
# \tag{25}
# $$
#
# $$
# r_l = r_m + spread_l (=0)
# \tag{26}
# $$
#
# $$
# r_{mo} = r_m + spread_{mo} (=0)
# \tag{27}
# $$
#
# $$
# V_b = L + MO - M
# \tag{28}
# $$

# %% [markdown]
# ## Residential Investment
#
#
# $$
# K_{HS} = K_{HD}
# \tag{29}
# $$
#
# $$
# \Delta K_{HD} = I_h
# \tag{30}
# $$
#
# $$
# I_h = (1+g_{Ih_{t-1}})\cdot I_{h_{t-1}}
# \tag{31}
# $$
#
# $$
# g_{I_h} = \overline g_{I_h}
# \tag{32}
# $$

# %% [markdown]
# # Simulation setup

# %% [markdown]
# ## Installing required packages

# %%
# !pip install pysolve3
# Out:
# Requirement already satisfied: pysolve3 in /usr/local/lib/python3.6/dist-packages (0.1.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pysolve3) (1.14.6)
# Requirement already satisfied: sympy==1.1 in /usr/local/lib/python3.6/dist-packages (from pysolve3) (1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pysolve3) (0.22.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy==1.1->pysolve3) (1.1.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->pysolve3) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->pysolve3) (2.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas->pysolve3) (1.11.0)

# %% [markdown]
# ## Loading libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
from pysolve3.utils import ShockModel, SFCTable, SolveSFC
from pysolve3.model import Model
import sympy as sp
#from sympy import init_printing
#init_printing(use_latex="mathjax")
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Creating model function

# %%
def model():
  model = Model()
  model.set_var_default(0)
  
  model.var('C', desc='Consumption')
  model.var('FD', desc='Distributed profits')
  model.var('Fn', desc='Net profits')
  model.var('FT', desc='Total Profits')
  model.var('FU', desc='Retained profits')
  model.var('gk', desc='Capital growth rate', default=0.01)
  model.var('g_Ih', desc='Residential investment growth rate (Demand)', default = 0.05)
  model.var('h', desc='Marginal propensity to invest (non-residential)', default=0.30)
  model.var('I_t', desc='Investment', default = 100) # 200
  model.var('I_f', desc='Non-residential investment') # 100
  model.var('I_h', desc='Residential investment', default = 100) # 100
  model.var('K_HS', desc='Houses supply', default=500) # 500
  model.var('K_HD', desc='Houses demand', default=500) # 500
  model.var('K_f', desc='Non-residential capital', default = 1000) # 10000
  model.var('K', desc='Capital', default=1500)
  model.var('L', desc='Loans') # 100
  model.var('M', desc='Money deposits', default = 305) # 300
  model.var('MO', desc='Mortgages', default = 305) # 200
  model.var('omega', desc='Wage-share', default = 0.5)
  model.var('rl', desc='Interests rates on loans')
  model.var('rmo', desc='Interests rates on mortgages')
  model.var('S_h', desc='Households savings', default = 100)
  model.var('S_f', desc='Firms savings')
  model.var('S_b', desc='Banks savings')
  model.var('u', desc='Capacity utilization ratio', default=0.7)
  model.var('V_h', desc='Household net financial wealth', default = 500)
  model.var('V_f', desc='Firms net financial wealth', default = 1000)
  model.var('V_b', desc='Banks net financial wealth')
  model.var('W', desc='Wages')
  model.var('Y', desc='GDP')
  model.var('Yk', desc='Capacity')
  model.var('YD', desc='Household disposable income')
  model.var('Z', desc='Autonomous expenditures')
  
  model.param('alpha', desc='Propensity to consume out of wages', default=1) # 0.7
  model.param('beta', desc='Expectation adjustment parameter', default=0.2) # 0.2
  model.param('gamma_F', desc='% of undistributed profits', default=0.46354) # 0.4
  model.param('gamma_u', desc='Adjustment parameter for the marginal propensity to invest', default=0.01) # 0.01
  model.param('gz', desc='Autonomous grouth rate', default=0.05) # 0.02
  model.param('omegapar', desc='Wage-share', default=0.5) # 0.5
  model.param('rm', desc='Interest rates on money deposits', default=0.02) # 0.02
  model.param('spread_l', desc='Spread for loans', default=0) # 0.01
  model.param('spread_mo', desc='Spread for mortgages', default=0) # 0.005
  model.param('un', desc='Normal capacity utilization ratio', default=0.8) # 0.8
  model.param('v', desc='Capitl-Output ratio', default=2.5) # 2.5
  
  
  # General equations
  model.add('Y = C + I_t') # Eq1
  model.add('I_t = I_f + I_h') # Eq2
  model.add('omega = omegapar') # Eq 3
  model.add('Yk = K_f(-1)/v') # Eq 4
  model.add('u = Y/Yk') # Eq 5
  model.add('W = omega*Y') # Eq 6
  model.add('gk = h*u/v') # Eq 7
  model.add('K = K_HD + K_f') # Eq 8
  model.add('Z = I_h') # Eq 9
  
  # Household equations
  model.add('YD = W + FD + rm*M(-1) - rmo*MO(-1)') # Eq 10
  model.add('S_h = YD - C') # Eq 11
  model.add('d(MO) = I_h') # Eq 12
  model.add('C = alpha*W') # Eq 13
  model.add('V_h = M + K_HD - MO') # Eq 14
  
  # Firms
  model.add('L = I_f - FU + L(-1)') # Eq 15
  model.add('FT = (1-omega)*Y') # Eq 16
  model.add('Fn = FT -rl*L(-1)')
  model.add('FU = gamma_F*(Fn)') # Eq 17
  model.add('FD = (1 - gamma_F)*(Fn)') # Eq 18
  model.add('I_f = h*Y') # Eq 19
  model.add('d(K_f) = I_f') # 20
  model.add('h = h(-1)*gamma_u*(u-un) + h(-1)') # Eq 21 # Version without corridor
  model.add('V_f = K_f - L') # Eq 22
  #model.add('S_f = FU - I_f') # Eq 23
  model.add('S_f = FU') # Eq 23
  #model.add('S_f = FU - I_f - rl*L(-1)') # Eq 23
  
  # Banks
  model.add('d(M) = d(L) + d(MO)') # Eq 24
  model.add('rmo = rm + spread_mo') # Eq 25
  model.add('rl = rm + spread_l') # Eq 26
  model.add('V_b = L + MO - M') # Eq 27
  model.add('S_b = rl*L(-1) + rmo*MO(-1) - rm*M(-1)') # Eq 28
  
  # Residential investment
  model.add('K_HS = K_HD') # Eq 29
  model.add('d(K_HD) = I_h') # Eq 30
  model.add('I_h = (1+g_Ih(-1))*I_h(-1)') # Eq 31
  model.add('g_Ih = gz') # Eq 32
  return model

# %% [markdown]
# # Evaluating consistenty

# %%
test = model()
SolveSFC(test, time=70, table = False)
evaldf = pd.DataFrame({
    'Households' : test.evaluate('M - MO + K_HD - V_h'),
    'Firms' : test.evaluate('K_f - L - V_f'),
    'Banks' : test.evaluate('L + MO - M - V_b'),
    'Mortgages' : test.evaluate('MO(-1) - MO(-2) - I_h(-1)'),
    'Financial assets' : test.evaluate('d(MO) + d(L) - d(M)'),
    '[Total Financial Wealth - K]' : test.evaluate('V_f + V_h + V_b - K'),
    "Firm's Funds" : test.evaluate('d(L) - I_f + FU'),
    "Housing" : test.evaluate('K_HD - K_HS'),
    "[Saving - Investment]" : test.evaluate('S_f + S_b + S_h - I_h - I_f'),
    "Investment" : test.evaluate('I_t - I_h - I_f'),
    "Profits" : test.evaluate('FT(-1) - rl*L(-2) - FU(-1) - FD(-1)'),
    "Wages" : test.evaluate('W - omega*Y')
}, index = ['Sum'])
evaldf = evaldf.transpose()
evaldf.round(5)
# Out:
#                                     Sum
# Banks                           0.00000
# Financial assets                0.00000
# Firm's Funds                 -368.50153
# Firms                           0.00000
# Households                      0.00264
# Housing                         0.00000
# Investment                     -0.02496
# Mortgages                       0.00000
# Profits                         0.00000
# Wages                           0.00000
# [Saving - Investment]          -0.08210
# [Total Financial Wealth - K]    0.02232

# %% [markdown]
# # Solving

# %%
base = model()
df = SolveSFC(base, time=500)
df.transpose()
# Out:
#                   0             1            2             3             4    \
# C             0.00000  2.645599e+02   279.510632  2.948878e+02  3.107399e+02
# FD            0.00000  1.419258e+02   149.550030  1.573696e+02  1.654106e+02
# FT            0.00000  2.645599e+02   279.510632  2.948878e+02  3.107399e+02
# FU            0.00000  1.226341e+02   129.221976  1.359787e+02  1.429267e+02
# Fn            0.00000  2.645599e+02   278.772006  2.933483e+02  3.083373e+02
# I_f           0.00000  1.595658e+02   169.266294  1.791313e+02  1.891954e+02
# I_h         100.00000  1.050000e+02   110.250000  1.157625e+02  1.215506e+02
# I_t         100.00000  2.645643e+02   279.514802  2.948922e+02  3.107444e+02
# K          1500.00000  1.764564e+03  2044.080611  2.338974e+03  2.649720e+03
# K_HD        500.00000  6.050000e+02   715.250000  8.310125e+02  9.525631e+02
# K_HS        500.00000  6.050000e+02   715.250000  8.310125e+02  9.525631e+02
# K_f        1000.00000  1.159566e+03  1328.832103  1.507963e+03  1.697159e+03
# L             0.00000  3.693132e+01    76.975275  1.201275e+02  1.663958e+02
# M           305.00000  4.469313e+02   597.225275  7.561400e+02  9.239590e+02
# MO          305.00000  4.100000e+02   520.250000  6.360125e+02  7.575631e+02
# S_b           0.00000  0.000000e+00     0.000000  0.000000e+00 -1.776357e-15
# S_f           0.00000  1.226341e+02   129.221976  1.359787e+02  1.429267e+02
# S_h         100.00000  1.419270e+02   150.289783  1.589103e+02  1.678144e+02
# V_b           0.00000  5.684342e-14     0.000000 -1.136868e-13 -1.136868e-13
# V_f        1000.00000  1.122634e+03  1251.856828  1.387836e+03  1.530763e+03
# V_h         500.00000  6.419309e+02   792.224849  9.511395e+02  1.118958e+03
# W             0.00000  2.645599e+02   279.510632  2.948878e+02  3.107399e+02
# Y             0.00000  5.291199e+02   559.021265  5.897756e+02  6.214797e+02
# YD            0.00000  4.064844e+02   429.797986  4.537956e+02  4.785516e+02
# Yk            0.00000  4.000000e+02   463.826324  5.315328e+02  6.031853e+02
# Z             0.00000  1.050000e+02   110.250000  1.157625e+02  1.215506e+02
# _I_h__1     100.00000  1.000000e+02   105.000000  1.102500e+02  1.157625e+02
# _K_HD__1    500.00000  5.000000e+02   605.000000  7.152500e+02  8.310125e+02
# _K_f__1    1000.00000  1.000000e+03  1159.565809  1.328832e+03  1.507963e+03
# _L__1         0.00000  0.000000e+00    36.931323  7.697528e+01  1.201275e+02
# _MO__1      305.00000  3.050000e+02   410.000000  5.202500e+02  6.360125e+02
# _M__1       305.00000  3.050000e+02   446.931323  5.972253e+02  7.561400e+02
# _g_Ih__1      0.05000  5.000000e-02     0.050000  5.000000e-02  5.000000e-02
# _h__1         0.30000  3.000000e-01     0.301568  3.027905e-01  3.037278e-01
# alpha         1.00000  1.000000e+00     1.000000  1.000000e+00  1.000000e+00
# beta          0.20000  2.000000e-01     0.200000  2.000000e-01  2.000000e-01
# g_Ih          0.05000  5.000000e-02     0.050000  5.000000e-02  5.000000e-02
# gamma_F       0.46354  4.635400e-01     0.463540  4.635400e-01  4.635400e-01
# gamma_u       0.01000  1.000000e-02     0.010000  1.000000e-02  1.000000e-02
# gk            0.01000  1.595658e-01     0.145974  1.348035e-01  1.254642e-01
# gz            0.05000  5.000000e-02     0.050000  5.000000e-02  5.000000e-02
# h             0.30000  3.015684e-01     0.302790  3.037278e-01  3.044274e-01
# omega         0.50000  5.000000e-01     0.500000  5.000000e-01  5.000000e-01
# omegapar      0.50000  5.000000e-01     0.500000  5.000000e-01  5.000000e-01
# rl            0.00000  2.000000e-02     0.020000  2.000000e-02  2.000000e-02
# rm            0.02000  2.000000e-02     0.020000  2.000000e-02  2.000000e-02
# rmo           0.00000  2.000000e-02     0.020000  2.000000e-02  2.000000e-02
# spread_l      0.00000  0.000000e+00     0.000000  0.000000e+00  0.000000e+00
# spread_mo     0.00000  0.000000e+00     0.000000  0.000000e+00  0.000000e+00
# u             0.70000  1.322800e+00     1.205238  1.109575e+00  1.030330e+00
# un            0.80000  8.000000e-01     0.800000  8.000000e-01  8.000000e-01
# v             2.50000  2.500000e+00     2.500000  2.500000e+00  2.500000e+00
#
#                     5             6             7             8    \
# C          3.271105e+02  3.440416e+02  3.615706e+02  3.797434e+02
# FD         1.736964e+02  1.822492e+02  1.910889e+02  2.002397e+02
# FT         3.271105e+02  3.440416e+02  3.615706e+02  3.797434e+02
# FU         1.500862e+02  1.574764e+02  1.651145e+02  1.730215e+02
# Fn         3.237826e+02  3.397256e+02  3.562034e+02  3.732611e+02
# I_f        1.994888e+02  2.100387e+02  2.208686e+02  2.320062e+02
# I_h        1.276282e+02  1.340096e+02  1.407100e+02  1.477455e+02
# I_t        3.271153e+02  3.440465e+02  3.615765e+02  3.797495e+02
# K          2.976837e+03  3.320885e+03  3.682464e+03  4.062215e+03
# K_HD       1.080191e+03  1.214201e+03  1.354911e+03  1.502656e+03
# K_HS       1.080191e+03  1.214201e+03  1.354911e+03  1.502656e+03
# K_f        1.896648e+03  2.106686e+03  2.327555e+03  2.559561e+03
# L          2.157981e+02  2.683599e+02  3.241135e+02  3.830976e+02
# M          1.100989e+03  1.287561e+03  1.484024e+03  1.690754e+03
# MO         8.851913e+02  1.019201e+03  1.159911e+03  1.307656e+03
# S_b        0.000000e+00  7.105427e-15  7.105427e-15  0.000000e+00
# S_f        1.500862e+02  1.574764e+02  1.651145e+02  1.730215e+02
# S_h        1.770256e+02  1.865665e+02  1.964577e+02  2.067236e+02
# V_b        2.273737e-13  2.273737e-13  0.000000e+00  2.273737e-13
# V_f        1.680850e+03  1.838326e+03  2.003441e+03  2.176464e+03
# V_h        1.295989e+03  1.482560e+03  1.679024e+03  1.885753e+03
# W          3.271105e+02  3.440416e+02  3.615706e+02  3.797434e+02
# Y          6.542211e+02  6.880831e+02  7.231411e+02  7.594868e+02
# YD         5.041334e+02  5.306052e+02  5.580248e+02  5.864635e+02
# Yk         6.788635e+02  7.586591e+02  8.426745e+02  9.310220e+02
# Z          1.276282e+02  1.340096e+02  1.407100e+02  1.477455e+02
# _I_h__1    1.215506e+02  1.276282e+02  1.340096e+02  1.407100e+02
# _K_HD__1   9.525631e+02  1.080191e+03  1.214201e+03  1.354911e+03
# _K_f__1    1.697159e+03  1.896648e+03  2.106686e+03  2.327555e+03
# _L__1      1.663958e+02  2.157981e+02  2.683599e+02  3.241135e+02
# _MO__1     7.575631e+02  8.851913e+02  1.019201e+03  1.159911e+03
# _M__1      9.239590e+02  1.100989e+03  1.287561e+03  1.484024e+03
# _g_Ih__1   5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# _h__1      3.044274e-01  3.049258e-01  3.052519e-01  3.054294e-01
# alpha      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# beta       2.000000e-01  2.000000e-01  2.000000e-01  2.000000e-01
# g_Ih       5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# gamma_F    4.635400e-01  4.635400e-01  4.635400e-01  4.635400e-01
# gamma_u    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02
# gk         1.175428e-01  1.107421e-01  1.048417e-01  9.967807e-02
# gz         5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# h          3.049258e-01  3.052519e-01  3.054294e-01  3.054776e-01
# omega      5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# omegapar   5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# rl         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rm         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rmo        2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# spread_l   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# u          9.637004e-01  9.069728e-01  8.581500e-01  8.157561e-01
# un         8.000000e-01  8.000000e-01  8.000000e-01  8.000000e-01
# v          2.500000e+00  2.500000e+00  2.500000e+00  2.500000e+00
#
#                     9        ...                491           492  \
# C          3.985974e+02      ...       3.696029e+12  3.880720e+12
# FD         2.097212e+02      ...       2.127639e+12  2.233984e+12
# FT         3.985974e+02      ...       3.696029e+12  3.880720e+12
# FU         1.812142e+02      ...       1.838433e+12  1.930323e+12
# Fn         3.909354e+02      ...       3.966073e+12  4.164308e+12
# I_f        2.434731e+02      ...       1.161238e+12  1.219190e+12
# I_h        1.551328e+02      ...       2.534813e+12  2.661553e+12
# I_t        3.986037e+02      ...       3.696047e+12  3.880739e+12
# K          4.460821e+03      ...       7.767548e+13  8.155622e+13
# K_HD       1.657789e+03      ...       5.323106e+13  5.589262e+13
# K_HS       1.657789e+03      ...       5.323106e+13  5.589262e+13
# K_f        2.803034e+03      ...       2.444442e+13  2.566361e+13
# L          4.453559e+02      ...      -1.417940e+13 -1.489053e+13
# M          1.908145e+03      ...       3.905166e+13  4.100209e+13
# MO         1.462789e+03      ...       5.323106e+13  5.589262e+13
# S_b        7.105427e-15      ...      -1.220703e-04  0.000000e+00
# S_f        1.812142e+02      ...       1.838433e+12  1.930323e+12
# S_h        2.173849e+02      ...       1.857601e+12  1.950403e+12
# V_b        2.273737e-13      ...       0.000000e+00  0.000000e+00
# V_f        2.357678e+03      ...       3.862382e+13  4.055414e+13
# V_h        2.103145e+03      ...       3.905167e+13  4.100209e+13
# W          3.985974e+02      ...       3.696029e+12  3.880720e+12
# Y          7.971948e+02      ...       7.392057e+12  7.761439e+12
# YD         6.159786e+02      ...       5.553617e+12  5.831109e+12
# Yk         1.023824e+03      ...       9.313272e+12  9.777767e+12
# Z          1.551328e+02      ...       2.534813e+12  2.661553e+12
# _I_h__1    1.477455e+02      ...       2.414107e+12  2.534813e+12
# _K_HD__1   1.502656e+03      ...       5.069625e+13  5.323106e+13
# _K_f__1    2.559561e+03      ...       2.328318e+13  2.444442e+13
# _L__1      3.830976e+02      ...      -1.350221e+13 -1.417940e+13
# _MO__1     1.307656e+03      ...       5.069625e+13  5.323106e+13
# _M__1      1.690754e+03      ...       3.719404e+13  3.905166e+13
# _g_Ih__1   5.000000e-02      ...       5.000000e-02  5.000000e-02
# _h__1      3.054776e-01      ...       1.571026e-01  1.570927e-01
# alpha      1.000000e+00      ...       1.000000e+00  1.000000e+00
# beta       2.000000e-01      ...       2.000000e-01  2.000000e-01
# g_Ih       5.000000e-02      ...       5.000000e-02  5.000000e-02
# gamma_F    4.635400e-01      ...       4.635400e-01  4.635400e-01
# gamma_u    1.000000e-02      ...       1.000000e-02  1.000000e-02
# gk         9.512299e-02      ...       4.987456e-02  4.987600e-02
# gz         5.000000e-02      ...       5.000000e-02  5.000000e-02
# h          3.054123e-01      ...       1.570927e-01  1.570830e-01
# omega      5.000000e-01      ...       5.000000e-01  5.000000e-01
# omegapar   5.000000e-01      ...       5.000000e-01  5.000000e-01
# rl         2.000000e-02      ...       2.000000e-02  2.000000e-02
# rm         2.000000e-02      ...       2.000000e-02  2.000000e-02
# rmo        2.000000e-02      ...       2.000000e-02  2.000000e-02
# spread_l   0.000000e+00      ...       0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00      ...       0.000000e+00  0.000000e+00
# u          7.786440e-01      ...       7.937122e-01  7.937844e-01
# un         8.000000e-01      ...       8.000000e-01  8.000000e-01
# v          2.500000e+00      ...       2.500000e+00  2.500000e+00
#
#                     493           494           495           496  \
# C          4.074641e+12  4.278264e+12  4.492054e+12  4.716479e+12
# FD         2.345645e+12  2.462893e+12  2.585997e+12  2.715227e+12
# FT         4.074641e+12  4.278264e+12  4.492054e+12  4.716479e+12
# FU         2.026806e+12  2.128117e+12  2.234487e+12  2.346151e+12
# Fn         4.372452e+12  4.591010e+12  4.820484e+12  5.061379e+12
# I_f        1.280035e+12  1.343921e+12  1.410993e+12  1.481399e+12
# I_h        2.794631e+12  2.934362e+12  3.081080e+12  3.235134e+12
# I_t        4.074661e+12  4.278280e+12  4.492070e+12  4.716523e+12
# K          8.563088e+13  8.990917e+13  9.440124e+13  9.911777e+13
# K_HD       5.868725e+13  6.162161e+13  6.470269e+13  6.793782e+13
# K_HS       5.868725e+13  6.162161e+13  6.470269e+13  6.793782e+13
# K_f        2.694364e+13  2.828756e+13  2.969856e+13  3.117995e+13
# L         -1.563730e+13 -1.642150e+13 -1.724499e+13 -1.810974e+13
# M          4.304995e+13  4.520011e+13  4.745770e+13  4.982809e+13
# MO         5.868725e+13  6.162161e+13  6.470269e+13  6.793782e+13
# S_b        0.000000e+00 -1.220703e-04  0.000000e+00  0.000000e+00
# S_f        2.026806e+12  2.128117e+12  2.234487e+12  2.346151e+12
# S_h        2.047841e+12  2.150152e+12  2.257572e+12  2.370342e+12
# V_b        0.000000e+00 -7.812500e-03 -7.812500e-03  0.000000e+00
# V_f        4.258094e+13  4.470906e+13  4.694354e+13  4.928969e+13
# V_h        4.304995e+13  4.520012e+13  4.745770e+13  4.982809e+13
# W          4.074641e+12  4.278264e+12  4.492054e+12  4.716479e+12
# Y          8.149282e+12  8.556529e+12  8.984108e+12  9.432958e+12
# YD         6.122468e+12  6.428406e+12  6.749615e+12  7.086790e+12
# Yk         1.026544e+13  1.077746e+13  1.131502e+13  1.187942e+13
# Z          2.794631e+12  2.934362e+12  3.081080e+12  3.235134e+12
# _I_h__1    2.661553e+12  2.794631e+12  2.934362e+12  3.081080e+12
# _K_HD__1   5.589262e+13  5.868725e+13  6.162161e+13  6.470269e+13
# _K_f__1    2.566361e+13  2.694364e+13  2.828756e+13  2.969856e+13
# _L__1     -1.489053e+13 -1.563730e+13 -1.642150e+13 -1.724499e+13
# _MO__1     5.589262e+13  5.868725e+13  6.162161e+13  6.470269e+13
# _M__1      4.100209e+13  4.304995e+13  4.520011e+13  4.745770e+13
# _g_Ih__1   5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# _h__1      1.570830e-01  1.570733e-01  1.570638e-01  1.570543e-01
# alpha      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# beta       2.000000e-01  2.000000e-01  2.000000e-01  2.000000e-01
# g_Ih       5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# gamma_F    4.635400e-01  4.635400e-01  4.635400e-01  4.635400e-01
# gamma_u    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02
# gk         4.987742e-02  4.987895e-02  4.988034e-02  4.988117e-02
# gz         5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# h          1.570733e-01  1.570638e-01  1.570543e-01  1.570450e-01
# omega      5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# omegapar   5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# rl         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rm         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rmo        2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# spread_l   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# u          7.938558e-01  7.939284e-01  7.939981e-01  7.940586e-01
# un         8.000000e-01  8.000000e-01  8.000000e-01  8.000000e-01
# v          2.500000e+00  2.500000e+00  2.500000e+00  2.500000e+00
#
#                     497           498           499           500
# C          4.952193e+12  5.199640e+12  5.459546e+12  5.732304e+12
# FD         2.850956e+12  2.993445e+12  3.143105e+12  3.300173e+12
# FT         4.952193e+12  5.199640e+12  5.459546e+12  5.732304e+12
# FU         2.463431e+12  2.586552e+12  2.715869e+12  2.851587e+12
# Fn         5.314388e+12  5.579996e+12  5.858974e+12  6.151760e+12
# I_f        1.555343e+12  1.632964e+12  1.714490e+12  1.800044e+12
# I_h        3.396891e+12  3.566736e+12  3.745073e+12  3.932326e+12
# I_t        4.952227e+12  5.199689e+12  5.459560e+12  5.732358e+12
# K          1.040700e+14  1.092697e+14  1.147293e+14  1.204616e+14
# K_HD       7.133472e+13  7.490145e+13  7.864652e+13  8.257885e+13
# K_HS       7.133472e+13  7.490145e+13  7.864652e+13  8.257885e+13
# K_f        3.273530e+13  3.436826e+13  3.608275e+13  3.788280e+13
# L         -1.901782e+13 -1.997140e+13 -2.097278e+13 -2.202432e+13
# M          5.231689e+13  5.493005e+13  5.767374e+13  6.055453e+13
# MO         7.133472e+13  7.490145e+13  7.864652e+13  8.257885e+13
# S_b       -2.441406e-04  1.220703e-04  0.000000e+00  0.000000e+00
# S_f        2.463431e+12  2.586552e+12  2.715869e+12  2.851587e+12
# S_h        2.488773e+12  2.613104e+12  2.743682e+12  2.880735e+12
# V_b        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# V_f        5.175312e+13  5.433966e+13  5.705553e+13  5.990711e+13
# V_h        5.231690e+13  5.493006e+13  5.767375e+13  6.055454e+13
# W          4.952193e+12  5.199640e+12  5.459546e+12  5.732304e+12
# Y          9.904386e+12  1.039928e+13  1.091909e+13  1.146461e+13
# YD         7.440942e+12  7.812710e+12  8.203218e+12  8.613001e+12
# Yk         1.247198e+13  1.309412e+13  1.374730e+13  1.443310e+13
# Z          3.396891e+12  3.566736e+12  3.745073e+12  3.932326e+12
# _I_h__1    3.235134e+12  3.396891e+12  3.566736e+12  3.745073e+12
# _K_HD__1   6.793782e+13  7.133472e+13  7.490145e+13  7.864652e+13
# _K_f__1    3.117995e+13  3.273530e+13  3.436826e+13  3.608275e+13
# _L__1     -1.810974e+13 -1.901782e+13 -1.997140e+13 -2.097278e+13
# _MO__1     6.793782e+13  7.133472e+13  7.490145e+13  7.864652e+13
# _M__1      4.982809e+13  5.231689e+13  5.493005e+13  5.767374e+13
# _g_Ih__1   5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# _h__1      1.570450e-01  1.570358e-01  1.570267e-01  1.570177e-01
# alpha      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# beta       2.000000e-01  2.000000e-01  2.000000e-01  2.000000e-01
# g_Ih       5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# gamma_F    4.635400e-01  4.635400e-01  4.635400e-01  4.635400e-01
# gamma_u    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02
# gk         4.988279e-02  4.988390e-02  4.988586e-02  4.988655e-02
# gz         5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# h          1.570358e-01  1.570267e-01  1.570177e-01  1.570088e-01
# omega      5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# omegapar   5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# rl         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rm         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rmo        2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# spread_l   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# u          7.941309e-01  7.941947e-01  7.942715e-01  7.943274e-01
# un         8.000000e-01  8.000000e-01  8.000000e-01  8.000000e-01
# v          2.500000e+00  2.500000e+00  2.500000e+00  2.500000e+00
#
# [52 rows x 501 columns]

# %% [markdown]
# # Plots

# %%
ax = df['K_HD'][10:].pct_change().plot(color = "black", title = "Houses growth rate", label = "$K_{HD}$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
plt.xlabel("Period")
sns.despine()
plt.show()

# %%
ax = df[['C', 'I_t']].apply(lambda x: x/df['Y']).plot(kind = 'area', stacked = True, legend = True, title = "Consumption and total investiment as % of GDP")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['I_f', 'I_h']].apply(lambda x: x/df['I_t']).plot(kind = 'area', stacked = True, legend = True, title = "Residential and Non-residential Investiment (as % of total investment)")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['W', 'FT']].apply(lambda x: x/df['Y']).plot(kind = 'area', stacked = True, legend = True, title = "Wage and profit share (as % of GDP)")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['V_b', 'V_h', 'V_f']].apply(lambda x: np.abs(x)/df['K']).plot(kind = 'area', stacked = True, title = "Net financial wealth (as % K)")
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
sns.despine()
plt.show()

ax = df[['V_b', 'V_h', 'V_f']].plot(title = "Net financial wealth", kind = "area", stacked = False)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
sns.despine()
plt.show()

# %%
df[["S_b", "S_h", "S_f"]].plot(title = "Savings")
sns.despine()
plt.show()

# %%
df['S_b'].plot(title = "Banks savings")
sns.despine()
plt.show()

# %%
ax = df[["FU", "FD"]].apply(lambda x: x/df["Fn"]).plot(kind = "area", stacked = True, title = "Profits (as % net profits)")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.axhline(y = 1, color = "black", ls = "--")
sns.despine()
plt.show()

# %%
ax = df[["MO", "L"]].apply(lambda x: x/df["M"]).plot(kind = "area",stacked = False ,title = "Credit (as % Deposits)")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.axhline(y = 1, color = "blue", ls = "--")
ax.axhline(y = 0, color = "black", ls = "--")
ax.axhline(y = -1, color = "red", ls = "--")
sns.despine()
plt.show()

# %%
df["M"].plot(title = "Deposits")
sns.despine()
plt.show()

# %%
ax = df['Y'].pct_change().plot(color = "black", title = "GDP growth rate", label = "$Y_t$", legend = True)
ax.set_yticklabels(['{:,.2%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=df["gz"][0], color = "red", ls = "--", lw=1, label = "Autonomous growth rate")
sns.despine()
plt.show()

# %%
ax = df['u'].plot(color = "black", title = "Capacity utilization ratio", label = "$u_t$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
ax = df['un'].plot(color = "red", ls="--",  title = "Capacity utilization ratio", label = "$un$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df['h'].plot(color = "black", ls="-",  title = "Marginal propensity to invest", label = "$h_t$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[["Y", "K", "I_h", "I_f"]][40:].pct_change().plot(title = "Growth rates")
ax.set_yticklabels(['{:,.2%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=df["gz"][0], color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
sns.despine()
plt.show()

# %% [markdown]
# # Analytical solution

# %%
base = model()
SolveSFC(base, time=1, table = False)
t = sp.Symbol('t')
initials = {
    key: base.evaluate(key) for key in base.parameters
}
initials.update({key: base.evaluate(key) for key in base.variables})

# %% [markdown]
# Model variables

# %%
for i in base.variables:
  globals()["_" + i] = sp.Function(i)

# %% [markdown]
# Model parameters

# %%
for i in base.parameters:
  globals()[i] = sp.Symbol(i)

# %% [markdown]
# Defining equations

# %% [markdown]
# ## General equations

# %%
Y = _C(t) + _I_t(t)
I = _I_f(t) + _I_h(t)
Yk = _K_f(t-1)/v
u = _Y(t)/_Yk(t)
Z = _I_h(t)
W = _omega(t)*_Y(t)
K = _K_HD(t) + _K_f(t)

# %% [markdown]
# ## Households

# %%
C = alpha*_W(t)
YD = _W(t) + _FD(t) + rm*_M(t-1) - _rmo(t)*_MO(t-1)
S_h = _YD(t) - _C(t)
dMO = _I_h(t)
V_h = _M(t) + _K_HD(t) - _MO(t)

# %% [markdown]
# ## Firms

# %%
I_f = _h(t)*_Y(t)
dK_f = _I_f(t)
L = _I_f(t) - _FU(t) + _L(t-1)
FT = _FU(t) + _FD(t)
FU = gamma_F*(_FT(t) - _rl(t)*_L(t-1))
FD = (1 - gamma_F)*(_FT(t) - _rl(t)*_L(t-1))
h = _h(t-1)*gamma_u*(_u(t)-un) + _h(t-1)
S_f = _FU(t) - _I_f(t)
V_f = _K_f(t) - _L(t)

# %% [markdown]
# ## Banks

# %%
M = (_L(t) - _L(t-1)) + (_MO(t) - _MO(t-1)) + _M(t-1)
rmo = rm + spread_mo
rl = rm + spread_l
V_b = _L(t) + _MO(t) - _M(t)
S_b = _rl(t)*_L(t-1) + _rmo(t)*_MO(t-1) - rm*_M(t-1)

# %% [markdown]
# ## Residential Investment

# %%
K_HS = _K_HD(t)
dK_HD = _I_h(t)
I_h = _I_h(t-1)*(1+_g_Ih(-1))
g_Ih = gz

# %% [markdown]
# # Rearranging

# %% [markdown]
# ## Level of GDP

# %%
EqY = Y - _Y(t)
EqY = EqY.subs(_C(t), C).subs(_I_t(t), I)
EqY = EqY.subs(_I_f(t), I_f)
EqY = EqY.subs(_W(t), W)
EqY = sp.solve(EqY, _Y(t))[0].collect(alpha).collect(omegapar)
solY = EqY
print('Y = ', solY)
print('dY/d alpha = ', EqY.diff(alpha))
print('dY/d omega = ', EqY.diff(_omega(t)))

print("\nReplacing the initial values.....")
EqY = EqY.subs(_h(t), h)
EqY = EqY.subs(alpha, df.loc[2, 'alpha']).subs(_omega(t), df.loc[2, 'omega'])
EqY = EqY.subs(un, df.loc[2, 'un']).subs(gamma_u, df.loc[1, 'gamma_u'])
EqY = EqY.subs(_u(t), df.loc[2, 'u']).subs(_h(t-1), df.loc[1, 'h'])
EqY = EqY.subs(_I_h(t), df.loc[2, 'I_h'])
print('Y0 = ', df.loc[1, 'Y'])
print('Y1 = ', EqY)
print('hat Y - Y1 = ', df.loc[2, "Y"] - EqY)
# Out:
# Y =  -I_h(t)/(alpha*omega(t) + h(t) - 1)
# dY/d alpha =  I_h(t)*omega(t)/(alpha*omega(t) + h(t) - 1)**2
# dY/d omega =  alpha*I_h(t)/(alpha*omega(t) + h(t) - 1)**2
#
# Replacing the initial values.....
# Y0 =  529.1198613927506
# Y1 =  559.050061316764
# hat Y - Y1 =  -0.0287963227365253

# %% [markdown]
# $$
# Y_{SR} =  \frac{-I_h(t)}{\alpha\cdot \omega + h(t) - 1}
# $$
#
# Rearranging
#
# $$
# Y_{SR} =  \frac{I_h(t)}{1 - \alpha\cdot \omega - h(t)}
# $$

# %% [markdown]
# ## Capacity output ratio (short-run)

# %% [markdown]
# $$
# \frac{Y}{K(-1)} = \frac{Y}{K(-1)}\frac{Yk}{Yk} = \frac{u}{v}
# $$
#
# $$
# \therefore u = \frac{Y}{K(-1)}v
# $$
#
# $$
# i_{h_t} = \frac{I_h}{K_{t-1}}
# $$
#
# $$
# K(-1) = (1+g_K(-1))\cdot K(-2)
# $$

# %%
Equ = Y - _Y(t)
Equ = Equ.subs(_C(t), _C(t)*v/_K_f(t-1)).subs(_I_t(t), _I_t(t)*v/_K_f(t-1)).subs(_Y(t), _u(t))
Equ = Equ.subs(_C(t), C).subs(_I_t(t), I)
Equ = Equ.subs(_I_f(t), I_f)
Equ = Equ.subs(_W(t), W)
Equ = Equ.expand()
Equ = Equ.subs(_Y(t)/_K_f(t-1), _u(t)/v)
i_h = sp.Function('i_h')
Equ = Equ.subs(_I_h(t)/_K_f(t-1), i_h(t))
Equ = Equ.collect(_u(t))
Equ = Equ.subs(_W(t), W)
Equ = sp.solve(Equ, _u(t))[0].factor().collect(alpha*omegapar).collect(_h(t)).collect(1+_gk(t-1))
Equ = Equ.subs(_I_h(t)/_K_f(t-1), i_h(t))
solu = Equ.collect(alpha**2).collect(omegapar).collect(_YD(t)).collect(alpha)
Equ = Equ.subs(_Y(t), EqY)
print('u = ', solu)
print('\nDerivatives')
print('du/d alpha = ', Equ.diff(alpha))
print('du/d omega = ', Equ.diff(omegapar))

print("\nReplacing the initial values.....")
Equ = Equ.subs(alpha, df.loc[1,'alpha']).subs(_omega(t), df.loc[1,'omega']).subs(alpha, df.loc[1,'alpha'])
Equ = Equ.subs(_gk(t-1), df.loc[0,'gk']).subs(_h(t), df.loc[1,'h']).subs(v, df.loc[1,'v'])
Equ = Equ.subs(i_h(t), df.loc[1,'I_h']/df.loc[0,'K_f']).subs(_YD(t), df.loc[1, 'YD'])

print('u0 = ', df.loc[0,'u'].round(3))
print('u1 = ', Equ.round(3))
print("hat u - u1 = ", (df.loc[1,'u'] - Equ).round(3))
# Out:
# u =  -v*i_h(t)/(alpha*omega(t) + h(t) - 1)
#
# Derivatives
# du/d alpha =  v*i_h(t)*omega(t)/(alpha*omega(t) + h(t) - 1)**2
# du/d omega =  0
#
# Replacing the initial values.....
# u0 =  0.7
# u1 =  1.323
# hat u - u1 =  0.

# %%
sp.latex(solu).replace("omegapar", "\\omega")
solu
# Out:
# -v*i_h(t)/(alpha*omega(t) + h(t) - 1)

# %% [markdown]
# $$
# u_{SR} =
# - \frac{v \operatorname{i_{h}}{\left (t \right )}}{\alpha \omega + h{\left (t \right )} - 1}
# $$

# %% [markdown]
# Rerranging
#
# $$
# u_{SR} =  \frac{v\cdot i_h(t)}{1 - \alpha\cdot \omega - h(t)}
# $$

# %% [markdown]
# # Medium run
#
# $$
# \Delta h_t = h_{t-1}\cdot \gamma_u\cdot (u_t - un)
# $$

# %%
Y_MR = solY
Y_MR = Y_MR.subs(_h(t), h).collect(_h(t-1))
print("Y_MR = ", Y_MR)
# Out:
# Y_MR =  -I_h(t)/(alpha*omega(t) + (gamma_u*(-un + u(t)) + 1)*h(t - 1) - 1)

# %% [markdown]
# $$
# Y_{MR} =
# - \frac{\operatorname{I_{h}}{\left (t \right )}}{\alpha \omega{\left (t \right )} + \left(\gamma_{u} \left(- un + u{\left (t \right )}\right) + 1\right) h{\left (t - 1 \right )} - 1}$$

# %%
u_MR = Y_MR.subs(_I_h(t), _I_h(t)*v/_K_f(t-1)) - _u(t)
u_MR = u_MR.subs(_I_h(t)/_K_f(t), i_h(t))
soluMR = sp.solve(u_MR, _u(t))[0]
soluMR
# Out:
# (-sqrt((alpha**2*K_f(t - 1)*omega(t)**2 - 2*alpha*gamma_u*un*K_f(t - 1)*h(t - 1)*omega(t) + 2*alpha*K_f(t - 1)*h(t - 1)*omega(t) - 2*alpha*K_f(t - 1)*omega(t) + gamma_u**2*un**2*K_f(t - 1)*h(t - 1)**2 - 2*gamma_u*un*K_f(t - 1)*h(t - 1)**2 + 2*gamma_u*un*K_f(t - 1)*h(t - 1) - 4*gamma_u*v*I_h(t)*h(t - 1) + K_f(t - 1)*h(t - 1)**2 - 2*K_f(t - 1)*h(t - 1) + K_f(t - 1))*K_f(t - 1)) + (-alpha*omega(t) + gamma_u*un*h(t - 1) - h(t - 1) + 1)*K_f(t - 1))/(2*gamma_u*K_f(t - 1)*h(t - 1))

# %% [markdown]
# $$
# u_{MR} =
# \frac{1}{2 \gamma_{u} h{\left (t - 1 \right )}} \left(- \alpha \omega{\left (t \right )} + \gamma_{u} un h{\left (t - 1 \right )} - \sqrt{\alpha^{2} \omega^{2}{\left (t \right )} - 2 \alpha \gamma_{u} un h{\left (t - 1 \right )} \omega{\left (t \right )} + 2 \alpha h{\left (t - 1 \right )} \omega{\left (t \right )} - 2 \alpha \omega{\left (t \right )} + \gamma_{u}^{2} un^{2} h^{2}{\left (t - 1 \right )} - 2 \gamma_{u} un h^{2}{\left (t - 1 \right )} + 2 \gamma_{u} un h{\left (t - 1 \right )} - 4 \gamma_{u} v h{\left (t - 1 \right )} \operatorname{i_{h}}{\left (t \right )} + h^{2}{\left (t - 1 \right )} - 2 h{\left (t - 1 \right )} + 1} - h{\left (t - 1 \right )} + 1\right)
# $$

# %% [markdown]
# # Long run

# %%
Y_LR = Y_MR.subs(_u(t), un)
Y_LR = Y_LR.subs(_h(t-1), _h(t))
Y_LR
# Out:
# -I_h(t)/(alpha*omega(t) + h(t) - 1)

# %% [markdown]
# $$- \frac{\operatorname{I_{h}}{\left (t \right )}}{\alpha \omega{\left (t \right )} + h{\left (t \right )} - 1}$$

# %%
u_LR = u_MR.subs(_h(t), h)
u_LR = u_LR.subs(_u(t), un)
u_LR
# Out:
# -un - v*I_h(t)/((alpha*omega(t) + h(t - 1) - 1)*K_f(t - 1))

# %% [markdown]
# $$- un - \frac{v \operatorname{i_{h}}{\left (t \right )}}{\alpha \omega{\left (t \right )} + h{\left (t - 1 \right )} - 1}$$

# %% [markdown]
# # Sensibility test

# %%
gamma_ufor = [i/1000 for i in range(5,1000,5)]

for i in gamma_ufor:
  gamma_model = model()
  try:
    gamma_model.set_values({
        'gamma_u' : i
    })
  
    gammadf = SolveSFC(gamma_model)
    print("For gamma_u = {}, GDP value is".format(i), gammadf['Y'].iloc[-1])
    print("\n Ploting...\n")
    gammadf['u'].plot()
    plt.show()
    plt.clf
  
    if (gammadf['Y'].iloc[-1] < 0):
      break
      print("GDP is negative")
    
    print("Continuing ...")
  except Exception as e:
    print(e)
    pass
# Out:
# For gamma_u = 0.005, GDP value is 12034972504462.838
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.01, GDP value is 11464607819327.098
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.015, GDP value is 11439209720261.164
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.02, GDP value is 11439168229507.305
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.025, GDP value is 11439355332824.586
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.03, GDP value is 11439676660212.904
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.035, GDP value is 11438536390618.945
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.04, GDP value is 11438942785974.035
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.045, GDP value is 11441435464363.273
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.05, GDP value is 11440783459034.605
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.055, GDP value is 11434897391282.803
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.06, GDP value is 11430890977004.531
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.065, GDP value is 11440069086918.822
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.07, GDP value is 11464039469496.184
#
#  Ploting...
# Continuing ...
# C, FD, Fn, FT, FU, I_t, I_f, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, S_h, S_f, W, Y, YD have not converged
# L have not converged
# C, FD, Fn, FT, I_f, L, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, L, M, S_h, S_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, S_h, S_f, V_h, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, S_h, S_f, u, V_h, V_f, W, Y, YD have not converged
# C, FD, Fn, FT, FU, h, S_h, S_f, u, V_h, V_f, V_b, W, Y, YD have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
# L, M, S_h, V_h, V_f, V_b have not converged
