# %% [markdown]
# # TODO
#
# - [ ] Checar importância da significância estatística dos coeficientes da regressão
# - [ ] Checar quebra estrutural em 1991

# %% [markdown]
# # Setup

# %%
# !rm *.csv # Removendo dados anteriores
# !rm -R figs # Removendo pasta de figuras
# !rm -R tabs # Removendo pasta de tabelas
# !mkdir figs # Criando pasta para salvar figuras
# !mkdir tabs # Criando pasta para salvar tabelas
# !ls
# Out:
# Benchmark.html		SeriesTemporais.Rproj	VECM_Infla.pdf
# Benchmark.ipynb		tabs			VECM_Infla.py
# Benchmark.pdf		tese_Lucas.xls		VECM_TxPropria.html
# Benchmark.Rmd		Teste.ipynb		VECM_TxPropria.ipynb
# Clean-checkpoint.ipynb	VECM_Infla.html		VECM_TxPropria_media.ipynb
# Clean.ipynb		VECM_Infla.ipynb	VECM_TxPropria.pdf
# figs			VECM_Infla_media.ipynb	VECM_TxPropria.py

# %% [markdown]
# # Introdução
#
# Esta rotina ajusta um modelo de séries temporais.
# Será testado se o investimento residencial ($I_h$) depende da <u>taxa própria de juros</u> dos imóveis, ou seja,
#
# $$
# I_h = f(r_{mo}, p_h)
# $$
# em que
#
# - $I_h$ Investimento residencial
#
#   + **Série:** PRFI
#   + Com ajuste sazonal
#   + Trimestral
#
# - $r_{mo}$ taxa de juros das hipotecas
#   + **Série:** MORTGAGE30US
#   - Sem ajuste sazonal
#   - Semanal (encerrado às quintas feiras)
#
# - $p_h$ Inflação de imóveis: Índice Case-Shiller
#
#   + **Série:** CSUSHPISA
#   + Com ajuste sazonal, Jan 2000 = 100
#   + Mensal
#
# **Nota:** Uma vez que pretende-se utilizar os resultados obtidos deste modelo em um trabalho futuro, os resultados serão checados tanto em python quanto em gretl, ambos softwares livres.

# %% [markdown]
# # Carregando pacotes

# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext rpy2.ipython

# Pacotes gerais

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.filterwarnings('ignore')
# Pacotes estatísticos

from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.tsa.api import SVAR
from statsmodels.tsa.vector_ar.vecm import coint_johansen, CointRankResults, VECM, select_coint_rank

from statsmodels.stats.diagnostic import acorr_breusch_godfrey, acorr_ljungbox, het_arch, het_breuschpagan, het_white
from statsmodels.tsa.stattools import adfuller, kpss, grangercausalitytests, q_stat, coint
from arch.unitroot import PhillipsPerron, ZivotAndrews, DFGLS, KPSS, ADF

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Pacotes para importação de dados

import pandas_datareader.data as web
from scipy.stats import yeojohnson

# Configurações do notebook

plt.style.use('seaborn-white')
start = datetime.datetime(1987, 1, 1)
#start = datetime.datetime(1992, 1, 1)
end = datetime.datetime(2019, 7, 1)

# %% [markdown]
# # Importando dados

# %%
df = web.DataReader(
    [
        "PRFI",
        "CSUSHPISA",
        "MORTGAGE30US",
    ], 
    'fred', 
    start, 
    end
)

df.columns = [
    "Investimento residencial", 
    "Preço dos imóveis", 
    "Taxa de juros",
]
df.index.name = ""

df['Taxa de juros'] = df['Taxa de juros'].divide(100)
df = df.resample('M').last()
df['Preço dos imóveis'] = df['Preço dos imóveis']/df['Preço dos imóveis'][0]
df = df.resample('Q').last()
#df = df.resample('Q').mean() #### Antigo
df["Inflação"] = df["Preço dos imóveis"].pct_change(4) # Warning: 12

df["Taxa Própria"] = ((1+df["Taxa de juros"])/(1+df["Inflação"])) -1
df['Taxa Própria'], *_ = yeojohnson(df['Taxa Própria'])
df['gZ'], *_ = yeojohnson(df["Investimento residencial"].pct_change(4))
df['Inflação'], *_ = yeojohnson(df['Inflação'])

df["Crise"] = [0 for i in range(len(df["gZ"]))]
for i in range(len(df["Crise"])):
    if df.index[i] > datetime.datetime(2007,12,1) and df.index[i] < datetime.datetime(2009,7,1):
        df["Crise"][i] = 1

df.to_csv("Dados_yeojohnson.csv")


df.to_csv(
    "Dados_yeojohnson_ascii.csv", 
    encoding='ascii', 
    header = [
        #'data',
        'invRes',
        'preco',
        'juros',
        'infla',
        'taxap',
        'gz',
        'crise',
          ], 
         )

df = df[["Taxa de juros", "Inflação", "gZ", "Crise", "Taxa Própria"]]
df.plot()
sns.despine()
plt.show()

df["d_Taxa Própria"] = df["Taxa Própria"].diff()
df["d_gZ"] = df["gZ"].diff()
df["d_Inflação"] = df["Inflação"].diff()
df["d_Taxa de juros"] = df['Taxa de juros'].diff()
df = df.dropna()
df.head()
# Out:
#             Taxa de juros  Inflação        gZ  Crise  Taxa Própria  \
#
# 1988-06-30         0.1040  0.095934  0.025430      0      0.032525
# 1988-09-30         0.1042  0.096154  0.033724      0      0.032601
# 1988-12-31         0.1077  0.095143  0.039976      0      0.037428
# 1989-03-31         0.1119  0.097452  0.050665      0      0.040773
# 1989-06-30         0.1007  0.082775  0.001108      0      0.038373
#
#             d_Taxa Própria      d_gZ  d_Inflação  d_Taxa de juros
#
# 1988-06-30        0.007931  0.010722   -0.004889           0.0041
# 1988-09-30        0.000076  0.008294    0.000221           0.0002
# 1988-12-31        0.004827  0.006252   -0.001011           0.0035
# 1989-03-31        0.003345  0.010689    0.002309           0.0042
# 1989-06-30       -0.002400 -0.049557   -0.014678          -0.0112

# %% [markdown]
# # Funções

# %% [markdown]
# ## Teste de raíz unitária

# %%
def testes_raiz(df=df["gZ"], original_trend='c', diff_trend='c'):
    """
    serie: Nome da coluna do df
    orignal_trend: 'c', 'ct', 'ctt'
    diff_trend: 'c', 'ct', 'ctt'
    
    Plota série o original e em diferenta e retorna testes de raíz unitária
    """
    fig, ax = plt.subplots(1,2)

    df.plot(ax=ax[0], title='série original')
    df.diff().plot(ax=ax[1], title='série em diferença')

    plt.tight_layout()
    sns.despine()
    plt.show()
    
    fig, ax = plt.subplots(2,2)
    
    plot_acf(df, ax=ax[0,0], title='ACF: serie original') 
    plot_pacf(df, ax=ax[0,1], title='PACF: serie original')
    
    plot_acf(df.diff().dropna(), ax=ax[1,0], title='ACF: serie em diferença') 
    plot_pacf(df.diff().dropna(), ax=ax[1,1], title='PACF: serie em diferença')
    
    plt.tight_layout()
    sns.despine() 
    plt.show()

    
    # Zivot Andrews
    print('\nZIVOT ANDREWS série em nível')
    print(ZivotAndrews(df, trend = original_trend).summary(),"\n")
    print('\nZIVOT ANDREWS série em primeira difenrença')
    print(ZivotAndrews(df.diff().dropna(), trend = diff_trend).summary(),"\n")
    
    print('\nADF série em nível')
    print(ADF(df, trend=original_trend).summary(),"\n")
    print('\nADF série em primeira diferença')
    print(ADF(df.diff().dropna(), trend=diff_trend).summary(),"\n")
    
    print('\nDFGLS série em nível')
    print(DFGLS(df, trend=original_trend).summary(),"\n")
    print('\nDFGLS série em primeira diferença')
    print(DFGLS(df.diff().dropna(), trend=diff_trend).summary(),"\n")
    
    print('\nKPSS em nível')
    print(KPSS(df, trend = original_trend).summary(),"\n")
    print('\nKPSS em primeira diferença')
    print(KPSS(df.diff().dropna(), trend = diff_trend).summary(),"\n")
    
    print('\nPhillips Perron em nível')
    print(PhillipsPerron(df, trend=original_trend).summary(),"\n")
    print('\nPhillips Perron em primeira diferença')
    print(PhillipsPerron(df.diff().dropna(), trend=diff_trend).summary(),"\n")

# %% [markdown]
# ## Teste de Cointegração Engel-Granger e de Johansen

# %%
# Teste de cointegração

def cointegracao(ts0, ts1, signif = 0.05, lag=1):
  trends = ['nc', 'c', 'ct', 'ctt']
  for trend in trends:
    print(f"\nTestando para lag = {lag} e trend = {trend}")
    result = coint(ts0, ts1, trend = trend, maxlag=lag)
    print('Null Hypothesis: there is NO cointegration')
    print('Alternative Hypothesis: there IS cointegration')
    print('t Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    if result[1] < signif:
      print('CONCLUSION: REJECT null Hypothesis: there IS cointegration\n')
    else:
      print('CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration\n')
    
def testes_coint(series, maxlag=8):
    for i in range(1, maxlag):
        print(50*'=')
        cointegracao(
            ts0=series.iloc[:, 0],
            ts1=series.iloc[:, 1:],
            signif=0.05,
            lag=i
        )
        print("\nTESTE DE JOHANSEN\n")
        result = select_coint_rank(endog=series, k_ar_diff=i, det_order=1, signif=0.01) ## Warning: 1
        print(result.summary())
        print(f'Para lag = {i}, Rank = {result.rank}')
        print(10*'=')

# %% [markdown]
# ## Análise de resíduos: Ljung-Box e Box-Pierce

# %%
### Resíduos

def LjungBox_Pierce(resid, signif = 0.05, boxpierce = False, k = 4):
  """
  resid = residuals df
  signif = signif. level
  """
  var = len(resid.columns)
  print("H0: autocorrelations up to lag k equal zero")
  print('H1: autocorrelations up to lag k not zero')
  print("Box-Pierce: ", boxpierce)
  
  for i in range(var):
    print("Testing for ", resid.columns[i].upper(), ". Considering a significance level of",  signif*100,"%")
    result = acorr_ljungbox(x = resid.iloc[:,i-1], lags = k, boxpierce = boxpierce)[i-1]
    conclusion = result < signif
    for j in range(k):
      print(f'p-value = {result[j]}')
      print("Reject H0 on lag " ,j+1,"? ", conclusion[j], "\n")
    print("\n")
    
def ARCH_LM(resid, signif = 0.05, autolag = 'bic'):
  """
  df = residuals df
  signif = signif. level
  """
  var = len(resid.columns)
  print("H0: Residuals are homoscedastic")
  print('H1: Residuals are heteroskedastic')
  
  for i in range(var):
    print("Testing for ", resid.columns[i].upper())
    result = het_arch(resid = resid.iloc[:,i], autolag = autolag)
    print('LM p-value: ', result[1])
    print("Reject H0? ", result[1] < signif)
    print('F p-value: ', result[3])
    print("Reject H0? ", result[3] < signif)
    print('\n')
    

def analise_residuos(results, nmax=15):
    
    residuals = pd.DataFrame(results.resid, columns = results.names)
    
    residuals.plot()
    sns.despine()
    plt.show()
    
    for serie in residuals.columns:
        sns.set_context('paper')
        fig, ax = plt.subplots(1,2, figsize=(10,8))

        plot_acf(residuals[serie], ax=ax[0], title=f'ACF Resíduo de {serie}', zero=False) 
        plot_pacf(residuals[serie], ax=ax[1], title=f'PACF Resíduo de {serie}', zero=False)
        
        plt.tight_layout()
        sns.despine() 
        plt.show()

    print('AUTOCORRELAÇÃO RESIDUAL: PORTMANTEAU\n')
    print(results.test_whiteness(nlags=nmax).summary())
    print('\nAUTOCORRELAÇÃO RESIDUAL: PORTMANTEAU AJUSTADO\n')
    print(results.test_whiteness(nlags=nmax, adjusted=True).summary())
    print('\nLJUNGBOX\n')
    LjungBox_Pierce(residuals, k = 12, boxpierce=False)
    print('\nBOXPIERCE\n')
    LjungBox_Pierce(residuals, k = 12, boxpierce=True)
    print('\nNORMALIDADE\n')
    print(results.test_normality().summary())
    print('\nHOMOCEDASTICIDADE\n')
    ARCH_LM(residuals)
    
    return residuals

# %%
results = []
def plot_lags(results = results, trimestres=[2, 5]):
    series = results.names
    fig, ax = plt.subplots(len(trimestres),2, figsize = (16,10))
    
    for i in range(len(trimestres)):
        sns.regplot(y = df[series[0]], x = df[series[1]].shift(-trimestres[i]), color = 'black', ax = ax[i,0], order = 2)
        ax[i,0].set_xlabel(f'{series[1]} defasada em {trimestres[i]} trimestres')

        sns.regplot(x = df[series[0]].shift(-trimestres[i]), y = df[series[1]], color = 'black', ax = ax[i,1], order = 2)
        ax[i,1].set_xlabel(f'{series[0]} defasada em {trimestres[i]} trimestres')

# %% [markdown]
# # Teste de quebra estrutural

# %%
# %%R -i df
# library(strucchange)
# library(urca)
# df <- df[,c(4:7)]
# names(df) <- c("Juros", "Infla", "TaxaP", "gZ")
# df <- ts(data = df, start = c(1987,01), frequency = 4)
# bp_ts <- breakpoints(Juros ~ 1, data=df)
# print("Testando quebra estrutural para Taxa de juros das hipotecas")
# print(summary(bp_ts))
#
# bp_ts <- breakpoints(gZ ~ 1, data=df)
# print("=========================")
# print("Testando quebra estrutural para Taxa de crescimento dos imóveis")
# print(summary(bp_ts))
#
# bp_ts <- breakpoints(TaxaP ~ 1, data=df)
# print("=========================")
# print("Testando quebra estrutural para Taxa Própria")
# print(summary(bp_ts))
#
# bp_ts <- breakpoints(Infla ~ 1, data=df)
# print("=========================")
# print("Testando quebra estrutural para Inflação")
# print(summary(bp_ts))
# Out:
# R[write to console]: Carregando pacotes exigidos: zoo
#
# R[write to console]:
# Attaching package: ‘zoo’
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# R[write to console]: Carregando pacotes exigidos: sandwich
# [1] "Testando quebra estrutural para Taxa de juros das hipotecas"
#
# 	 Optimal (m+1)-segment partition:
#
# Call:
# breakpoints.formula(formula = Juros ~ 1, data = df)
#
# Breakpoints at observation number:
#
# m = 1            78
# m = 2            67 85
# m = 3   18       67 85
# m = 4   18 36    67 85
# m = 5   18 36 54 73 91
#
# Corresponding to breakdates:
#
# m = 1                           2006(2)
# m = 2                           2003(3) 2008(1)
# m = 3   1991(2)                 2003(3) 2008(1)
# m = 4   1991(2) 1995(4)         2003(3) 2008(1)
# m = 5   1991(2) 1995(4) 2000(2) 2005(1) 2009(3)
#
# Fit:
#
# m   0       1       2       3       4       5
# RSS   6.608   5.957   4.278   4.278   4.278   4.278
# BIC  -3.113  -6.411 -38.155 -28.499 -18.842  -9.186
# [1] "========================="
# [1] "Testando quebra estrutural para Taxa de crescimento dos imÃ³veis"
#
# 	 Optimal (m+1)-segment partition:
#
# Call:
# breakpoints.formula(formula = gZ ~ 1, data = df)
#
# Breakpoints at observation number:
#
# m = 1               101
# m = 2            83 101
# m = 3         65 83 101
# m = 4      47 65 83 101
# m = 5   19 37 65 83 101
#
# Corresponding to breakdates:
#
# m = 1                                   2012(1)
# m = 2                           2007(3) 2012(1)
# m = 3                   2003(1) 2007(3) 2012(1)
# m = 4           1998(3) 2003(1) 2007(3) 2012(1)
# m = 5   1991(3) 1996(1) 2003(1) 2007(3) 2012(1)
#
# Fit:
#
# m   0         1         2         3         4         5
# RSS    0.5554    0.5437    0.5259    0.5016    0.4962    0.4883
# BIC -312.6553 -305.6544 -300.1655 -296.4234 -288.1095 -280.4622
# [1] "========================="
# [1] "Testando quebra estrutural para Taxa PrÃ³pria"
#
# 	 Optimal (m+1)-segment partition:
#
# Call:
# breakpoints.formula(formula = TaxaP ~ 1, data = df)
#
# Breakpoints at observation number:
#
# m = 1            84
# m = 2         66 84
# m = 3         66 84 102
# m = 4   18    66 84 102
# m = 5   18 42 66 84 102
#
# Corresponding to breakdates:
#
# m = 1                           2007(4)
# m = 2                   2003(2) 2007(4)
# m = 3                   2003(2) 2007(4) 2012(2)
# m = 4   1991(2)         2003(2) 2007(4) 2012(2)
# m = 5   1991(2) 1997(2) 2003(2) 2007(4) 2012(2)
#
# Fit:
#
# m   0          1          2          3          4          5
# RSS    0.07019    0.06375    0.05260    0.04416    0.04334    0.04329
# BIC -571.21279 -573.58915 -587.96910 -600.17268 -592.86961 -583.35738
# [1] "========================="
# [1] "Testando quebra estrutural para InflaÃ§Ã£o"
#
# 	 Optimal (m+1)-segment partition:
#
# Call:
# breakpoints.formula(formula = Infla ~ 1, data = df)
#
# Breakpoints at observation number:
#
# m = 1               97
# m = 2            76 95
# m = 3      38    76 95
# m = 4   20 39    76 95
# m = 5   20 38 56 76 95
#
# Corresponding to breakdates:
#
# m = 1                                   2011(1)
# m = 2                           2005(4) 2010(3)
# m = 3           1996(2)         2005(4) 2010(3)
# m = 4   1991(4) 1996(3)         2005(4) 2010(3)
# m = 5   1991(4) 1996(2) 2000(4) 2005(4) 2010(3)
#
# Fit:
#
# m   0         1         2         3         4         5
# RSS    1.0587    0.9095    0.5076    0.3416    0.3329    0.3270
# BIC -232.0228 -241.3481 -304.5846 -344.4384 -338.0177 -330.5791

# %% [markdown]
# Selecionando série para depois de 1991

# %%
df = df["1992-01-01":]

# %% [markdown]
# # Teste de raíz unitária

# %% [markdown]
# ## Investimento residencial ($g_Z$)

# %%
testes_raiz(df=df['gZ'])
# Out:
# ZIVOT ANDREWS série em nível
#         Zivot-Andrews Results
# =====================================
# Test Statistic                 -3.206
# P-value                         0.838
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: -5.28 (1%), -4.81 (5%), -4.57 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
#
# ZIVOT ANDREWS série em primeira difenrença
#         Zivot-Andrews Results
# =====================================
# Test Statistic                 -7.727
# P-value                         0.000
# Lags                                3
# -------------------------------------
#
# Trend: Constant
# Critical Values: -5.28 (1%), -4.81 (5%), -4.57 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
#
# ADF série em nível
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -2.406
# P-value                         0.140
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# ADF série em primeira diferença
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -7.298
# P-value                         0.000
# Lags                                3
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# DFGLS série em nível
#       Dickey-Fuller GLS Results
# =====================================
# Test Statistic                 -1.683
# P-value                         0.091
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: -2.75 (1%), -2.13 (5%), -1.82 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# DFGLS série em primeira diferença
#       Dickey-Fuller GLS Results
# =====================================
# Test Statistic                 -4.216
# P-value                         0.000
# Lags                                4
# -------------------------------------
#
# Trend: Constant
# Critical Values: -2.75 (1%), -2.13 (5%), -1.82 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# KPSS em nível
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.140
# P-value                         0.423
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: 0.74 (1%), 0.46 (5%), 0.35 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.
#
#
# KPSS em primeira diferença
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.043
# P-value                         0.915
# Lags                                2
# -------------------------------------
#
# Trend: Constant
# Critical Values: 0.74 (1%), 0.46 (5%), 0.35 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.
#
#
# Phillips Perron em nível
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -2.747
# P-value                         0.066
# Lags                               13
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# Phillips Perron em primeira diferença
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -9.694
# P-value                         0.000
# Lags                               13
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.

# %% [markdown]
# **Conclusão:** Série  não é fracamente estacionária.

# %% [markdown]
# ## Taxa própria

# %%
testes_raiz(df['Taxa Própria'])
# Out:
# ZIVOT ANDREWS série em nível
#         Zivot-Andrews Results
# =====================================
# Test Statistic                 -4.224
# P-value                         0.227
# Lags                                2
# -------------------------------------
#
# Trend: Constant
# Critical Values: -5.28 (1%), -4.81 (5%), -4.57 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
#
# ZIVOT ANDREWS série em primeira difenrença
#         Zivot-Andrews Results
# =====================================
# Test Statistic                 -7.121
# P-value                         0.000
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -5.28 (1%), -4.81 (5%), -4.57 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
#
# ADF série em nível
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -2.709
# P-value                         0.073
# Lags                                2
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# ADF série em primeira diferença
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -5.114
# P-value                         0.000
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# DFGLS série em nível
#       Dickey-Fuller GLS Results
# =====================================
# Test Statistic                 -2.362
# P-value                         0.018
# Lags                                2
# -------------------------------------
#
# Trend: Constant
# Critical Values: -2.75 (1%), -2.13 (5%), -1.81 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# DFGLS série em primeira diferença
#       Dickey-Fuller GLS Results
# =====================================
# Test Statistic                 -5.137
# P-value                         0.000
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -2.75 (1%), -2.13 (5%), -1.81 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# KPSS em nível
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.121
# P-value                         0.491
# Lags                                6
# -------------------------------------
#
# Trend: Constant
# Critical Values: 0.74 (1%), 0.46 (5%), 0.35 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.
#
#
# KPSS em primeira diferença
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.055
# P-value                         0.845
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: 0.74 (1%), 0.46 (5%), 0.35 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.
#
#
# Phillips Perron em nível
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -2.156
# P-value                         0.223
# Lags                               13
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# Phillips Perron em primeira diferença
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -3.486
# P-value                         0.008
# Lags                               13
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.

# %% [markdown]
# **Conclusão:** Será tomada em primeira diferença.

# %% [markdown]
# ## Inflação

# %%
testes_raiz(df['Inflação'])
# Out:
# ZIVOT ANDREWS série em nível
#         Zivot-Andrews Results
# =====================================
# Test Statistic                 -5.402
# P-value                         0.006
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: -5.28 (1%), -4.81 (5%), -4.57 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
#
# ZIVOT ANDREWS série em primeira difenrença
#         Zivot-Andrews Results
# =====================================
# Test Statistic                 -4.512
# P-value                         0.116
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: -5.28 (1%), -4.81 (5%), -4.57 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
#
# ADF série em nível
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -2.847
# P-value                         0.052
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# ADF série em primeira diferença
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -3.751
# P-value                         0.003
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.50 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# DFGLS série em nível
#       Dickey-Fuller GLS Results
# =====================================
# Test Statistic                 -2.488
# P-value                         0.013
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: -2.75 (1%), -2.13 (5%), -1.82 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# DFGLS série em primeira diferença
#       Dickey-Fuller GLS Results
# =====================================
# Test Statistic                 -3.309
# P-value                         0.001
# Lags                                4
# -------------------------------------
#
# Trend: Constant
# Critical Values: -2.75 (1%), -2.13 (5%), -1.82 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# KPSS em nível
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.131
# P-value                         0.455
# Lags                                6
# -------------------------------------
#
# Trend: Constant
# Critical Values: 0.74 (1%), 0.46 (5%), 0.35 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.
#
#
# KPSS em primeira diferença
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.068
# P-value                         0.763
# Lags                                5
# -------------------------------------
#
# Trend: Constant
# Critical Values: 0.74 (1%), 0.46 (5%), 0.35 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.
#
#
# Phillips Perron em nível
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -2.114
# P-value                         0.239
# Lags                               13
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# Phillips Perron em primeira diferença
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -3.389
# P-value                         0.011
# Lags                               13
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.

# %% [markdown]
# ## Taxa de juros das hipotecas

# %%
testes_raiz(df['Taxa de juros'], original_trend='ct')
# Out:
# ZIVOT ANDREWS série em nível
#         Zivot-Andrews Results
# =====================================
# Test Statistic                 -4.494
# P-value                         0.215
# Lags                                0
# -------------------------------------
#
# Trend: Constant and Linear Time Trend
# Critical Values: -5.58 (1%), -5.07 (5%), -4.83 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
#
# ZIVOT ANDREWS série em primeira difenrença
#         Zivot-Andrews Results
# =====================================
# Test Statistic                 -8.144
# P-value                         0.000
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -5.28 (1%), -4.81 (5%), -4.57 (10%)
# Null Hypothesis: The process contains a unit root with a single structural break.
# Alternative Hypothesis: The process is trend and break stationary.
#
#
# ADF série em nível
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -3.638
# P-value                         0.027
# Lags                                0
# -------------------------------------
#
# Trend: Constant and Linear Time Trend
# Critical Values: -4.04 (1%), -3.45 (5%), -3.15 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# ADF série em primeira diferença
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                 -8.050
# P-value                         0.000
# Lags                                1
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# DFGLS série em nível
#       Dickey-Fuller GLS Results
# =====================================
# Test Statistic                 -3.445
# P-value                         0.009
# Lags                                0
# -------------------------------------
#
# Trend: Constant and Linear Time Trend
# Critical Values: -3.60 (1%), -3.02 (5%), -2.73 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# DFGLS série em primeira diferença
#       Dickey-Fuller GLS Results
# =====================================
# Test Statistic                 -1.074
# P-value                         0.264
# Lags                                9
# -------------------------------------
#
# Trend: Constant
# Critical Values: -2.76 (1%), -2.14 (5%), -1.83 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# KPSS em nível
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.081
# P-value                         0.264
# Lags                                5
# -------------------------------------
#
# Trend: Constant and Linear Time Trend
# Critical Values: 0.22 (1%), 0.15 (5%), 0.12 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.
#
#
# KPSS em primeira diferença
#     KPSS Stationarity Test Results
# =====================================
# Test Statistic                  0.034
# P-value                         0.962
# Lags                                3
# -------------------------------------
#
# Trend: Constant
# Critical Values: 0.74 (1%), 0.46 (5%), 0.35 (10%)
# Null Hypothesis: The process is weakly stationary.
# Alternative Hypothesis: The process contains a unit root.
#
#
# Phillips Perron em nível
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                 -3.604
# P-value                         0.030
# Lags                               13
# -------------------------------------
#
# Trend: Constant and Linear Time Trend
# Critical Values: -4.04 (1%), -3.45 (5%), -3.15 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
#
# Phillips Perron em primeira diferença
#      Phillips-Perron Test (Z-tau)
# =====================================
# Test Statistic                -11.127
# P-value                         0.000
# Lags                               13
# -------------------------------------
#
# Trend: Constant
# Critical Values: -3.49 (1%), -2.89 (5%), -2.58 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.

# %% [markdown]
# # Cointegração

# %% [markdown]
# ## $g_Z$ e Taxa Própria

# %%
print("Ordem do VAR\n")

model = VAR(
    df[["gZ", 'Taxa Própria']],
)
print(model.select_order(maxlags=15, trend='ct').summary())

testes_coint(series=df[['gZ', 'Taxa Própria']], maxlag=9)
# Out:
# Ordem do VAR
#
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -9.099      -8.991   0.0001118      -9.055
# 1       -12.87      -12.65   2.578e-06      -12.78
# 2       -13.69     -13.37*   1.137e-06     -13.56*
# 3       -13.72      -13.29   1.097e-06      -13.55
# 4       -13.75      -13.22   1.066e-06      -13.54
# 5      -13.80*      -13.15  1.020e-06*      -13.54
# 6       -13.77      -13.01   1.056e-06      -13.46
# 7       -13.70      -12.84   1.135e-06      -13.35
# 8       -13.66      -12.69   1.182e-06      -13.27
# 9       -13.60      -12.53   1.254e-06      -13.17
# 10      -13.60      -12.42   1.258e-06      -13.13
# 11      -13.55      -12.26   1.329e-06      -13.03
# 12      -13.61      -12.21   1.270e-06      -13.04
# 13      -13.59      -12.08   1.302e-06      -12.98
# 14      -13.59      -11.98   1.305e-06      -12.94
# 15      -13.56      -11.84   1.358e-06      -12.87
# --------------------------------------------------
# ==================================================
#
# Testando para lag = 1 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.249464
# p-value: 0.152576
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 1 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.863356
# p-value: 0.011136
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 1 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.951997
# p-value: 0.031462
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 1 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.836092
# p-value: 0.108961
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          30.51          23.15
#   1   2          8.706          6.635
# -------------------------------------
# Para lag = 1, Rank = 2
# ==========
# ==================================================
#
# Testando para lag = 2 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.249464
# p-value: 0.152576
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 2 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.863356
# p-value: 0.011136
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 2 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.951997
# p-value: 0.031462
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 2 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.836092
# p-value: 0.108961
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          26.25          23.15
#   1   2          8.753          6.635
# -------------------------------------
# Para lag = 2, Rank = 2
# ==========
# ==================================================
#
# Testando para lag = 3 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.249464
# p-value: 0.152576
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 3 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.853636
# p-value: 0.000303
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 3 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.931646
# p-value: 0.001133
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 3 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.830371
# p-value: 0.006253
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          31.26          23.15
#   1   2          5.986          6.635
# -------------------------------------
# Para lag = 3, Rank = 1
# ==========
# ==================================================
#
# Testando para lag = 4 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -1.694338
# p-value: 0.369363
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.680718
# p-value: 0.206590
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.787451
# p-value: 0.364892
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.680750
# p-value: 0.636923
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          15.80          23.15
# -------------------------------------
# Para lag = 4, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 5 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -1.694338
# p-value: 0.369363
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.072821
# p-value: 0.093893
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.179184
# p-value: 0.193127
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.105107
# p-value: 0.401386
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          15.96          23.15
# -------------------------------------
# Para lag = 5, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 6 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -1.694338
# p-value: 0.369363
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.072821
# p-value: 0.093893
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.179184
# p-value: 0.193127
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.105107
# p-value: 0.401386
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          17.67          23.15
# -------------------------------------
# Para lag = 6, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 7 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -1.694338
# p-value: 0.369363
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.072821
# p-value: 0.093893
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.179184
# p-value: 0.193127
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.105107
# p-value: 0.401386
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          20.72          23.15
# -------------------------------------
# Para lag = 7, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 8 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -1.694338
# p-value: 0.369363
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 8 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.072821
# p-value: 0.093893
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 8 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.179184
# p-value: 0.193127
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 8 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.105107
# p-value: 0.401386
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          17.14          23.15
# -------------------------------------
# Para lag = 8, Rank = 0
# ==========

# %% [markdown]
# ## $g_Z$, Inflação e taxa de juros

# %%
testes_coint(series=df[['gZ', 'Inflação', 'Taxa de juros']])
# Out:
# ==================================================
#
# Testando para lag = 1 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.158025
# p-value: 0.070237
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 1 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.245000
# p-value: 0.154410
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 1 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.724079
# p-value: 0.008146
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 1 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -5.162905
# p-value: 0.005495
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   3          82.83          41.08
#   1   3          26.64          23.15
#   2   3          11.69          6.635
# -------------------------------------
# Para lag = 1, Rank = 3
# ==========
# ==================================================
#
# Testando para lag = 2 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.158025
# p-value: 0.070237
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 2 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.245000
# p-value: 0.154410
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 2 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.724079
# p-value: 0.008146
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 2 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -5.162905
# p-value: 0.005495
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   3          52.32          41.08
#   1   3          21.48          23.15
# -------------------------------------
# Para lag = 2, Rank = 1
# ==========
# ==================================================
#
# Testando para lag = 3 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.193907
# p-value: 0.003305
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 3 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.262429
# p-value: 0.011083
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 3 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -5.454438
# p-value: 0.000504
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 3 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -6.667785
# p-value: 0.000007
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   3          58.95          41.08
#   1   3          16.25          23.15
# -------------------------------------
# Para lag = 3, Rank = 1
# ==========
# ==================================================
#
# Testando para lag = 4 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.447336
# p-value: 0.281004
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.454300
# p-value: 0.508243
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.121790
# p-value: 0.366089
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.830096
# p-value: 0.203338
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   3          41.76          41.08
#   1   3          17.05          23.15
# -------------------------------------
# Para lag = 4, Rank = 1
# ==========
# ==================================================
#
# Testando para lag = 5 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.447336
# p-value: 0.281004
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.454300
# p-value: 0.508243
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.121790
# p-value: 0.366089
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.830096
# p-value: 0.203338
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   3          27.88          41.08
# -------------------------------------
# Para lag = 5, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 6 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.447336
# p-value: 0.281004
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.454300
# p-value: 0.508243
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.203209
# p-value: 0.821339
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.830096
# p-value: 0.203338
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   3          26.25          41.08
# -------------------------------------
# Para lag = 6, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 7 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.447336
# p-value: 0.281004
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.454300
# p-value: 0.508243
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.121790
# p-value: 0.366089
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.830096
# p-value: 0.203338
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   3          25.82          41.08
# -------------------------------------
# Para lag = 7, Rank = 0
# ==========

# %% [markdown]
# ## $g_Z$ e Inflação

# %%
testes_coint(series=df[['gZ', 'Inflação']])
# Out:
# ==================================================
#
# Testando para lag = 1 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.226547
# p-value: 0.014248
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 1 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.251846
# p-value: 0.061677
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 1 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.245875
# p-value: 0.169483
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 1 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.210497
# p-value: 0.346168
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          26.61          23.15
#   1   2          11.58          6.635
# -------------------------------------
# Para lag = 1, Rank = 2
# ==========
# ==================================================
#
# Testando para lag = 2 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.226547
# p-value: 0.014248
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 2 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.251846
# p-value: 0.061677
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 2 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.245875
# p-value: 0.169483
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 2 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.210497
# p-value: 0.346168
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          22.11          23.15
# -------------------------------------
# Para lag = 2, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 3 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -3.226547
# p-value: 0.014248
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 3 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.266897
# p-value: 0.002882
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 3 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.190820
# p-value: 0.015499
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# Testando para lag = 3 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -4.324923
# p-value: 0.031189
# CONCLUSION: REJECT null Hypothesis: there IS cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          24.77          23.15
#   1   2          7.071          6.635
# -------------------------------------
# Para lag = 3, Rank = 2
# ==========
# ==================================================
#
# Testando para lag = 4 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.555515
# p-value: 0.081116
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.455406
# p-value: 0.299082
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.411290
# p-value: 0.569151
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 4 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.337586
# p-value: 0.799633
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          14.70          23.15
# -------------------------------------
# Para lag = 4, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 5 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.555515
# p-value: 0.081116
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.455406
# p-value: 0.299082
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.411290
# p-value: 0.569151
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 5 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.337586
# p-value: 0.799633
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          14.48          23.15
# -------------------------------------
# Para lag = 5, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 6 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.555515
# p-value: 0.081116
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.455406
# p-value: 0.299082
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.411290
# p-value: 0.569151
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 6 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.337586
# p-value: 0.799633
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          13.21          23.15
# -------------------------------------
# Para lag = 6, Rank = 0
# ==========
# ==================================================
#
# Testando para lag = 7 e trend = nc
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.555515
# p-value: 0.081116
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = c
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.455406
# p-value: 0.299082
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = ct
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.411290
# p-value: 0.569151
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# Testando para lag = 7 e trend = ctt
# Null Hypothesis: there is NO cointegration
# Alternative Hypothesis: there IS cointegration
# t Statistic: -2.337586
# p-value: 0.799633
# CONCLUSION: FAIL to reject Null Hypothesis: there is NO cointegration
#
#
# TESTE DE JOHANSEN
#
# Johansen cointegration test using trace test statistic with 1% significance level
# =====================================
# r_0 r_1 test statistic critical value
# -------------------------------------
#   0   2          13.35          23.15
# -------------------------------------
# Para lag = 7, Rank = 0
# ==========

# %% [markdown]
# # VECM

# %% [markdown]
# VECM: $g_Z$, Inflação e Juros exógeno

# %% [markdown]
# ## Ordem do modelo

# %%
from statsmodels.tsa.vector_ar.vecm import select_order

#det = 'cili'
#det = 'coli'
#det = 'colo'
#det = 'cilo'
#det = 'ci'
#det = 'nc'
det= 'co'

order_vec = select_order(
    df[[
        #"Inflação", 
        "Taxa Própria", 
        "gZ"
    ]], 
    #exog=df[["Taxa de juros"]],
    maxlags=15, deterministic=det)

with open('./tabs/VECM_lag_order.tex','w') as fh:
    fh.write(order_vec.summary().as_latex_tabular(tile = "Selação ordem do VECM"))

order_vec.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Estimação

# %%
model = VECM(
    endog = df[[
        #"Inflação", 
        "Taxa Própria", 
        "gZ"
    ]], 
    #exog=df[["Taxa de juros"]],
    #k_ar_diff=0,
    #k_ar_diff=1,
    #k_ar_diff=2,
    #k_ar_diff=3,
    #k_ar_diff=4,
    #k_ar_diff=5,
    #k_ar_diff=6,
    #k_ar_diff=7,
    k_ar_diff=8,
    deterministic=det, 
)
results = model.fit()

with open('./tabs/VECM_ajuste.tex','w') as fh:
    fh.write(results.summary().as_latex())

print(results.summary())

print(60*"=")
print("\nPÓS ESTIMAÇÂO\n")
residuals = analise_residuos(results=results)
print(60*"=")
# Out:
# Det. terms outside the coint. relation & lagged endog. parameters for equation Taxa Própria
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0004      0.004      0.086      0.931      -0.008       0.008
# L1.Taxa Própria     0.8346      0.100      8.319      0.000       0.638       1.031
# L1.gZ              -0.0240      0.032     -0.755      0.450      -0.086       0.038
# L2.Taxa Própria    -0.1506      0.134     -1.123      0.261      -0.414       0.112
# L2.gZ              -0.0072      0.034     -0.212      0.832      -0.073       0.059
# L3.Taxa Própria    -0.1628      0.140     -1.162      0.245      -0.438       0.112
# L3.gZ              -0.0364      0.033     -1.086      0.278      -0.102       0.029
# L4.Taxa Própria    -0.0070      0.142     -0.049      0.961      -0.285       0.271
# L4.gZ              -0.0088      0.035     -0.251      0.802      -0.077       0.060
# L5.Taxa Própria    -0.1250      0.142     -0.883      0.377      -0.402       0.153
# L5.gZ              -0.0322      0.029     -1.101      0.271      -0.089       0.025
# L6.Taxa Própria    -0.0239      0.142     -0.168      0.866      -0.302       0.254
# L6.gZ              -0.0191      0.029     -0.650      0.516      -0.077       0.038
# L7.Taxa Própria     0.1778      0.137      1.299      0.194      -0.090       0.446
# L7.gZ              -0.0340      0.028     -1.214      0.225      -0.089       0.021
# L8.Taxa Própria    -0.1883      0.100     -1.881      0.060      -0.385       0.008
# L8.gZ              -0.0270      0.028     -0.954      0.340      -0.083       0.028
#  Det. terms outside the coint. relation & lagged endog. parameters for equation gZ
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0412      0.014      3.019      0.003       0.014       0.068
# L1.Taxa Própria     0.4807      0.332      1.450      0.147      -0.169       1.131
# L1.gZ               0.4026      0.105      3.833      0.000       0.197       0.609
# L2.Taxa Própria    -1.2060      0.443     -2.720      0.007      -2.075      -0.337
# L2.gZ               0.1373      0.112      1.228      0.219      -0.082       0.356
# L3.Taxa Própria     0.8664      0.463      1.870      0.061      -0.042       1.775
# L3.gZ               0.3702      0.111      3.344      0.001       0.153       0.587
# L4.Taxa Própria    -0.1822      0.468     -0.389      0.697      -1.100       0.736
# L4.gZ              -0.3313      0.115     -2.870      0.004      -0.558      -0.105
# L5.Taxa Própria     0.3204      0.468      0.685      0.494      -0.597       1.238
# L5.gZ               0.2060      0.097      2.134      0.033       0.017       0.395
# L6.Taxa Própria     0.0813      0.469      0.173      0.862      -0.838       1.000
# L6.gZ               0.0980      0.097      1.010      0.312      -0.092       0.288
# L7.Taxa Própria    -0.2079      0.452     -0.460      0.646      -1.095       0.679
# L7.gZ               0.1174      0.093      1.268      0.205      -0.064       0.299
# L8.Taxa Própria    -0.0455      0.331     -0.138      0.891      -0.694       0.603
# L8.gZ              -0.0053      0.094     -0.056      0.955      -0.189       0.178
#             Loading coefficients (alpha) for equation Taxa Própria
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0069      0.021     -0.329      0.742      -0.048       0.034
#                  Loading coefficients (alpha) for equation gZ
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.2429      0.070     -3.491      0.000      -0.379      -0.107
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2         1.1623      0.192      6.052      0.000       0.786       1.539
# ==============================================================================
# ============================================================
#
# PÓS ESTIMAÇÂO
# AUTOCORRELAÇÃO RESIDUAL: PORTMANTEAU
#
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 15 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          34.19          38.89   0.130 26
# ----------------------------------------
#
# AUTOCORRELAÇÃO RESIDUAL: PORTMANTEAU AJUSTADO
#
# Adjusted Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 15 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          38.35          38.89   0.056 26
# ----------------------------------------
#
# LJUNGBOX
#
# H0: autocorrelations up to lag k equal zero
# H1: autocorrelations up to lag k not zero
# Box-Pierce:  False
# Testing for  TAXA PRÓPRIA . Considering a significance level of 5.0 %
# p-value = 0.9343479250493243
# Reject H0 on lag  1 ?  False
#
# p-value = 0.8841205913085268
# Reject H0 on lag  2 ?  False
#
# p-value = 0.9589889479561519
# Reject H0 on lag  3 ?  False
#
# p-value = 0.9527038205309691
# Reject H0 on lag  4 ?  False
#
# p-value = 0.9492898237934896
# Reject H0 on lag  5 ?  False
#
# p-value = 0.9218082666425947
# Reject H0 on lag  6 ?  False
#
# p-value = 0.9529291179012858
# Reject H0 on lag  7 ?  False
#
# p-value = 0.9700985707278815
# Reject H0 on lag  8 ?  False
#
# p-value = 0.9851043292301833
# Reject H0 on lag  9 ?  False
#
# p-value = 0.9540940218382568
# Reject H0 on lag  10 ?  False
#
# p-value = 0.9582199861282531
# Reject H0 on lag  11 ?  False
#
# p-value = 0.94917867958939
# Reject H0 on lag  12 ?  False
#
#
#
# Testing for  GZ . Considering a significance level of 5.0 %
# p-value = 0.017948820439122076
# Reject H0 on lag  1 ?  True
#
# p-value = 0.21635883104136394
# Reject H0 on lag  2 ?  False
#
# p-value = 0.2254107132707351
# Reject H0 on lag  3 ?  False
#
# p-value = 0.3756569190665338
# Reject H0 on lag  4 ?  False
#
# p-value = 0.39437210432769904
# Reject H0 on lag  5 ?  False
#
# p-value = 0.561076794642784
# Reject H0 on lag  6 ?  False
#
# p-value = 0.60306503496712
# Reject H0 on lag  7 ?  False
#
# p-value = 2.3769540178768342
# Reject H0 on lag  8 ?  False
#
# p-value = 2.9115822283645163
# Reject H0 on lag  9 ?  False
#
# p-value = 3.432378347399983
# Reject H0 on lag  10 ?  False
#
# p-value = 9.240101128138841
# Reject H0 on lag  11 ?  False
#
# p-value = 9.269524025220301
# Reject H0 on lag  12 ?  False
#
#
#
#
# BOXPIERCE
#
# H0: autocorrelations up to lag k equal zero
# H1: autocorrelations up to lag k not zero
# Box-Pierce:  True
# Testing for  TAXA PRÓPRIA . Considering a significance level of 5.0 %
# p-value = 0.9353089593517432
# Reject H0 on lag  1 ?  False
#
# p-value = 0.888330191508709
# Reject H0 on lag  2 ?  False
#
# p-value = 0.9613141097345955
# Reject H0 on lag  3 ?  False
#
# p-value = 0.9568672728829144
# Reject H0 on lag  4 ?  False
#
# p-value = 0.9552552670104836
# Reject H0 on lag  5 ?  False
#
# p-value = 0.9332448486086913
# Reject H0 on lag  6 ?  False
#
# p-value = 0.9611115797965938
# Reject H0 on lag  7 ?  False
#
# p-value = 0.9761818974312308
# Reject H0 on lag  8 ?  False
#
# p-value = 0.988544360154189
# Reject H0 on lag  9 ?  False
#
# p-value = 0.9669418408261437
# Reject H0 on lag  10 ?  False
#
# p-value = 0.9712388340706547
# Reject H0 on lag  11 ?  False
#
# p-value = 0.9666135666078677
# Reject H0 on lag  12 ?  False
#
#
#
# Testing for  GZ . Considering a significance level of 5.0 %
# p-value = 0.017948820439122076
# Reject H0 on lag  1 ?  True
#
# p-value = 0.21635883104136394
# Reject H0 on lag  2 ?  False
#
# p-value = 0.2254107132707351
# Reject H0 on lag  3 ?  False
#
# p-value = 0.3756569190665338
# Reject H0 on lag  4 ?  False
#
# p-value = 0.39437210432769904
# Reject H0 on lag  5 ?  False
#
# p-value = 0.561076794642784
# Reject H0 on lag  6 ?  False
#
# p-value = 0.60306503496712
# Reject H0 on lag  7 ?  False
#
# p-value = 2.3769540178768342
# Reject H0 on lag  8 ?  False
#
# p-value = 2.9115822283645163
# Reject H0 on lag  9 ?  False
#
# p-value = 3.432378347399983
# Reject H0 on lag  10 ?  False
#
# p-value = 9.240101128138841
# Reject H0 on lag  11 ?  False
#
# p-value = 9.269524025220301
# Reject H0 on lag  12 ?  False
#
#
#
#
# NORMALIDADE
#
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          321.2          9.488   0.000  4
# ----------------------------------------
#
# HOMOCEDASTICIDADE
#
# H0: Residuals are homoscedastic
# H1: Residuals are heteroskedastic
# Testing for  TAXA PRÓPRIA
# LM p-value:  0.043243973153863434
# Reject H0?  True
# F p-value:  0.04299633445009071
# Reject H0?  True
#
#
# Testing for  GZ
# LM p-value:  0.13391195625156196
# Reject H0?  False
# F p-value:  0.13663752421329217
# Reject H0?  False
#
#
# ============================================================

# %% [markdown]
# ## Função impulso resposta ortogonalizada

# %%
p = results.irf(20).plot(orth=True)
p.suptitle("")
sns.despine()
plt.show()
p.savefig("./figs/Impulso_VECMOrth.png", dpi = 300, bbox_inches = 'tight',
    pad_inches = 0.2, transparent = True,)

# %% [markdown]
# ## Função impulso resposta não-ortogonalizada

# %%
p = results.irf(20).plot(orth=False)
p.suptitle("")
sns.despine()
plt.show()
p.savefig("./figs/Impulso_VECM.png", dpi = 300, bbox_inches = 'tight',
    pad_inches = 0.2, transparent = True,)

# %% [markdown]
# ## Teste de causalidade de granger

# %%
series = residuals.columns
print(results.test_granger_causality(causing=series[0], caused=series[1]).summary())
print(results.test_inst_causality(causing=series[0]).summary())
# Out:
# Granger causality F-test. H_0: Taxa Própria does not Granger-cause gZ. Conclusion: reject H_0 at 5% significance level.
# ==============================================
# Test statistic Critical value p-value    df
# ----------------------------------------------
#          2.273          1.940   0.020 (9, 158)
# ----------------------------------------------
# Instantaneous causality Wald-test. H_0: Taxa Própria does not instantaneously cause gZ. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          6.122          3.841   0.013  1
# ----------------------------------------

# %% [markdown]
# ## Inspeção gráfica dos resíduos

# %%
series = results.names
for serie in series:
    sns.scatterplot(x = residuals[serie], y = residuals[serie]**2)
    plt.ylabel(f"{serie}^2")
    sns.despine()
    plt.show()
    
    sns.scatterplot(
    y = residuals[serie], 
    x = residuals[serie].shift(-1), 
    color = 'darkred' 
    )
    sns.despine()
    plt.xlabel(f"{serie}(-1)")
    plt.show()

# %%
sns.set_context('paper')
g = sns.PairGrid(residuals, diag_sharey=False)
g.map_lower(sns.kdeplot, color = 'darkred')
g.map_upper(sns.scatterplot, color = 'darkred')
g.map_diag(sns.kdeplot, lw=3, color = 'darkred')
plt.show()
g.savefig("./figs/Residuos_4VECM.png", dpi = 300, bbox_inches = 'tight',
    pad_inches = 0.2, transparent = True,)

# %%
series = results.names
sns.set_context('talk')
ax = sns.jointplot(
    x = series[0], 
    y = series[1], 
    data = residuals, color = 'darkred', kind="reg", 
)
plt.show()

# %% [markdown]
# ## FEVD

# %%
# %%R -o fevd_gz
# library(tsDyn)
# library(readr)
# df <- read.csv("./Dados_yeojohnson.csv", encoding="UTF-8")
# df <- df[,c(4:7)]
# names(df) <- c("Juros", "Infla", "TaxaP", "gZ")
# df <- na.omit(df[,c("Juros", "Infla","TaxaP", "gZ")])
# df <- ts(data = df, start = c(1992,03), frequency = 4)
# model <- tsDyn::VECM(data = df[,c("TaxaP","gZ")], lag = 5, r = 1, estim = "ML", LRinclude="const", include="none")
# fevd_gz = data.frame(tsDyn::fevd(model, 20)$gZ)
# Out:
# R[write to console]: Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
#
# R[write to console]: Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# R[write to console]: Registered S3 methods overwritten by 'forecast':
#   method             from
#   fitted.fracdiff    fracdiff
#   residuals.fracdiff fracdiff

# %%
# %%R -o fevd_tx
# fevd_tx = data.frame(tsDyn::fevd(model, 20)$TaxaP)

# %%
sns.set_context('talk')
fig, ax = plt.subplots(2,1, figsize = (16,10))

fevd_gz.plot(
    ax=ax[0], 
    title = "Decomposição da variância para $g_Z$", 
    color = ("black", "lightgray"), 
    kind = 'bar', stacked = True
)
ax[0].set_xlabel('Trimestres')
ax[0].set_ylabel('Porcentagem')
ax[0].axhline(y=0.5, color = 'red', ls = '--')
ax[0].legend(loc='center left', bbox_to_anchor=(1, 0.5), labels = ("50%", "Inflação", "gZ"))
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=0)


fevd_tx.plot(
    ax=ax[1], 
    title = "Decomposição da variância para Inflação", 
    color = ("black", "lightgray"), 
    kind = 'bar', stacked = True,
)
ax[1].axhline(y=0.5, color = 'red', ls = '--')
ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5), labels = ("50%", "Inflação", "gZ"))
ax[1].set_xlabel('Trimestres')
ax[1].set_ylabel('Porcentagem')
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=0)

sns.despine()
plt.tight_layout()
plt.show()
fig.savefig("./figs/FEVD_VECM.png", dpi = 300, bbox_inches = 'tight',
    pad_inches = 0.2, transparent = True,)

# %% [markdown]
# # VAR
#
# **Dúvida:** Variável exógena do VAR deve ser estacionária também?

# %% [markdown]
# ## Ordem do modelo

# %%
model = VAR(
    df[["d_Taxa Própria", 'd_gZ']],
)
print(model.select_order(maxlags=15, trend='ct').summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -12.80      -12.69   2.773e-06      -12.75
# 1       -13.48     -13.27*   1.394e-06      -13.40
# 2       -13.56      -13.24   1.293e-06      -13.43
# 3       -13.55      -13.12   1.311e-06      -13.37
# 4      -13.71*      -13.18  1.110e-06*     -13.50*
# 5       -13.67      -13.02   1.161e-06      -13.41
# 6       -13.59      -12.84   1.253e-06      -13.29
# 7       -13.54      -12.68   1.321e-06      -13.20
# 8       -13.53      -12.56   1.341e-06      -13.14
# 9       -13.50      -12.42   1.394e-06      -13.06
# 10      -13.44      -12.26   1.477e-06      -12.96
# 11      -13.41      -12.12   1.532e-06      -12.89
# 12      -13.47      -12.07   1.455e-06      -12.90
# 13      -13.43      -11.93   1.521e-06      -12.82
# 14      -13.35      -11.74   1.661e-06      -12.70
# 15      -13.43      -11.71   1.559e-06      -12.73
# --------------------------------------------------

# %% [markdown]
# Adotando o BIC como critério de seleção dada a parciomônia, estima-se uma VAR de ordem 5.

# %% [markdown]
# ## Estimação

# %%
results = model.fit(maxlags=5)
print(results.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           ter, 10, dez, 2019
# Time:                     19:39:19
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -13.2525
# Nobs:                     105.000    HQIC:                  -13.5832
# Log likelihood:           448.972    FPE:                1.00855e-06
# AIC:                     -13.8085    Det(Omega_mle):     8.26338e-07
# --------------------------------------------------------------------
# Results for equation d_Taxa Própria
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.000585         0.001619           -0.361           0.718
# L1.d_Taxa Própria         0.859154         0.104672            8.208           0.000
# L1.d_gZ                  -0.024322         0.030582           -0.795           0.426
# L2.d_Taxa Própria        -0.160038         0.140820           -1.136           0.256
# L2.d_gZ                  -0.003572         0.026273           -0.136           0.892
# L3.d_Taxa Própria        -0.139073         0.148827           -0.934           0.350
# L3.d_gZ                  -0.028870         0.025120           -1.149           0.250
# L4.d_Taxa Própria        -0.014146         0.146056           -0.097           0.923
# L4.d_gZ                  -0.004148         0.024666           -0.168           0.866
# L5.d_Taxa Própria        -0.063932         0.107015           -0.597           0.550
# L5.d_gZ                  -0.045516         0.027622           -1.648           0.099
# ====================================================================================
#
# Results for equation d_gZ
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.002005         0.005559           -0.361           0.718
# L1.d_Taxa Própria         0.396669         0.359340            1.104           0.270
# L1.d_gZ                   0.257923         0.104987            2.457           0.014
# L2.d_Taxa Própria        -1.441313         0.483438           -2.981           0.003
# L2.d_gZ                  -0.082698         0.090195           -0.917           0.359
# L3.d_Taxa Própria         0.923889         0.510926            1.808           0.071
# L3.d_gZ                   0.158362         0.086238            1.836           0.066
# L4.d_Taxa Própria        -0.253720         0.501410           -0.506           0.613
# L4.d_gZ                  -0.460137         0.084678           -5.434           0.000
# L5.d_Taxa Própria         0.173444         0.367384            0.472           0.637
# L5.d_gZ                   0.116528         0.094828            1.229           0.219
# ====================================================================================
#
# Correlation matrix of residuals
#                   d_Taxa Própria      d_gZ
# d_Taxa Própria          1.000000 -0.222031
# d_gZ                   -0.222031  1.000000

# %% [markdown]
# ## Pós-estimação

# %% [markdown]
# ### Autocorrelação dos resíduos
#
# **OBS:** série consigo mesma na diagonal principal.

# %%
results.plot_acorr(nlags = 20)
sns.despine()
plt.show()

# %% [markdown]
# **Conclusão:** Pela inspeção gráfica, o modelo não apresenta autocorrelação serial dos resíduos.

# %% [markdown]
# ### Estabilidade

# %%
print("Estável:", results.is_stable(verbose=True))
# Out:
# Eigenvalues of VAR(1) rep
# 0.8372022789787056
# 0.8372022789787056
# 0.7862642628578941
# 0.7862642628578941
# 0.8383154512476891
# 0.8383154512476891
# 0.44711279290583306
# 0.44711279290583306
# 0.2661637978598548
# 0.027434215940121433
# Estável: True

# %% [markdown]
# **OBS:** Apesar de estar escrito VAR(1), os resultados acima correspondem ao VAR(p)

# %% [markdown]
# ## Inspeção dos resíduos

# %%
residuals = analise_residuos(results=results)
# Out:
# AUTOCORRELAÇÃO RESIDUAL: PORTMANTEAU
#
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 15 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          44.88          55.76   0.275 40
# ----------------------------------------
#
# AUTOCORRELAÇÃO RESIDUAL: PORTMANTEAU AJUSTADO
#
# Adjusted Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 15 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          49.63          55.76   0.141 40
# ----------------------------------------
#
# LJUNGBOX
#
# H0: autocorrelations up to lag k equal zero
# H1: autocorrelations up to lag k not zero
# Box-Pierce:  False
# Testing for  D_TAXA PRÓPRIA . Considering a significance level of 5.0 %
# p-value = 0.9665183667827709
# Reject H0 on lag  1 ?  False
#
# p-value = 0.9761494844712023
# Reject H0 on lag  2 ?  False
#
# p-value = 0.9704032516960618
# Reject H0 on lag  3 ?  False
#
# p-value = 0.9349918902432011
# Reject H0 on lag  4 ?  False
#
# p-value = 0.9253147479270282
# Reject H0 on lag  5 ?  False
#
# p-value = 0.903944892118859
# Reject H0 on lag  6 ?  False
#
# p-value = 0.9109099020947118
# Reject H0 on lag  7 ?  False
#
# p-value = 0.8782606624393098
# Reject H0 on lag  8 ?  False
#
# p-value = 0.893651246705403
# Reject H0 on lag  9 ?  False
#
# p-value = 0.8450820742506846
# Reject H0 on lag  10 ?  False
#
# p-value = 0.7639627646886429
# Reject H0 on lag  11 ?  False
#
# p-value = 0.6953583050525205
# Reject H0 on lag  12 ?  False
#
#
#
# Testing for  D_GZ . Considering a significance level of 5.0 %
# p-value = 0.0074831780413218965
# Reject H0 on lag  1 ?  True
#
# p-value = 0.045188013961194026
# Reject H0 on lag  2 ?  True
#
# p-value = 0.11448936053797446
# Reject H0 on lag  3 ?  False
#
# p-value = 0.15995184265088877
# Reject H0 on lag  4 ?  False
#
# p-value = 0.820421096852745
# Reject H0 on lag  5 ?  False
#
# p-value = 0.9051090634758684
# Reject H0 on lag  6 ?  False
#
# p-value = 4.276439787004153
# Reject H0 on lag  7 ?  False
#
# p-value = 6.5579959551345395
# Reject H0 on lag  8 ?  False
#
# p-value = 7.002396338465008
# Reject H0 on lag  9 ?  False
#
# p-value = 8.426328240551952
# Reject H0 on lag  10 ?  False
#
# p-value = 12.901380752909626
# Reject H0 on lag  11 ?  False
#
# p-value = 13.236647361716622
# Reject H0 on lag  12 ?  False
#
#
#
#
# BOXPIERCE
#
# H0: autocorrelations up to lag k equal zero
# H1: autocorrelations up to lag k not zero
# Box-Pierce:  True
# Testing for  D_TAXA PRÓPRIA . Considering a significance level of 5.0 %
# p-value = 0.9669908006747537
# Reject H0 on lag  1 ?  False
#
# p-value = 0.9770227277380339
# Reject H0 on lag  2 ?  False
#
# p-value = 0.9722807471678809
# Reject H0 on lag  3 ?  False
#
# p-value = 0.940847036861085
# Reject H0 on lag  4 ?  False
#
# p-value = 0.933869865150902
# Reject H0 on lag  5 ?  False
#
# p-value = 0.9172636044675703
# Reject H0 on lag  6 ?  False
#
# p-value = 0.92551535689837
# Reject H0 on lag  7 ?  False
#
# p-value = 0.9010555521205647
# Reject H0 on lag  8 ?  False
#
# p-value = 0.9163413099334643
# Reject H0 on lag  9 ?  False
#
# p-value = 0.8812622681607073
# Reject H0 on lag  10 ?  False
#
# p-value = 0.8215418244831031
# Reject H0 on lag  11 ?  False
#
# p-value = 0.7720923103538413
# Reject H0 on lag  12 ?  False
#
#
#
# Testing for  D_GZ . Considering a significance level of 5.0 %
# p-value = 0.0074831780413218965
# Reject H0 on lag  1 ?  True
#
# p-value = 0.045188013961194026
# Reject H0 on lag  2 ?  True
#
# p-value = 0.11448936053797446
# Reject H0 on lag  3 ?  False
#
# p-value = 0.15995184265088877
# Reject H0 on lag  4 ?  False
#
# p-value = 0.820421096852745
# Reject H0 on lag  5 ?  False
#
# p-value = 0.9051090634758684
# Reject H0 on lag  6 ?  False
#
# p-value = 4.276439787004153
# Reject H0 on lag  7 ?  False
#
# p-value = 6.5579959551345395
# Reject H0 on lag  8 ?  False
#
# p-value = 7.002396338465008
# Reject H0 on lag  9 ?  False
#
# p-value = 8.426328240551952
# Reject H0 on lag  10 ?  False
#
# p-value = 12.901380752909626
# Reject H0 on lag  11 ?  False
#
# p-value = 13.236647361716622
# Reject H0 on lag  12 ?  False
#
#
#
#
# NORMALIDADE
#
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          624.9          9.488   0.000  4
# ----------------------------------------
#
# HOMOCEDASTICIDADE
#
# H0: Residuals are homoscedastic
# H1: Residuals are heteroskedastic
# Testing for  D_TAXA PRÓPRIA
# LM p-value:  0.505859417162297
# Reject H0?  False
# F p-value:  0.5105643172989753
# Reject H0?  False
#
#
# Testing for  D_GZ
# LM p-value:  0.15336693908099125
# Reject H0?  False
# F p-value:  0.15634419720720316
# Reject H0?  False

# %% [markdown]
# ## Inspeção gráfica dos resíduos

# %%
series = results.names
sns.set_context('talk')
ax = sns.jointplot(
    x = series[0], 
    y = series[1], 
    data = residuals, color = 'darkred', kind="reg", 
)
plt.show()

# %%
sns.set_context('paper')
g = sns.PairGrid(residuals, diag_sharey=False)
g.map_lower(sns.kdeplot, color = 'darkred')
g.map_upper(sns.scatterplot, color = 'darkred')
g.map_diag(sns.kdeplot, lw=3, color = 'darkred')
plt.show()
g.savefig("./figs/Residuos_4.png", dpi=300)

# %%
series = results.names
for serie in series:
    sns.scatterplot(x = residuals[serie], y = residuals[serie]**2)
    sns.despine()
    plt.show()
    
    sns.scatterplot(
    y = residuals[serie], 
    x = residuals[serie].shift(-1), 
    color = 'darkred' 
    )
    sns.despine()
    plt.xlabel(f"{serie}(-1)")
    plt.show()

# %%
plot_lags(results=results)

# %% [markdown]
# ## Função resposta ao impulso ortogonalizada

# %%
p = results.irf(20).plot(orth=True)
p.suptitle("")
sns.despine()
plt.show()
p.savefig("./figs/Impulso_Orth.png", dpi = 300)

# %% [markdown]
# ## Função resposta ao impulso não-ortogonalizada

# %%
p = results.irf(20).plot(orth=False)
p.suptitle("")
sns.despine()
plt.show()
p.savefig("./figs/Impulso.png", dpi = 300)

# %% [markdown]
# ## Efeito cumulativo

# %%
p = results.irf(20).plot_cum_effects(orth=True)
sns.despine()
plt.show()
p.savefig("./figs/Impulso_Cum.png", dpi = 300)

# %% [markdown]
# ## Decomposição da variância

# %%
p = results.fevd(20).plot()
sns.despine()
plt.show()
p.savefig("./figs/DecompVar.png", dpi = 300)
