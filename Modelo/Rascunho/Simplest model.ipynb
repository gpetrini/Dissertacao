# %% [markdown]
# Time checking:

# %%
from datetime import datetime
t1 = datetime.now()

# %% [markdown]
# # Introduction
#
# Jupyter notebook for the simplest model scratch. By convention, all exogenous variables are presented with a overline line (*e.g.* $\overline a$) and the parameters are represented by greek letters (*e.g.* $\alpha$). The code in this document is executable and is strongly recommend to do the follow to ensure that the output is corrected and updated:
#
# Run time > Restart and run all...

# %% [markdown]
# ## Variables list
#
# - $C$ Consumption
# - $CG$: Capital gains
# - $FT$: Total profits
# - $FD$: Distributed profits
# - $FU$: Retained profits
# - $g_i$: Growth rate of variable $i$
# - $g^e_i$: Expected growth rate of variable $i$
# - $h$: Marginal propensity to invest
# - $I$: Total investment
# - $I_f$: Non-residential investment
# - $I_h$: Residential investment
# - $K_f$: Non-residential fixed capital
# - $K_h$: Residential capital
# - $K_{HD}$: Demand for houses
# - $K_{HU}$: Unsold houses
# - $K_H$: Houses supply
# - $L$: Loans
# - $morp$: Mortgages repayments
# - $M$: Money deposits
# - $MO$: Mortgages
# - $p_h$ Housing prices
# - $r_l$: Interest rates on Loans
# - $r_m$: Interest rates on money deposits
# - $r_H$: Housing own interest rates
# - $S_i$: Sector $i$ savings
# - $u$: Capacity utilization ratio
# - $v$: Capacity-Output ratio
# - $V_i$: Net financial Wealth of sector $i$
# - $W$ Total Wage bill
# - $Y$: GDP
# - $Y_K$: Capacity
# - $YD$: Household disposable income
# - $Z$: Autonomous expenditures

# %% [markdown]
# ## Parameters list
#
# - $\alpha$: Propensity to consume out of wages
# - $\beta$: Expectation adjustment parameter
# - $\gamma_F$: % of distributed profits
# - $\gamma_u$: Adjustment parameter for the marginal propensity to invest

# %% [markdown]
# ## Exogenous variables
#
# - $gz$: Autonomous grouth rate
# - $\omega$: Wage share
# - $rm$: Interest rates on money deposits
# - $spread_l$: Spread for loans
# - $spread_{mo}$: Spread for mortgages
# - $un$: Normal capacity utilization ratio
# - $v$: Capitl-Output ratio

# %% [markdown]
# # Assumptions

# %% [markdown]
# ## General
#
# - No inflation
# - Two kinds of capital: Residential and non-Residential
# - No depeciation
# - Non-residential investment is induced

# %% [markdown]
# ## Households
#
# - All savings are accumulated in bank deposits
# - Households do not have access to Loans

# %% [markdown]
# ## Firms

# %% [markdown]
# ## Banks
#
# - Have any net worth

# %% [markdown]
# # Matrix

# %% [markdown]
# ## Balance sheet
#
# |                	| Households 	|  Firms 	| Banks 	| $\sum$ 	|
# |----------------	|:----------:	|:------:	|:-----:	|:------:	|
# | Money Deposits 	|    $+M$    	|        	|  $-M$ 	|   $0$  	|
# | Loans          	|            	|  $-L$  	|  $+L$ 	|   $0$  	|
# | Mortgages          	| $-MO$           	|   	|  $+MO$ 	|   $0$  	|
# | Capital        	|    |  $K_f$ 	|       	|   $K_f$  	|
# | Houses 	|    $K_{HD}$    	| |  	|   $K_H$  	|
# | Net Worth      	|   $V_h$   	| $V_f$ 	| $V_b$      	|  $K$  	|

# %% [markdown]
# ## Transactions and flow  of funds matrix
#
# |                            	| Households             	| Households  	| Firms                  	| Firms       	| Banks                  	|  Sum    	|
# |----------------------------	|------------------------	|-------------	|------------------------	|-------------	|------------------------	|-------------	|--------	|
# |                            	| Current                	| Capital     	| Current                	| Capital     	| Current                	| $\sum$ 	|
# | Consumption                	| $-C$                   	|             	| $+C$                   	|             	|                        	|             	$0$    	|
# | Investment                 	|                  	|             	| $+I_f$                    	| $-I_f$      	|                        	|             	$0$    	|
# | Residential Investment                 	|                  	| $-I_h$            	| $+I_h$                    	|       	|                        	|             	 $0$    	|
# | **[Production]**               	|                        	|             	| **[$Y$]**                  	|             	|                        	|             	$[Y]$    	|
# | Wages                      	| $+W$                    	|             	| $-W$                   	|             	|                        	|             	$0$    	|
# | Profits                      	| $+FD$                    	|             	| $-FT$                   	| $+FU$	|                        	|             	$0$    	|
# | Interests on loans         	|                        	|             	| $-r_{l-1}\cdot L_{-1}$ 	|             	| $+r_{l-1}\cdot L_{-1}$ 	|             	$0$    	|
# | Interests on Bank deposits 	| $+r_{m-1}\cdot M_{-1}$ 	|             	|                        	|             	| $-r_{m-1}\cdot M_{-1}$ 	|             	$0$    	|
# | Interests on Mortgage 	| $-r_{mo-1}\cdot MO_{-1}$ 	|             	|                        	|             	| $+r_{mo-1}\cdot MO_{-1}$  	|             	$0$    	|
# | **Subtotal** 	| $+S_h$ 	| $-I_h$|                        	|  $+NFW_f$           	|  +$NFW_b$	|             	 $0$    	|
# | Change in Loans            	|                        	|             	|                        	| $+\Delta L$ 	|                        	 $-\Delta L$ 	|$0$    	|
# | Change in Bank deposits    	| $-\Delta M$                       	|  	|                        	|             	|                        	$+\Delta M$ 	| $0$    	|
# | Change in Mortgages    	|                        	| $+\Delta MO$ 	|                        	|             	|                        	$-\Delta MO$ 	| $0$    	|
# | Sum    	| $0$                        	| $0$ 	| $0$| $0$| $0$| $0$|

# %% [markdown]
# # Equations

# %% [markdown]
# ## General Equations
#
# $$
# Y = C + I
# \tag{1}
# $$
#
# $$
# I = I_f + I_h
# \tag{2}
# $$
#
# $$
# \omega = \overline \omega
# \tag{3}
# $$
#
# $$
# W = \omega \cdot  Y
# \tag{4}
# $$
#
# $$
# Y_K = \frac{K_f}{\overline v}
# \tag{5}
# $$
#
# $$
# u = \frac{Y}{Y_K}
# \tag{6}
# $$
#
# $$
# g_k = \frac{h\cdot u}{v}
# \tag{7}
# $$
#
# $$
# Z = I_h
# \tag{8}
# $$
#
# $$
# K = K_f + K_{HD}
# \tag{9}
# $$

# %% [markdown]
# ## Households
#
# $$
# YD = W + FD + \overline r_{m-1}\cdot M_{-1} - \overline r_{mo-1}\cdot MO
# \tag{10}
# $$
#
# $$
# S_h = YD - C = \Delta M
# \tag{11}
# $$
#
# $$
# \Delta MO = I_h
# \tag{12}
# $$
#
# $$
# C = \alpha\cdot W
# \tag{13}
# $$
#
# $$
# V_h = M + K_H - MO
# \tag{14}
# $$
#
# $$
# NFW_h = S_h - I_h
# $$

# %% [markdown]
# ## Firms
#
# $$
# \Delta L = I_f - FU
# \tag{15}
# $$
#
# $$
# FT = Y - W = FU+ FD
# \tag{16}
# $$
#
# $$
# FU = \gamma_F\cdot (FT - r_{L_{-1}}\cdot L_{-1})
# \tag{17}
# $$
#
#
# $$
# FD = (1 - \gamma_F)\cdot (FT - r_{L_{-1}}\cdot L_{-1})
# \tag{18}
# $$
#
# $$
# I_f = h\cdot Y
# \tag{19}
# $$
#
# $$
# \Delta K_f = I_f
# \tag{20}
# $$
#
# $$
# \Delta h =
# h_{-1}\cdot \gamma_u\cdot (u - \overline u_n)
# \tag{21}
# $$
#
# $$
# V_f = K_f  - L
# \tag{22}
# $$
#
# $$
# NFW_f = FU - I_f
# \tag{23}
# $$

# %% [markdown]
# ## Banks
#
# $$
# \Delta M = \Delta L + \Delta MO
# \tag{24}
# $$
#
# $$
# NFW_b = rl_{-1}\cdot L_{-1} + rmo_{-1}\cdot MO_{-1} - rm_{-1}\cdot M_{-1}
# \tag{25}
# $$
#
# $$
# r_l = r_m + spread_l (=0)
# \tag{26}
# $$
#
# $$
# r_{mo} = r_m + spread_{mo} (=0)
# \tag{27}
# $$
#
# $$
# V_b = L + MO - M
# \tag{28}
# $$

# %% [markdown]
# ## Residential Investment
#
#
# $$
# K_{HS} = K_{HD}
# \tag{29}
# $$
#
# $$
# I_h^S = I_h
# $$
#
# $$
# \Delta K_{HD} = I_h
# \tag{30}
# $$
#
# $$
# I_h = (1+g_{Ih_{t-1}})\cdot I_{h_{t-1}}
# \tag{31}
# $$
#
# $$
# g_{I_h} = \overline g_{I_h}
# \tag{32}
# $$
#
# $$
# \tau = \frac{K_f}{K}
# $$

# %% [markdown]
# # Simulation setup

# %% [markdown]
# ## Installing required packages

# %%
# !pip install pysolve3
# Out:
# Requirement already satisfied: pysolve3 in /usr/local/lib/python3.6/dist-packages (0.1.3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pysolve3) (0.22.0)
# Requirement already satisfied: sympy==1.1 in /usr/local/lib/python3.6/dist-packages (from pysolve3) (1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pysolve3) (1.14.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->pysolve3) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->pysolve3) (2.5.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy==1.1->pysolve3) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas->pysolve3) (1.11.0)

# %% [markdown]
# ## Loading libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
plt.style.use('seaborn-white')
import seaborn as sns
from pysolve3.utils import ShockModel, SFCTable, SolveSFC
from pysolve3.model import Model
import sympy as sp
#from sympy import init_printing
#init_printing(use_latex="mathjax")
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Creating model function

# %%
def model():
  model = Model()
  model.set_var_default(0)
  
  model.var('C', desc='Consumption')
  model.var('FD', desc='Distributed profits')
  model.var('Fn', desc='Net profits')
  model.var('FT', desc='Total Profits')
  model.var('FU', desc='Retained profits')
  model.var('gk', desc='Capital growth rate', default=0.01)
  model.var('g_Ih', desc='Residential investment growth rate (Demand)', default = 0.05)
  model.var('h', desc='Marginal propensity to invest (non-residential)', default=0.30)
  model.var('I_t', desc='Investment', default = 100) # 200
  model.var('I_f', desc='Non-residential investment') # 100
  model.var('I_h', desc='Residential investment', default = 100) # 100
  model.var('Is', desc='Residential investment (Supply)', default = 100) # 100
  model.var('K_HS', desc='Houses supply', default=500) # 500
  model.var('K_HD', desc='Houses demand', default=500) # 500
  model.var('K_f', desc='Non-residential capital', default = 1000) # 10000
  model.var('K', desc='Capital', default=1500)
  model.var('L', desc='Loans') # 100
  model.var('M', desc='Money deposits', default = 305) # 300
  model.var('MO', desc='Mortgages', default = 305) # 200
  model.var('NFW_h', desc='Households Net Financial Wealth')
  model.var('NFW_f', desc='Firms Net Financial Wealth')
  model.var('NFW_b', desc='Banks Net Financial Wealth')
  model.var('omega', desc='Wage-share', default = 0.5)
  model.var('rl', desc='Interests rates on loans')
  model.var('rmo', desc='Interests rates on mortgages')
  model.var('S_h', desc='Households savings', default = 100)
  model.var('tau', desc="% of Kf in total")
  model.var('u', desc='Capacity utilization ratio', default=0.7)
  model.var('V_h', desc='Household net financial wealth', default = 500)
  model.var('V_f', desc='Firms net financial wealth', default = 1000)
  model.var('V_b', desc='Banks net financial wealth')
  model.var('W', desc='Wages')
  model.var('Y', desc='GDP')
  model.var('Yk', desc='Capacity')
  model.var('YD', desc='Household disposable income')
  model.var('Z', desc='Autonomous expenditures')
  
  model.param('alpha', desc='Propensity to consume out of wages', default=1) # 0.7
  model.param('gamma_F', desc='% of undistributed profits', default=0.4) # 0.4
  model.param('gamma_u', desc='Adjustment parameter for the marginal propensity to invest', default=0.01) # 0.01
  model.param('gz', desc='Autonomous grouth rate', default=0.05) # 0.02
  model.param('omegapar', desc='Wage-share', default=0.5) # 0.5
  model.param('rm', desc='Interest rates on money deposits', default=0.02) # 0.02
  model.param('spread_l', desc='Spread for loans', default=0) # 0.01
  model.param('spread_mo', desc='Spread for mortgages', default=0) # 0.005
  model.param('un', desc='Normal capacity utilization ratio', default=0.8) # 0.8
  model.param('v', desc='Capitl-Output ratio', default=2.5) # 2.5
  
  
  # General equations
  model.add('Y = C + I_t') # Eq1
  model.add('I_t = I_f + I_h') # Eq2
  model.add('omega = omegapar') # Eq 3
  model.add('Yk = K_f(-1)/v') # Eq 4
  model.add('u = Y/Yk') # Eq 5
  model.add('W = omega*Y') # Eq 6
  model.add('gk = h*u/v') # Eq 7
  model.add('K = K_HD + K_f') # Eq 8
  model.add('Z = I_h') # Eq 9
  
  # Household equations
  model.add('YD = W + FD + rm*M(-1) - rmo*MO(-1)') # Eq 10
  model.add('S_h = YD - C') # Eq 11
  model.add('d(MO) = I_h') # Eq 12
  model.add('C = alpha*W') # Eq 13
  model.add('V_h = M + K_HD - MO') # Eq 14
  model.add('NFW_h = S_h - I_h')
  
  # Firms
  model.add('d(L) = I_f - FU') # Eq 15
  model.add('FT = (1-omega)*Y') # Eq 16
  model.add('Fn = FT -rl*L(-1)')
  model.add('FU = gamma_F*(Fn)') # Eq 17
  model.add('FD = (1 - gamma_F)*(Fn)') # Eq 18
  model.add('I_f = h*Y') # Eq 19
  model.add('d(K_f) = I_f') # 20
  model.add('h = h(-1)*gamma_u*(u-un) + h(-1)') # Eq 21 # Version without corridor
  model.add('V_f = K_f - L') # Eq 22
  model.add('NFW_f = FU - I_f') # Eq 23
  
  # Banks
  model.add('d(M) = d(L) + d(MO)') # Eq 24
  model.add('rmo = rm + spread_mo') # Eq 25
  model.add('rl = rm + spread_l') # Eq 26
  model.add('V_b = L + MO - M') # Eq 27
  model.add('NFW_b = rl*L(-1) + rmo*MO(-1) - rm*M(-1)') # Eq 28
  
  # Residential investment
  model.add('K_HS = K_HD') # Eq 29
  model.add('Is = I_h')
  model.add('d(K_HD) = I_h') # Eq 30
  model.add('I_h = (1+g_Ih(-1))*I_h(-1)') # Eq 31
  model.add('g_Ih = gz') # Eq 32
  model.add('tau = K_f/K')
  return model

# %% [markdown]
# # Evaluating consistenty

# %%
test = model()
SolveSFC(test, time=70, table = False)
evaldf = pd.DataFrame({
    'Households' : test.evaluate('M - MO + K_HD - V_h'),
    'Firms' : test.evaluate('K_f - L - V_f'),
    'Banks' : test.evaluate('L + MO - M - V_b'),
    'Mortgages' : test.evaluate('MO(-1) - MO(-2) - I_h(-1)'),
    'Financial assets' : test.evaluate('d(MO) + d(L) - d(M)'),
    '[Total Financial Wealth - K]' : test.evaluate('V_f + V_h + V_b - K'),
    "Firm's Funds" : test.evaluate('L(-1) - L(-2) - I_f(-1) + FU(-1)'),
    "Housing" : test.evaluate('K_HD - K_HS'),
    "[Net Financial Wealth]" : test.evaluate('NFW_h + NFW_f + NFW_b'),
    "Investment" : test.evaluate('I_t - I_h - I_f'),
    "Profits" : test.evaluate('FT(-1) - rl*L(-2) - FU(-1) - FD(-1)'),
    "Wages" : test.evaluate('W - omega*Y')
}, index = ['Sum'])
evaldf = evaldf.transpose()
evaldf.round(5)
# Out:
#                                   Sum
# Banks                         0.00000
# Financial assets              0.00000
# Firm's Funds                 -0.00151
# Firms                         0.00000
# Households                    0.00186
# Housing                       0.00000
# Investment                   -0.00716
# Mortgages                     0.00000
# Profits                       0.00000
# Wages                         0.00000
# [Net Financial Wealth]       -0.02445
# [Total Financial Wealth - K]  0.00530

# %% [markdown]
# # Solving

# %%
base = model()
df = SolveSFC(base, time=700)
df.transpose()
# Out:
#                0            1             2             3             4    \
# C             0.00   264.568078  2.795186e+02  2.948964e+02  3.107489e+02
# FD            0.00   158.740847  1.670663e+02  1.755982e+02  1.843648e+02
# FT            0.00   264.568078  2.795186e+02  2.948964e+02  3.107489e+02
# FU            0.00   105.827231  1.113775e+02  1.170654e+02  1.229099e+02
# Fn            0.00   264.568078  2.784438e+02  2.926636e+02  3.072747e+02
# I_f           0.00   159.570799  1.692713e+02  1.791366e+02  1.892012e+02
# I_h         100.00   105.000000  1.102500e+02  1.157625e+02  1.215506e+02
# I_t         100.00   264.570083  2.795206e+02  2.948984e+02  3.107510e+02
# Is          100.00   105.000000  1.102500e+02  1.157625e+02  1.215506e+02
# K          1500.00  1764.570083  2.044091e+03  2.338990e+03  2.649742e+03
# K_HD        500.00   605.000000  7.152500e+02  8.310125e+02  9.525631e+02
# K_HS        500.00   605.000000  7.152500e+02  8.310125e+02  9.525631e+02
# K_f        1000.00  1159.570799  1.328842e+03  1.507979e+03  1.697180e+03
# L             0.00    53.743319  1.116368e+02  1.737078e+02  2.399988e+02
# M           305.00   463.743319  6.318868e+02  8.097203e+02  9.975619e+02
# MO          305.00   410.000000  5.202500e+02  6.360125e+02  7.575631e+02
# NFW_b         0.00     0.000000  0.000000e+00  1.776357e-15  3.552714e-15
# NFW_f         0.00   -53.743568 -5.789376e+01 -6.207117e+01 -6.629127e+01
# NFW_h         0.00    53.741314  5.789158e+01  6.206888e+01  6.628887e+01
# S_h         100.00   158.741314  1.681416e+02  1.778314e+02  1.878395e+02
# V_b           0.00     0.000000  1.136868e-13  1.136868e-13  1.136868e-13
# V_f        1000.00  1105.827479  1.217205e+03  1.334271e+03  1.457181e+03
# V_h         500.00   658.743029  8.268866e+02  1.004720e+03  1.192562e+03
# W             0.00   264.568078  2.795186e+02  2.948964e+02  3.107489e+02
# Y             0.00   529.136156  5.590373e+02  5.897927e+02  6.214978e+02
# YD            0.00   423.308223  4.476591e+02  4.727265e+02  4.985872e+02
# Yk            0.00   400.000000  4.638283e+02  5.315368e+02  6.031915e+02
# Z             0.00   105.000000  1.102500e+02  1.157625e+02  1.215506e+02
# _I_h__1     100.00   100.000000  1.050000e+02  1.102500e+02  1.157625e+02
# _K_HD__1    500.00   500.000000  6.050000e+02  7.152500e+02  8.310125e+02
# _K_f__1    1000.00  1000.000000  1.159571e+03  1.328842e+03  1.507979e+03
# _L__1         0.00     0.000000  5.374332e+01  1.116368e+02  1.737078e+02
# _MO__1      305.00   305.000000  4.100000e+02  5.202500e+02  6.360125e+02
# _M__1       305.00   305.000000  4.637433e+02  6.318868e+02  8.097203e+02
# _g_Ih__1      0.05     0.050000  5.000000e-02  5.000000e-02  5.000000e-02
# _h__1         0.30     0.300000  3.015685e-01  3.027907e-01  3.037281e-01
# alpha         1.00     1.000000  1.000000e+00  1.000000e+00  1.000000e+00
# g_Ih          0.05     0.050000  5.000000e-02  5.000000e-02  5.000000e-02
# gamma_F       0.40     0.400000  4.000000e-01  4.000000e-01  4.000000e-01
# gamma_u       0.01     0.010000  1.000000e-02  1.000000e-02  1.000000e-02
# gk            0.01     0.159571  1.459775e-01  1.348066e-01  1.254667e-01
# gz            0.05     0.050000  5.000000e-02  5.000000e-02  5.000000e-02
# h             0.30     0.301569  3.027907e-01  3.037281e-01  3.044278e-01
# omega         0.50     0.500000  5.000000e-01  5.000000e-01  5.000000e-01
# omegapar      0.50     0.500000  5.000000e-01  5.000000e-01  5.000000e-01
# rl            0.00     0.020000  2.000000e-02  2.000000e-02  2.000000e-02
# rm            0.02     0.020000  2.000000e-02  2.000000e-02  2.000000e-02
# rmo           0.00     0.020000  2.000000e-02  2.000000e-02  2.000000e-02
# spread_l      0.00     0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# spread_mo     0.00     0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# tau           0.00     0.657141  6.500894e-01  6.447135e-01  6.405075e-01
# u             0.70     1.322840  1.205268e+00  1.109599e+00  1.030349e+00
# un            0.80     0.800000  8.000000e-01  8.000000e-01  8.000000e-01
# v             2.50     2.500000  2.500000e+00  2.500000e+00  2.500000e+00
#
#                     5             6             7             8    \
# C          3.271187e+02  3.440501e+02  3.615825e+02  3.797558e+02
# FD         1.933913e+02  2.027033e+02  2.123238e+02  2.222759e+02
# FT         3.271187e+02  3.440501e+02  3.615825e+02  3.797558e+02
# FU         1.289275e+02  1.351355e+02  1.415492e+02  1.481839e+02
# Fn         3.223188e+02  3.378388e+02  3.538730e+02  3.704598e+02
# I_f        1.994941e+02  2.100442e+02  2.208762e+02  2.320141e+02
# I_h        1.276282e+02  1.340096e+02  1.407100e+02  1.477455e+02
# I_t        3.271213e+02  3.440528e+02  3.615852e+02  3.797586e+02
# Is         1.276282e+02  1.340096e+02  1.407100e+02  1.477455e+02
# K          2.976864e+03  3.320918e+03  3.682504e+03  4.062264e+03
# K_HD       1.080191e+03  1.214201e+03  1.354911e+03  1.502656e+03
# K_HS       1.080191e+03  1.214201e+03  1.354911e+03  1.502656e+03
# K_f        1.896674e+03  2.106718e+03  2.327594e+03  2.559609e+03
# L          3.105650e+02  3.854734e+02  4.648000e+02  5.486299e+02
# M          1.195756e+03  1.404674e+03  1.624711e+03  1.856286e+03
# MO         8.851913e+02  1.019201e+03  1.159911e+03  1.307656e+03
# NFW_b      0.000000e+00  7.105427e-15  7.105427e-15  7.105427e-15
# NFW_f     -7.056660e+01 -7.490869e+01 -7.932699e+01 -8.383021e+01
# NFW_h      7.056368e+01  7.490567e+01  7.932387e+01  8.382699e+01
# S_h        1.981918e+02  2.089152e+02  2.200339e+02  2.315725e+02
# V_b        3.410605e-13  2.273737e-13  2.273737e-13  2.273737e-13
# V_f        1.586109e+03  1.721245e+03  1.862794e+03  2.010979e+03
# V_h        1.390756e+03  1.599674e+03  1.819711e+03  2.051286e+03
# W          3.271187e+02  3.440501e+02  3.615825e+02  3.797558e+02
# Y          6.542375e+02  6.881003e+02  7.231649e+02  7.595116e+02
# YD         5.253091e+02  5.529638e+02  5.816148e+02  6.113267e+02
# Yk         6.788719e+02  7.586696e+02  8.426873e+02  9.310378e+02
# Z          1.276282e+02  1.340096e+02  1.407100e+02  1.477455e+02
# _I_h__1    1.215506e+02  1.276282e+02  1.340096e+02  1.407100e+02
# _K_HD__1   9.525631e+02  1.080191e+03  1.214201e+03  1.354911e+03
# _K_f__1    1.697180e+03  1.896674e+03  2.106718e+03  2.327594e+03
# _L__1      2.399988e+02  3.105650e+02  3.854734e+02  4.648000e+02
# _MO__1     7.575631e+02  8.851913e+02  1.019201e+03  1.159911e+03
# _M__1      9.975619e+02  1.195756e+03  1.404674e+03  1.624711e+03
# _g_Ih__1   5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# _h__1      3.044278e-01  3.049261e-01  3.052524e-01  3.054299e-01
# alpha      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# g_Ih       5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# gamma_F    4.000000e-01  4.000000e-01  4.000000e-01  4.000000e-01
# gamma_u    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02
# gk         1.175445e-01  1.107435e-01  1.048437e-01  9.967979e-02
# gz         5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# h          3.049261e-01  3.052524e-01  3.054299e-01  3.054781e-01
# omega      5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# omegapar   5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# rl         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rm         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rmo        2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# spread_l   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# tau        6.371382e-01  6.343782e-01  6.320683e-01  6.300941e-01
# u          9.637127e-01  9.069828e-01  8.581652e-01  8.157688e-01
# un         8.000000e-01  8.000000e-01  8.000000e-01  8.000000e-01
# v          2.500000e+00  2.500000e+00  2.500000e+00  2.500000e+00
#
#                     9        ...                691           692  \
# C          3.986102e+02      ...       6.377259e+16  6.696125e+16
# FD         2.325826e+02      ...       3.985384e+16  4.184659e+16
# FT         3.986102e+02      ...       6.377259e+16  6.696125e+16
# FU         1.550550e+02      ...       2.656922e+16  2.789773e+16
# Fn         3.876376e+02      ...       6.642306e+16  6.974432e+16
# I_f        2.434813e+02      ...       1.993934e+16  2.093619e+16
# I_h        1.551328e+02      ...       4.383345e+16  4.602512e+16
# I_t        3.986131e+02      ...       6.377275e+16  6.696130e+16
# Is         1.551328e+02      ...       4.383345e+16  4.602512e+16
# K          4.460878e+03      ...       1.339327e+18  1.406288e+18
# K_HD       1.657789e+03      ...       9.205025e+17  9.665276e+17
# K_HS       1.657789e+03      ...       9.205025e+17  9.665276e+17
# K_f        2.803090e+03      ...       4.188242e+17  4.397604e+17
# L          6.370558e+02      ...      -1.391533e+17 -1.461149e+17
# M          2.099845e+03      ...       7.813491e+17  8.204127e+17
# MO         1.462789e+03      ...       9.205025e+17  9.665276e+17
# NFW_b      7.105427e-15      ...       6.000000e+00  8.000000e+00
# NFW_f     -8.842631e+01      ...       6.629889e+15  6.961542e+15
# NFW_h      8.842301e+01      ...      -6.630038e+15 -6.961584e+15
# S_h        2.435558e+02      ...       3.720341e+16  3.906354e+16
# V_b       -2.273737e-13      ...       3.840000e+02  3.840000e+02
# V_f        2.166034e+03      ...       5.579775e+17  5.858753e+17
# V_h        2.294845e+03      ...       7.813491e+17  8.204127e+17
# W          3.986102e+02      ...       6.377259e+16  6.696125e+16
# Y          7.972204e+02      ...       1.275452e+17  1.339225e+17
# YD         6.421643e+02      ...       1.009759e+17  1.060248e+17
# Yk         1.023843e+03      ...       1.595539e+17  1.675297e+17
# Z          1.551328e+02      ...       4.383345e+16  4.602512e+16
# _I_h__1    1.477455e+02      ...       4.174614e+16  4.383345e+16
# _K_HD__1   1.502656e+03      ...       8.766690e+17  9.205025e+17
# _K_f__1    2.559609e+03      ...       3.988849e+17  4.188242e+17
# _L__1      5.486299e+02      ...      -1.325235e+17 -1.391533e+17
# _MO__1     1.307656e+03      ...       8.766690e+17  9.205025e+17
# _M__1      1.856286e+03      ...       7.441456e+17  7.813491e+17
# _g_Ih__1   5.000000e-02      ...       5.000000e-02  5.000000e-02
# _h__1      3.054781e-01      ...       1.563325e-01  1.563315e-01
# alpha      1.000000e+00      ...       1.000000e+00  1.000000e+00
# g_Ih       5.000000e-02      ...       5.000000e-02  5.000000e-02
# gamma_F    4.000000e-01      ...       4.000000e-01  4.000000e-01
# gamma_u    1.000000e-02      ...       1.000000e-02  1.000000e-02
# gk         9.512445e-02      ...       4.998770e-02  4.998800e-02
# gz         5.000000e-02      ...       5.000000e-02  5.000000e-02
# h          3.054129e-01      ...       1.563315e-01  1.563306e-01
# omega      5.000000e-01      ...       5.000000e-01  5.000000e-01
# omegapar   5.000000e-01      ...       5.000000e-01  5.000000e-01
# rl         2.000000e-02      ...       2.000000e-02  2.000000e-02
# rm         2.000000e-02      ...       2.000000e-02  2.000000e-02
# rmo        2.000000e-02      ...       2.000000e-02  2.000000e-02
# spread_l   0.000000e+00      ...       0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00      ...       0.000000e+00  0.000000e+00
# tau        6.283718e-01      ...       3.127125e-01  3.127101e-01
# u          7.786546e-01      ...       7.993860e-01  7.993957e-01
# un         8.000000e-01      ...       8.000000e-01  8.000000e-01
# v          2.500000e+00      ...       2.500000e+00  2.500000e+00
#
#                     693           694           695           696  \
# C          7.030905e+16  7.382424e+16  7.751531e+16  8.139069e+16
# FD         4.393881e+16  4.613564e+16  4.844239e+16  5.086433e+16
# FT         7.030905e+16  7.382424e+16  7.751531e+16  8.139069e+16
# FU         2.929254e+16  3.075709e+16  3.229492e+16  3.390955e+16
# Fn         7.323135e+16  7.689273e+16  8.073731e+16  8.477388e+16
# I_f        2.198278e+16  2.308170e+16  2.423560e+16  2.544711e+16
# I_h        4.832638e+16  5.074270e+16  5.327983e+16  5.594382e+16
# I_t        7.030914e+16  7.382437e+16  7.751541e+16  8.139089e+16
# Is         4.832638e+16  5.074270e+16  5.327983e+16  5.594382e+16
# K          1.476597e+18  1.550422e+18  1.627937e+18  1.709328e+18
# K_HD       1.014854e+18  1.065597e+18  1.118876e+18  1.174820e+18
# K_HS       1.014854e+18  1.065597e+18  1.118876e+18  1.174820e+18
# K_f        4.617432e+17  4.848249e+17  5.090605e+17  5.345076e+17
# L         -1.534246e+17 -1.611000e+17 -1.691593e+17 -1.776218e+17
# M          8.614293e+17  9.044966e+17  9.497172e+17  9.971986e+17
# MO         1.014854e+18  1.065597e+18  1.118876e+18  1.174820e+18
# NFW_b      8.000000e+00  6.000000e+00  8.000000e+00  8.000000e+00
# NFW_f      7.309758e+15  7.675392e+15  8.059324e+15  8.462439e+15
# NFW_h     -7.309844e+15 -7.675516e+15 -8.059418e+15 -8.462629e+15
# S_h        4.101654e+16  4.306718e+16  4.522041e+16  4.748120e+16
# V_b        3.840000e+02  3.840000e+02  2.560000e+02  2.560000e+02
# V_f        6.151678e+17  6.459249e+17  6.782198e+17  7.121293e+17
# V_h        8.614293e+17  9.044967e+17  9.497172e+17  9.971986e+17
# W          7.030905e+16  7.382424e+16  7.751531e+16  8.139069e+16
# Y          1.406181e+17  1.476485e+17  1.550306e+17  1.627814e+17
# YD         1.113255e+17  1.168913e+17  1.227357e+17  1.288717e+17
# Yk         1.759042e+17  1.846973e+17  1.939299e+17  2.036242e+17
# Z          4.832638e+16  5.074270e+16  5.327983e+16  5.594382e+16
# _I_h__1    4.602512e+16  4.832638e+16  5.074270e+16  5.327983e+16
# _K_HD__1   9.665276e+17  1.014854e+18  1.065597e+18  1.118876e+18
# _K_f__1    4.397604e+17  4.617432e+17  4.848249e+17  5.090605e+17
# _L__1     -1.461149e+17 -1.534246e+17 -1.611000e+17 -1.691593e+17
# _MO__1     9.665276e+17  1.014854e+18  1.065597e+18  1.118876e+18
# _M__1      8.204127e+17  8.614293e+17  9.044966e+17  9.497172e+17
# _g_Ih__1   5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# _h__1      1.563306e-01  1.563297e-01  1.563287e-01  1.563278e-01
# alpha      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# g_Ih       5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# gamma_F    4.000000e-01  4.000000e-01  4.000000e-01  4.000000e-01
# gamma_u    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02
# gk         4.998809e-02  4.998818e-02  4.998836e-02  4.998839e-02
# gz         5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# h          1.563297e-01  1.563287e-01  1.563278e-01  1.563269e-01
# omega      5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# omegapar   5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# rl         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rm         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rmo        2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# spread_l   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# tau        3.127076e-01  3.127052e-01  3.127028e-01  3.127004e-01
# u          7.994018e-01  7.994080e-01  7.994156e-01  7.994206e-01
# un         8.000000e-01  8.000000e-01  8.000000e-01  8.000000e-01
# v          2.500000e+00  2.500000e+00  2.500000e+00  2.500000e+00
#
#                     697           698           699           700
# C          8.546000e+16  8.973288e+16  9.421917e+16  9.893020e+16
# FD         5.340746e+16  5.607782e+16  5.888155e+16  6.182573e+16
# FT         8.546000e+16  8.973288e+16  9.421917e+16  9.893020e+16
# FU         3.560497e+16  3.738521e+16  3.925437e+16  4.121716e+16
# Fn         8.901244e+16  9.346303e+16  9.813592e+16  1.030429e+17
# I_f        2.671924e+16  2.805501e+16  2.945749e+16  3.093021e+16
# I_h        5.874102e+16  6.167807e+16  6.476197e+16  6.800007e+16
# I_t        8.546021e+16  8.973304e+16  9.421940e+16  9.893027e+16
# Is         5.874102e+16  6.167807e+16  6.476197e+16  6.800007e+16
# K          1.794788e+18  1.884521e+18  1.978741e+18  2.077671e+18
# K_HD       1.233561e+18  1.295239e+18  1.360001e+18  1.428001e+18
# K_HS       1.233561e+18  1.295239e+18  1.360001e+18  1.428001e+18
# K_f        5.612268e+17  5.892818e+17  6.187393e+17  6.496695e+17
# L         -1.865075e+17 -1.958377e+17 -2.056345e+17 -2.159215e+17
# M          1.047054e+18  1.099402e+18  1.154367e+18  1.212080e+18
# MO         1.233561e+18  1.295239e+18  1.360001e+18  1.428001e+18
# NFW_b      0.000000e+00  4.000000e+00  4.000000e+00  8.000000e+00
# NFW_f      8.885730e+15  9.330202e+15  9.796884e+15  1.028694e+16
# NFW_h     -8.885930e+15 -9.330353e+15 -9.797104e+15 -1.028701e+16
# S_h        4.985509e+16  5.234771e+16  5.496487e+16  5.771306e+16
# V_b        2.560000e+02  2.560000e+02  2.560000e+02  2.560000e+02
# V_f        7.477343e+17  7.851195e+17  8.243739e+17  8.655910e+17
# V_h        1.047054e+18  1.099402e+18  1.154367e+18  1.212080e+18
# W          8.546000e+16  8.973288e+16  9.421917e+16  9.893020e+16
# Y          1.709200e+17  1.794658e+17  1.884383e+17  1.978604e+17
# YD         1.353149e+17  1.420805e+17  1.491839e+17  1.566432e+17
# Yk         2.138030e+17  2.244907e+17  2.357127e+17  2.474957e+17
# Z          5.874102e+16  6.167807e+16  6.476197e+16  6.800007e+16
# _I_h__1    5.594382e+16  5.874102e+16  6.167807e+16  6.476197e+16
# _K_HD__1   1.174820e+18  1.233561e+18  1.295239e+18  1.360001e+18
# _K_f__1    5.345076e+17  5.612268e+17  5.892818e+17  6.187393e+17
# _L__1     -1.776218e+17 -1.865075e+17 -1.958377e+17 -2.056345e+17
# _MO__1     1.174820e+18  1.233561e+18  1.295239e+18  1.360001e+18
# _M__1      9.971986e+17  1.047054e+18  1.099402e+18  1.154367e+18
# _g_Ih__1   5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# _h__1      1.563269e-01  1.563260e-01  1.563251e-01  1.563243e-01
# alpha      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# g_Ih       5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# gamma_F    4.000000e-01  4.000000e-01  4.000000e-01  4.000000e-01
# gamma_u    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02
# gk         4.998852e-02  4.998872e-02  4.998879e-02  4.998908e-02
# gz         5.000000e-02  5.000000e-02  5.000000e-02  5.000000e-02
# h          1.563260e-01  1.563251e-01  1.563243e-01  1.563234e-01
# omega      5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# omegapar   5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# rl         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rm         2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# rmo        2.000000e-02  2.000000e-02  2.000000e-02  2.000000e-02
# spread_l   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# tau        3.126981e-01  3.126958e-01  3.126935e-01  3.126913e-01
# u          7.994274e-01  7.994351e-01  7.994406e-01  7.994497e-01
# un         8.000000e-01  8.000000e-01  8.000000e-01  8.000000e-01
# v          2.500000e+00  2.500000e+00  2.500000e+00  2.500000e+00
#
# [54 rows x 701 columns]

# %% [markdown]
# # Baseline Plots

# %%
ax = df['K_HD'][10:].pct_change().plot(color = "black", title = "Houses growth rate", label = "$K_{HD}$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
plt.xlabel("Period")
sns.despine()
plt.show()

# %%
ax = df['tau'].plot(color = "black", title = "Capacity generating capital as % of total capital", label = "$\\tau$", legend = True)
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
plt.xlabel("Period")
sns.despine()
plt.show()

# %%
ax = df[['C', 'I_t']].apply(lambda x: x/df['Y']).plot(kind = 'area', stacked = True, legend = True, title = "Consumption and total investiment as % of GDP")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['I_f', 'I_h']].apply(lambda x: x/df['I_t']).plot(kind = 'area', stacked = True, legend = True, title = "Residential and Non-residential Investiment (as % of total investment)")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['W', 'FT']].apply(lambda x: x/df['Y']).plot(kind = 'area', stacked = True, legend = True, title = "Wage and profit share (as % of GDP)")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['V_b', 'V_h', 'V_f']].apply(lambda x: np.abs(x)/df['K']).plot(kind = 'area', stacked = True, title = "Net financial wealth (as % K)")
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
sns.despine()
plt.show()

# %%
df[["NFW_b", "NFW_h", "NFW_f"]].plot(title = "Net Financial Wealth")
sns.despine()
plt.show()

# %%
df['NFW_b'].plot(title = "Banks Net Financial Wealth")
sns.despine()
plt.show()

# %%
ax = df[["FU", "FD"]].apply(lambda x: x/df["Fn"]).plot(kind = "area", stacked = True, title = "Profits (as % net profits)")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.axhline(y = 1, color = "black", ls = "--")
sns.despine()
plt.show()

# %%
ax = df[["MO", "L"]].apply(lambda x: x/df["M"]).plot(kind = "area",stacked = False ,title = "Credit (as % Deposits)")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.axhline(y = 1, color = "blue", ls = "--")
ax.axhline(y = 0, color = "black", ls = "--")
sns.despine()
plt.show()

# %%
df["M"].plot(title = "Deposits")
sns.despine()
plt.show()

# %%
ax = df['Y'].pct_change().plot(color = "black", title = "GDP growth rate", label = "$Y_t$", legend = True)
ax.set_yticklabels(['{:,.2%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=df["gz"][0], color = "red", ls = "--", lw=1, label = "Autonomous growth rate")
sns.despine()
plt.show()

# %%
ax = df['u'].plot(color = "black", title = "Capacity utilization ratio", label = "$u_t$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
ax = df['un'].plot(color = "red", ls="--",  title = "Capacity utilization ratio", label = "$un$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df['h'].plot(color = "black", ls="-",  title = "Marginal propensity to invest", label = "$h_t$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[["Y", "K", "I_h", "I_f"]][40:].pct_change().plot(title = "Growth rates")
ax.set_yticklabels(['{:,.2%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=df["gz"][0], color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
sns.despine()
plt.show()

# %% [markdown]
# # Analytical solution

# %%
base_eq = model()
SolveSFC(base_eq, time=1, table = False)
t = sp.Symbol('t')
initials = {
    key: base_eq.evaluate(key) for key in base_eq.parameters
}
initials.update({key: base_eq.evaluate(key) for key in base_eq.variables})

# %% [markdown]
# Model variables

# %%
for i in base_eq.variables:
  globals()["_" + i] = sp.Function(i)

# %% [markdown]
# Model parameters

# %%
for i in base_eq.parameters:
  globals()[i] = sp.symbols(i, positive=True)

# %% [markdown]
# Defining equations

# %% [markdown]
# ## General equations

# %%
Y = _C(t) + _I_t(t)
I = _I_f(t) + _I_h(t)
Yk = _K_f(t-1)/v
u = _Y(t)/_Yk(t)
Z = _I_h(t)
W = _omega(t)*_Y(t)
K = _K_HD(t) + _K_f(t)

# %% [markdown]
# ## Households

# %%
C = alpha*_W(t)
YD = _W(t) + _FD(t) + rm*_M(t-1) - _rmo(t)*_MO(t-1)
S_h = _YD(t) - _C(t)
dMO = _I_h(t)
V_h = _M(t) + _K_HD(t) - _MO(t)
NFW_h = _S_h(t) - _I_h(t)

# %% [markdown]
# ## Firms

# %%
I_f = _h(t)*_Y(t)
dK_f = _I_f(t)
L = _I_f(t) - _FU(t) + _L(t-1)
FT = _FU(t) + _FD(t)
FU = gamma_F*(_FT(t) - _rl(t)*_L(t-1))
FD = (1 - gamma_F)*(_FT(t) - _rl(t)*_L(t-1))
h = _h(t-1)*gamma_u*(_u(t)-un) + _h(t-1)
NFW_f = _FU(t) - _I_f(t)
V_f = _K_f(t) - _L(t)

# %% [markdown]
# ## Banks

# %%
M = (_L(t) - _L(t-1)) + (_MO(t) - _MO(t-1)) + _M(t-1)
rmo = rm + spread_mo
rl = rm + spread_l
V_b = _L(t) + _MO(t) - _M(t)
NFW_b = _rl(t)*_L(t-1) + _rmo(t)*_MO(t-1) - rm*_M(t-1)

# %% [markdown]
# ## Residential Investment

# %%
K_HS = _K_HD(t)
Is = _I_h(t)
dK_HD = _I_h(t)
I_h = _I_h(t-1)*(1+_g_Ih(-1))
g_Ih = gz

# %% [markdown]
# # Rearranging

# %% [markdown]
# ## Level of GDP

# %%
EqY = Y - _Y(t)
EqY = EqY.subs(_C(t), C).subs(_I_t(t), I)
EqY = EqY.subs(_I_f(t), I_f)
EqY = EqY.subs(_W(t), W)
EqY = sp.solve(EqY, _Y(t))[0].collect(alpha).collect(omegapar)
solY = EqY
print('Y = ', solY)
print('dY/d alpha = ', EqY.diff(alpha))
print('dY/d omega = ', EqY.diff(_omega(t)))

print("\nReplacing the initial values.....")
EqY = EqY.subs(_h(t), h)
EqY = EqY.subs(alpha, df.loc[2, 'alpha']).subs(_omega(t), df.loc[2, 'omega'])
EqY = EqY.subs(un, df.loc[2, 'un']).subs(gamma_u, df.loc[1, 'gamma_u'])
EqY = EqY.subs(_u(t), df.loc[2, 'u']).subs(_h(t-1), df.loc[1, 'h'])
EqY = EqY.subs(_I_h(t), df.loc[2, 'I_h'])
print('Y0 = ', df.loc[1, 'Y'])
print('Y1 = ', EqY)
print('hat Y - Y1 = ', df.loc[2, "Y"] - EqY)
# Out:
# Y =  -I_h(t)/(alpha*omega(t) + h(t) - 1)
# dY/d alpha =  I_h(t)*omega(t)/(alpha*omega(t) + h(t) - 1)**2
# dY/d omega =  alpha*I_h(t)/(alpha*omega(t) + h(t) - 1)**2
#
# Replacing the initial values.....
# Y0 =  529.1361556137123
# Y1 =  559.050660074990
# hat Y - Y1 =  -0.0133757390952951

# %% [markdown]
# $$
# Y_{SR} =  \frac{-I_h(t)}{\alpha\cdot \omega + h(t) - 1}
# $$
#
# Rearranging
#
# $$
# Y_{SR} =  \frac{I_h(t)}{1 - \alpha\cdot \omega - h(t)}
# $$

# %% [markdown]
# ## Capacity output ratio (short-run)

# %% [markdown]
# $$
# \frac{Y}{K(-1)} = \frac{Y}{K(-1)}\frac{Yk}{Yk} = \frac{u}{v}
# $$
#
# $$
# \therefore u = \frac{Y}{K(-1)}v
# $$
#
# $$
# i_{h_t} = \frac{I_h}{K_{t-1}}
# $$
#
# $$
# K(-1) = (1+g_K(-1))\cdot K(-2)
# $$

# %%
Equ = Y - _Y(t)
Equ = Equ.subs(_C(t), _C(t)*v/_K_f(t-1)).subs(_I_t(t), _I_t(t)*v/_K_f(t-1)).subs(_Y(t), _u(t))
Equ = Equ.subs(_C(t), C).subs(_I_t(t), I)
Equ = Equ.subs(_I_f(t), I_f)
Equ = Equ.subs(_W(t), W)
Equ = Equ.expand()
Equ = Equ.subs(_Y(t)/_K_f(t-1), _u(t)/v)
i_h = sp.Function('i_h')
Equ = Equ.subs(_I_h(t)/_K_f(t-1), i_h(t))
Equ = Equ.collect(_u(t))
Equ = Equ.subs(_W(t), W)
Equ = sp.solve(Equ, _u(t))[0].factor().collect(alpha*omegapar).collect(_h(t)).collect(1+_gk(t-1))
Equ = Equ.subs(_I_h(t)/_K_f(t-1), i_h(t))
solu = Equ.collect(alpha**2).collect(omegapar).collect(_YD(t)).collect(alpha)
Equ = Equ.subs(_Y(t), EqY)
print('u = ', solu)
print('\nDerivatives')
print('du/d alpha = ', Equ.diff(alpha))
print('du/d omega = ', Equ.diff(omegapar))

print("\nReplacing the initial values.....")
Equ = Equ.subs(alpha, df.loc[1,'alpha']).subs(_omega(t), df.loc[1,'omega']).subs(alpha, df.loc[1,'alpha'])
Equ = Equ.subs(_gk(t-1), df.loc[0,'gk']).subs(_h(t), df.loc[1,'h']).subs(v, df.loc[1,'v'])
Equ = Equ.subs(i_h(t), df.loc[1,'I_h']/df.loc[0,'K_f']).subs(_YD(t), df.loc[1, 'YD'])

print('u0 = ', df.loc[0,'u'].round(3))
print('u1 = ', Equ)
print("hat u - u1 = ", (df.loc[1,'u'] - Equ))
# Out:
# u =  -v*i_h(t)/(alpha*omega(t) + h(t) - 1)
#
# Derivatives
# du/d alpha =  v*i_h(t)*omega(t)/(alpha*omega(t) + h(t) - 1)**2
# du/d omega =  0
#
# Replacing the initial values.....
# u0 =  0.7
# u1 =  1.32287478551251
# hat u - u1 =  -3.43964782341111e-5

# %%
sp.latex(solu).replace("omegapar", "\\omega")
solu
# Out:
# -v*i_h(t)/(alpha*omega(t) + h(t) - 1)

# %% [markdown]
# $$
# u_{SR} =
# - \frac{v \operatorname{i_{h}}{\left (t \right )}}{\alpha \omega + h{\left (t \right )} - 1}
# $$

# %% [markdown]
# Rerranging
#
# $$
# u_{SR} =  \frac{v\cdot i_h(t)}{1 - \alpha\cdot \omega - h(t)}
# $$

# %% [markdown]
# Consider $\tau$ as the fraction between capacity generating capital and total capital (including households' capital):
#
# $$
# \tau = \frac{K_f}{K}
# $$
#
# The capacity utilization ration can be definede as:
#
# $$
# u = \frac{Y\cdot v}{K \cdot \tau}
# $$

# %% [markdown]
# So, dividing Y by houseolds' capital is the same as:
#
# $$
# \frac{Y}{(1-\tau)\cdot K}
# $$
#
# Multiplying by $v$:
#
#
# $$
# \frac{Y}{(1-\tau)\cdot K}\cdot v = \frac{Y\cdot v}{K}\cdot \left(\frac{1}{1-\tau}\right)
# $$
#
# Multiplying and dividing by $\tau$:
#
# $$
# \frac{Y\cdot v}{K\cdot \tau}\cdot \left(\frac{\tau}{1-\tau}\right) = u \cdot \left(\frac{\tau}{1-\tau}\right)
# $$
#
# Therefore,
#
# $$
# Y\frac{v}{K_h} =  u \cdot \left(\frac{\tau}{1-\tau}\right)
# $$

# %%
tau = sp.Symbol('tau')
solY = solY.subs(_I_h(t), _I_h(t)*v/_K_HD(t)).subs(_I_h(t)/_K_HD(t), gz)
solY = solY - _u(t)*((tau)/(1-tau))

# %%
u_SR = sp.solve(solY, _u(t))[0]
print(sp.latex(u_SR))
# Out:
# \frac{gz v \left(\tau - 1\right)}{\tau \left(\alpha \omega{\left (t \right )} + h{\left (t \right )} - 1\right)}

# %% [markdown]
# $$
# u_{SR} = \frac{gz v \left(\tau - 1\right)}{\tau \left(\alpha \omega{\left (t \right )} + h{\left (t \right )} - 1\right)}
# $$

# %%
Equ = u_SR
print('u = ', solu)
print('\nDerivatives')
print('du/d alpha = ', Equ.diff(alpha))
print('du/d omega = ', Equ.diff(omegapar))
print('du/d tau = ', Equ.diff(tau))

print("\nReplacing the initial values.....")
Equ = Equ.subs(alpha, df.loc[1,'alpha']).subs(_omega(t), df.loc[1,'omega']).subs(alpha, df.loc[1,'alpha'])
Equ = Equ.subs(_h(t), df.loc[1,'h']).subs(v, df.loc[1,'v'])
Equ = Equ.subs(tau, df.loc[1,'tau']).subs(gz, df.loc[0, 'gz'])

print('u0 = ', df.loc[0,'u'].round(3))
print('u1 = ', Equ)
print("hat u - u1 = ", (df.loc[1,'u'] - Equ))
# Out:
# u =  -v*i_h(t)/(alpha*omega(t) + h(t) - 1)
#
# Derivatives
# du/d alpha =  -gz*v*(tau - 1)*omega(t)/(tau*(alpha*omega(t) + h(t) - 1)**2)
# du/d omega =  0
# du/d tau =  gz*v/(tau*(alpha*omega(t) + h(t) - 1)) - gz*v*(tau - 1)/(tau**2*(alpha*omega(t) + h(t) - 1))
#
# Replacing the initial values.....
# u0 =  0.7
# u1 =  0.328667706738667
# hat u - u1 =  0.994172682295613

# %% [markdown]
# # Medium run
#
# $$
# \Delta h_t = h_{t-1}\cdot \gamma_u\cdot (u_t - un)
# $$

# %%
Y_MR = solY
Y_MR = Y_MR.subs(_h(t), h).collect(_h(t-1))
print("Y_MR = ", sp.latex(Y_MR))
# Out:
# Y_MR =  - \frac{gz v}{\alpha \omega{\left (t \right )} + \gamma_{u} \left(- un + u{\left (t \right )}\right) h{\left (t - 1 \right )} + h{\left (t - 1 \right )} - 1} - \frac{\tau u{\left (t \right )}}{- \tau + 1}

# %% [markdown]
# $$
# Y_{MR} =  - \frac{gz v}{\alpha \omega{\left (t \right )} + \gamma_{u} \left(- un + u{\left (t \right )}\right) h{\left (t - 1 \right )} + h{\left (t - 1 \right )} - 1} - \frac{\tau u{\left (t \right )}}{- \tau + 1}
# $$

# %%
u_MR = Y_MR
soluMR = sp.solve(u_MR, _u(t))[0]
soluMR
# Out:
# (tau*(-alpha*omega(t) + gamma_u*un*h(t - 1) - h(t - 1) + 1) - sqrt(tau*(alpha**2*tau*omega(t)**2 - 2*alpha*gamma_u*tau*un*h(t - 1)*omega(t) + 2*alpha*tau*h(t - 1)*omega(t) - 2*alpha*tau*omega(t) + gamma_u**2*tau*un**2*h(t - 1)**2 + 4*gamma_u*gz*tau*v*h(t - 1) - 4*gamma_u*gz*v*h(t - 1) - 2*gamma_u*tau*un*h(t - 1)**2 + 2*gamma_u*tau*un*h(t - 1) + tau*h(t - 1)**2 - 2*tau*h(t - 1) + tau)))/(2*gamma_u*tau*h(t - 1))

# %% [markdown]
# $$
# u_{MR} =
# \frac{1}{2 \gamma_{u} h{\left (t - 1 \right )}} \left(- \alpha \omega{\left (t \right )} + \gamma_{u} un h{\left (t - 1 \right )} - \sqrt{\alpha^{2} \omega^{2}{\left (t \right )} - 2 \alpha \gamma_{u} un h{\left (t - 1 \right )} \omega{\left (t \right )} + 2 \alpha h{\left (t - 1 \right )} \omega{\left (t \right )} - 2 \alpha \omega{\left (t \right )} + \gamma_{u}^{2} un^{2} h^{2}{\left (t - 1 \right )} - 2 \gamma_{u} un h^{2}{\left (t - 1 \right )} + 2 \gamma_{u} un h{\left (t - 1 \right )} - 4 \gamma_{u} v h{\left (t - 1 \right )} \operatorname{i_{h}}{\left (t \right )} + h^{2}{\left (t - 1 \right )} - 2 h{\left (t - 1 \right )} + 1} - h{\left (t - 1 \right )} + 1\right)
# $$

# %% [markdown]
# # Long run

# %%
Y_LR = Y_MR.subs(_u(t), un)
Y_LR = Y_LR.subs(_h(t-1), _h(t))
Y_LR
# Out:
# -gz*v/(alpha*omega(t) + h(t) - 1) - tau*un/(-tau + 1)

# %% [markdown]
# $$- \frac{\operatorname{I_{h}}{\left (t \right )}}{\alpha \omega{\left (t \right )} + h{\left (t \right )} - 1}$$

# %%
u_LR = u_MR.subs(_h(t), h)
u_LR = u_LR.subs(_u(t), un)
u_LR
# Out:
# -gz*v/(alpha*omega(t) + h(t - 1) - 1) - tau*un/(-tau + 1)

# %% [markdown]
# $$- un - \frac{v \operatorname{i_{h}}{\left (t \right )}}{\alpha \omega{\left (t \right )} + h{\left (t - 1 \right )} - 1}$$

# %% [markdown]
# # Sensibility test

# %% [markdown]
# ## Test for $\gamma_u$

# %%
gamma_ufor = [i/1000 for i in range(5,1000,5)]

for i in gamma_ufor:
  gamma_model = model()
  try:
    gamma_model.set_values({
        'gamma_u' : i
    })
  
    gammadf = SolveSFC(gamma_model)
    print("For gamma_u = {}, GDP value is".format(i), gammadf['Y'].iloc[-1])
    print("\n Ploting...\n")
    gammadf['u'].plot()
    plt.show()
    plt.clf
  
    if (gammadf['Y'].iloc[-1] < 0):
      break
      print("GDP is negative")
    
    print("Continuing ...")
  except Exception as e:
    print("For gamma_u = {},",e)
    pass
# Out:
# For gamma_u = 0.005, GDP value is 12035221068571.672
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.01, GDP value is 11464769680794.941
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.015, GDP value is 11439295850749.36
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.02, GDP value is 11439325828068.137
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.025, GDP value is 11439502096929.791
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.03, GDP value is 11439825797913.102
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.035, GDP value is 11438592824211.727
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.04, GDP value is 11439119398322.64
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.045, GDP value is 11441600773984.938
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.05, GDP value is 11440962400591.725
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.055, GDP value is 11434972209667.0
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.06, GDP value is 11430940904765.766
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.065, GDP value is 11440199134245.16
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.07, GDP value is 11464173132386.193
#
#  Ploting...
# Continuing ...
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, NFW_h, NFW_f have not converged
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, L, NFW_h, NFW_f have not converged
# For gamma_u = {}, C, FD, Fn, FT, I_f, L, NFW_h, NFW_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, h, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, V_b, W, Y, YD have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged

# %% [markdown]
# ## Test for $\alpha$

# %%
alpha_for = [i/100 for i in range(5,100,5)]

for i in alpha_for:
  mod = model()
  try:
    mod.set_values({
        'alpha' : i
    })
  
    df = SolveSFC(mod)
    print("For alpha = {}, GDP value is".format(i), df['Y'].iloc[-1])
    print("\n Ploting...\n")
    df['u'].plot()
    plt.show()
    plt.clf()
  
    if (df['Y'].iloc[-1] < 0):
      break
      print("GDP is negative")
    
    print("Continuing ...")
  except Exception as e:
    print("For alpha = {},", e)
    pass
# Out:
# For alpha = 0.05, GDP value is 4808027278139.257
#
#  Ploting...
# Continuing ...
# For alpha = 0.1, GDP value is 4959642303027.448
#
#  Ploting...
# Continuing ...
# For alpha = 0.15, GDP value is 5121130291911.545
#
#  Ploting...
# Continuing ...
# For alpha = 0.2, GDP value is 5293484984180.596
#
#  Ploting...
# Continuing ...
# For alpha = 0.25, GDP value is 5477843820662.768
#
#  Ploting...
# Continuing ...
# For alpha = 0.3, GDP value is 5675500669379.085
#
#  Ploting...
# Continuing ...
# For alpha = 0.35, GDP value is 5887954099217.204
#
#  Ploting...
# Continuing ...
# For alpha = 0.4, GDP value is 6116923170412.811
#
#  Ploting...
# Continuing ...
# For alpha = 0.45, GDP value is 6364414566333.225
#
#  Ploting...
# Continuing ...
# For alpha = 0.5, GDP value is 6632764626109.129
#
#  Ploting...
# Continuing ...
# For alpha = 0.55, GDP value is 6924728073424.146
#
#  Ploting...
# Continuing ...
# For alpha = 0.6, GDP value is 7243566801913.9
#
#  Ploting...
# Continuing ...
# For alpha = 0.65, GDP value is 7593170371854.1
#
#  Ploting...
# Continuing ...
# For alpha = 0.7, GDP value is 7978195279132.133
#
#  Ploting...
# Continuing ...
# For alpha = 0.75, GDP value is 8404305202347.699
#
#  Ploting...
# Continuing ...
# For alpha = 0.8, GDP value is 8878470654099.967
#
#  Ploting...
# Continuing ...
# For alpha = 0.85, GDP value is 9409249122987.129
#
#  Ploting...
# Continuing ...
# For alpha = 0.9, GDP value is 10007469406555.383
#
#  Ploting...
# Continuing ...
# For alpha = 0.95, GDP value is 10686719104609.72
#
#  Ploting...
# Continuing ...

# %% [markdown]
# ## Testing for $\alpha$ and $\gamma_u$

# %%
alpha_for = [i/100 for i in range(5,105,5)]
gamma_ufor = [i/1000 for i in range(5,1000,5)]

for i in alpha_for:
  for j in gamma_ufor:
    mod = model()
    try:
      mod.set_values({
          'alpha' : i,
          'gamma_u': j
      })

      df = SolveSFC(mod)
      print("For alpha = {} and gamma_u = {}, u value is ".format(i,j), df['u'].iloc[-1])
      print("\n Ploting...\n")

      if (df['Y'].iloc[-1] < 0):
        break
        print("GDP is negative")

      print("Continuing ...")
    except Exception as e:
      print("For alpha = {} and gamma_u = {},".format(i,j), e)
      pass
# Out:
# For alpha = 0.05 and gamma_u = 0.005, u value is  0.7167298963296247
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.01, u value is  0.7939819221810204
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.015, u value is  0.8000030468516469
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.02, u value is  0.7999849224425475
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.025, u value is  0.800015175275823
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.03, u value is  0.7999861441990013
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.035, u value is  0.7999955939473192
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.04, u value is  0.8000220770758818
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.045, u value is  0.8000026456963099
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.05, u value is  0.7999703599131532
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.055, u value is  0.7999821387878097
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.06, u value is  0.8000288434908934
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.065, u value is  0.8000493458739669
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.07, u value is  0.8000087719751632
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.075, u value is  0.7999407100673528
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.08, u value is  0.7999160188374859
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.085, u value is  0.7999740747339047
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.09, u value is  0.8000827446977937
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.095, u value is  0.8001559997787061
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.1, u value is  0.8001169506041291
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.105, u value is  0.7999604873969517
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.11, u value is  0.7997705282342352
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.115, u value is  0.7996789072056272
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.12, u value is  0.7997860824707013
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.125, u value is  0.8000908589887477
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.13, u value is  0.8004659830279566
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.135, u value is  0.8007014783656641
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.14, u value is  0.8006023582883244
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.145, u value is  0.8000994297733762
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.15, u value is  0.7993183261146437
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.155, u value is  0.7985708584629083
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.16, u value is  0.7982545686506692
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.165, u value is  0.7986937325807045
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.17, u value is  0.7999762036954484
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.175, u value is  0.8018504092081591
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.18, u value is  0.803725414256083
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.185, u value is  0.8047962737801633
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.19, u value is  0.804285674339589
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.195, u value is  0.8017494971480943
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.2, u value is  0.7973459283178953
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.205, u value is  0.7919524960912161
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.21, u value is  0.7870477344732115
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.215, u value is  0.7843777709091225
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.22, u value is  0.7855284951519576
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.225, u value is  0.7915481833458038
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.23, u value is  0.8027345670937633
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.235, u value is  0.8186153656915076
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.24, u value is  0.8381602502285603
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.245, u value is  0.860357388838362
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.25, u value is  0.885577285908942
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.255, u value is  0.918856084854923
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.26, u value is  0.975607962561451
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.265, u value is  0.9113095630147414
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.05 and gamma_u = 0.27, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.275, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.28, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.285, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.29, L have not converged
# For alpha = 0.05 and gamma_u = 0.295, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.3, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.305, I_f, L, NFW_h, NFW_f, YD have not converged
# For alpha = 0.05 and gamma_u = 0.31, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.315, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.32, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.325, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.33, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.335, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.34, NFW_h have not converged
# For alpha = 0.05 and gamma_u = 0.345, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.35, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.355, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.36, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.365, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.37, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.375, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.38, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.385, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.39, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.395, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.4, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.405, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.41, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.415, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.42, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.425, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.43, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.435, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.44, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, u, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.445, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.45, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.455, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.46, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.465, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.47, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.475, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.48, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.485, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.49, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.495, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.5, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.505, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.51, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.515, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.52, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.525, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.53, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.535, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.54, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.545, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.55, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.555, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.56, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.565, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.57, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.575, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.58, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.585, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.59, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.595, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.6, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.605, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.61, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.615, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.62, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.625, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.63, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.635, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.64, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.645, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.65, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.655, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.66, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.665, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.67, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.675, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.68, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.685, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.69, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.695, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.7, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.705, NFW_h, NFW_f have not converged
# For alpha = 0.05 and gamma_u = 0.71, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.05 and gamma_u = 0.715, C, FD, Fn, FT, FU, I_t, I_f, K_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.72, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, u, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.725, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.73, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.735, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.74, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.745, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.75, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.755, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.76, C, FD, Fn, FT, FU, h, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, V_b, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.765, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.77, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.775, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.78, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.785, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.79, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.795, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.8, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.805, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.81, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.815, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.82, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.825, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.83, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.835, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.84, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.845, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.85, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.855, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.86, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.865, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.87, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.875, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.88, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.885, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.89, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.895, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.9, C, FD, Fn, FT, FU, h, I_t, K, L, M, NFW_h, S_h, tau, u, V_h, V_f, V_b, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.905, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.91, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.915, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.92, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.925, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.93, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.935, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, u, V_h, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.94, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, u, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.945, C, FD, Fn, FT, FU, I_t, I_f, K_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.05 and gamma_u = 0.95, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.05 and gamma_u = 0.955, NFW_h have not converged
# For alpha = 0.05 and gamma_u = 0.96, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.965, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.97, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.975, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.98, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.985, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.99, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.05 and gamma_u = 0.995, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.005, u value is  0.7164717370587597
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.01, u value is  0.7939556206404756
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.015, u value is  0.8000051158117866
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.02, u value is  0.7999841772517212
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.025, u value is  0.8000155273529672
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.03, u value is  0.7999858985964178
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.035, u value is  0.7999953655694937
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.04, u value is  0.8000228182070837
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.045, u value is  0.8000028076717872
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.05, u value is  0.7999693478328275
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.055, u value is  0.799981448060225
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.06, u value is  0.8000301997163765
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.065, u value is  0.8000514789932922
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.07, u value is  0.800008501658832
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.075, u value is  0.7999368780984145
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.08, u value is  0.799911264568249
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.085, u value is  0.7999741742774895
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.09, u value is  0.800090689667333
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.095, u value is  0.8001683286446866
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.1, u value is  0.8001234861955525
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.105, u value is  0.7999513431142667
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.11, u value is  0.7997442019069552
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.115, u value is  0.7996474990328485
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.12, u value is  0.799772755079292
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.125, u value is  0.8001169667610701
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.13, u value is  0.8005354911709189
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.135, u value is  0.8007911333864941
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.14, u value is  0.8006626286518659
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.145, u value is  0.8000736957301346
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.15, u value is  0.7991728676567307
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.155, u value is  0.798324118350931
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.16, u value is  0.7979902308798956
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.165, u value is  0.7985471249843306
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.17, u value is  0.8000931491399037
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.175, u value is  0.8023229497110858
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.18, u value is  0.8045270825831143
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.185, u value is  0.8057364903524732
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.19, u value is  0.8050130568769183
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.195, u value is  0.8018212412228655
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.2, u value is  0.796362634940788
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.205, u value is  0.7897220322599076
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.21, u value is  0.7837132087658042
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.215, u value is  0.7804603339545144
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.22, u value is  0.7818752653118827
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.225, u value is  0.7892300708834631
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.23, u value is  0.8029596565053959
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.235, u value is  0.8227287137565756
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.24, u value is  0.8478438047623842
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.245, u value is  0.8782284166108785
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.25, u value is  0.91622273357326
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.255, u value is  0.9622153125572352
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.26, u value is  0.7057379818215095
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.1 and gamma_u = 0.265, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.27, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.275, L, NFW_h have not converged
# For alpha = 0.1 and gamma_u = 0.28, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.285, L have not converged
# For alpha = 0.1 and gamma_u = 0.29, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.295, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.3, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.305, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.31, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, u, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.315, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.32, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.325, L, M, NFW_h, NFW_f, S_h, tau, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.33, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.335, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.34, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.345, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.35, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.355, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.36, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.365, NFW_h have not converged
# For alpha = 0.1 and gamma_u = 0.37, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.375, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.38, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.385, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.39, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, u, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.395, C, FD, Fn, FT, FU, h, I_t, K, L, M, NFW_h, S_h, tau, u, V_h, V_f, V_b, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.4, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.405, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.41, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.415, NFW_h have not converged
# For alpha = 0.1 and gamma_u = 0.42, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.425, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.43, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.435, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.44, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.445, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.45, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.455, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.46, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.465, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.47, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.475, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.48, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.485, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.49, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.495, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.5, NFW_h, NFW_f have not converged
# For alpha = 0.1 and gamma_u = 0.505, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.51, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.515, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.52, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.525, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.53, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.535, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.54, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.545, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.55, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.555, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.56, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.565, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.57, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.575, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.58, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.585, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.59, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.595, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.6, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.605, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.61, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.615, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.62, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.625, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.63, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.635, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.64, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.645, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.65, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.655, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.66, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.665, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.67, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.675, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.68, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.685, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.69, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.695, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.7, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.705, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.71, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.715, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.72, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.725, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.73, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.735, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.74, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.745, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.75, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.755, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.76, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.765, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.77, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.775, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.78, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.785, NFW_h, NFW_f have not converged
# For alpha = 0.1 and gamma_u = 0.79, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.1 and gamma_u = 0.795, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.1 and gamma_u = 0.8, FT, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.805, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.81, C, FD, Fn, FT, FU, I_t, I_f, K_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.815, C, FD, Fn, FT, FU, I_t, I_f, K_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.82, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.825, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.83, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.835, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.84, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.845, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, u, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.85, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.855, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.86, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.865, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.87, C, FD, Fn, FT, FU, I_t, I_f, K_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.875, C, FD, Fn, FT, FU, I_t, I_f, K_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.88, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.885, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.1 and gamma_u = 0.89, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.1 and gamma_u = 0.895, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.1 and gamma_u = 0.9, NFW_h, NFW_f have not converged
# For alpha = 0.1 and gamma_u = 0.905, NFW_h have not converged
# For alpha = 0.1 and gamma_u = 0.91, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.915, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.92, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.925, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.93, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.935, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.94, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.945, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.95, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.955, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.96, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.965, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.97, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.975, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.98, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.985, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.99, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.1 and gamma_u = 0.995, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.15 and gamma_u = 0.005, u value is  0.7162061995705259
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.01, u value is  0.793930791827655
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.015, u value is  0.8000071977839319
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.02, u value is  0.7999837642146862
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.025, u value is  0.8000161524021109
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.03, u value is  0.799985591331951
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.035, u value is  0.7999949726864443
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.04, u value is  0.8000234487353918
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.045, u value is  0.8000032101592915
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.05, u value is  0.7999680027844925
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.055, u value is  0.7999808376423476
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.06, u value is  0.8000318162617623
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.065, u value is  0.8000541060648105
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.07, u value is  0.8000086371905297
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.075, u value is  0.7999322208414008
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.08, u value is  0.7999055267497404
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.085, u value is  0.7999738698447556
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.09, u value is  0.8001000070672356
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.095, u value is  0.8001830260139077
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.1, u value is  0.8001315442460031
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.105, u value is  0.799940624325788
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.11, u value is  0.7997129119209125
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.115, u value is  0.7996101330429287
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.12, u value is  0.7997566320882968
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.125, u value is  0.8001483306525807
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.13, u value is  0.8006200892668441
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.135, u value is  0.8008998070718585
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.14, u value is  0.8007354804614625
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.145, u value is  0.8000405619367977
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.15, u value is  0.7989912072869405
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.155, u value is  0.7980165239861375
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.16, u value is  0.7976612002873857
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.165, u value is  0.7983681269131547
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.17, u value is  0.8002485711639139
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.175, u value is  0.8029329842849241
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.18, u value is  0.8055610794391924
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.185, u value is  0.8069518207112146
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.19, u value is  0.805952569314162
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.195, u value is  0.8019001086563897
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.2, u value is  0.7950457857173723
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.205, u value is  0.7867344531468555
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.21, u value is  0.7792068912936295
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.215, u value is  0.7750576885237368
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.22, u value is  0.7765836913637578
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.225, u value is  0.785295482259823
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.23, u value is  0.8017380573250789
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.235, u value is  0.8256358824803853
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.24, u value is  0.8562859866395491
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.245, u value is  0.8921221368134427
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.25, u value is  0.9135874643800448
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.15 and gamma_u = 0.255, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.26, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.265, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.27, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.275, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.28, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.285, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.29, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.295, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.15 and gamma_u = 0.3, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# ...
# For alpha = 0.75 and gamma_u = 0.3, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.305, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.31, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.315, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.32, L, M, NFW_h, NFW_f, S_h, tau, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.325, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.33, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.335, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.34, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.345, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.35, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.355, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.36, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.365, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.37, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.375, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.38, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.385, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.39, C, FT, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.395, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.4, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.405, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.41, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.415, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.42, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.425, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.43, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.435, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, u, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.44, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.445, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.45, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.455, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.46, C, FD, Fn, FT, FU, I_t, I_f, K_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.465, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.47, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.475, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.48, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.485, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.49, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, NFW_h, NFW_f, S_h, u, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.495, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.5, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.505, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.51, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.515, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.52, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.525, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.53, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.535, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.54, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.545, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.55, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.555, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.56, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.565, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.57, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.575, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.58, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.585, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.59, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.595, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.6, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.605, I_f, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.61, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.615, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, V_b, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.62, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.625, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.63, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.635, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.64, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.645, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.65, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.655, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.66, C, FD, Fn, FT, FU, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.665, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.67, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, tau, u, V_h, V_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.675, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.68, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.685, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.69, L, M, NFW_h, NFW_f, S_h, tau, V_h, V_f, V_b have not converged
# For alpha = 0.75 and gamma_u = 0.695, NFW_h have not converged
# For alpha = 0.75 and gamma_u = 0.7, NFW_h have not converged
# For alpha = 0.75 and gamma_u = 0.705, NFW_h have not converged
# For alpha = 0.75 and gamma_u = 0.71, L, NFW_h have not converged
# For alpha = 0.75 and gamma_u = 0.715, L, NFW_h have not converged
# For alpha = 0.75 and gamma_u = 0.72, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.725, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.73, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.735, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.74, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.745, I_f, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.75, I_f, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.755, I_f, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.76, I_f, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.765, I_f, L, NFW_h, NFW_f have not converged
# For alpha = 0.75 and gamma_u = 0.77, I_f, L, NFW_h, NFW_f, YD have not converged
# For alpha = 0.75 and gamma_u = 0.775, C, Fn, FT, I_f, L, NFW_h, NFW_f, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.78, C, FD, Fn, FT, FU, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.785, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.79, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.795, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.8, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.805, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.81, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.815, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.82, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.825, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.83, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.835, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.84, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.845, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.85, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.855, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.86, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.865, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.87, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.875, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.88, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.885, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.89, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.895, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.9, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.905, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.91, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.915, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.92, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.925, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.93, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.935, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.94, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.945, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.95, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.955, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.96, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.965, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.97, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.975, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.98, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.985, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.99, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, W, Y, YD have not converged
# For alpha = 0.75 and gamma_u = 0.995, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, W, Y, YD have not converged
# For alpha = 0.8 and gamma_u = 0.005, u value is  0.7118271267342343
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.8 and gamma_u = 0.01, u value is  0.7939263466822198
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.8 and gamma_u = 0.015, u value is  0.8000618319795079
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.8 and gamma_u = 0.02, u value is  0.7999710726786167
#
#  Ploting...
#
# Continuing ...
# For alpha = 0.8 and gamma_u = 0.025, u value is  0.8000415021896585
#
#  Ploting...
#
# Continuing ...

# %% [markdown]
# # Shocks

# %% [markdown]
# ## Increase in autonomous growth rate ($g_z$)

# %%
base = model()
df = SolveSFC(base, time=900)
shock = ShockModel(base_model=base, create_function=model(), variable='gz', increase=0.01, time = 900)
shock.transpose()

# %% [markdown]
# ### Plots

# %%
fig, ax = plt.subplots(2,2)

shock[["Y", "K", "I_h", "I_f"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[0,0].set_yticklabels(['{:,.1%}'.format(x) for x in ax[0,0].get_yticks()])
ax[0,0].axhline(y=shock["gz"].iloc[-1], color = "black", ls = "--", lw=1)

shock['tau'].plot(color = "darkred", title = "Capacity generating capital as % of total capital", label = "$\\tau$", legend = False, ax = ax[0,1], lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[0,1].set_yticklabels(['{:,.0%}'.format(x) for x in ax[0,1].get_yticks()])
ax[0,1].axhline(y = df['tau'].iloc[-1], ls ='--', color = "gray")


shock['u'].plot(title = 'Capacity utilization ratio', ax=ax[1,0], legend = False, color = "darkred", lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[1,0].axhline(y = shock['un'].iloc[-1], ls ='--', color = "gray")
ax[1,0].set_yticklabels(['{:,.2%}'.format(x) for x in ax[1,0].get_yticks()])

shock['h'].plot(title = 'Marginal propensity to invest', ax=ax[1,1], legend = False, color = "darkred", lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[1,1].axhline(y = df['h'].iloc[-1], ls ='--', color = "gray")

sns.despine()
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle('Increase in autonomous growth rate ($g_z$)')
plt.show()

# %% [markdown]
# ## Increase in wage-share ($\omega$)

# %%
base = model()
df = SolveSFC(base, time=900)
shock = ShockModel(base_model=base, create_function=model(), variable='omegapar', increase=0.01, time = 900)
shock.transpose()

# %%
fig, ax = plt.subplots(2,2)

shock[["Y", "K", "I_h", "I_f"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[0,0].set_ylim(0.04,0.08)
ax[0,0].set_yticklabels(['{:,.1%}'.format(x) for x in ax[0,0].get_yticks()])
ax[0,0].axhline(y=shock["gz"].iloc[-1], color = "black", ls = "--", lw=1)

shock['tau'].plot(color = "darkred", title = "Capacity generating capital as % of total capital", label = "$\\tau$", legend = False, ax = ax[0,1], lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[0,1].set_yticklabels(['{:,.0%}'.format(x) for x in ax[0,1].get_yticks()])
ax[0,1].axhline(y = df['tau'].iloc[-1], ls ='--', color = "gray")


shock['u'].plot(title = 'Capacity utilization ratio', ax=ax[1,0], legend = False, color = "darkred", lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[1,0].axhline(y = shock['un'].iloc[-1], ls ='--', color = "gray")
ax[1,0].set_yticklabels(['{:,.2%}'.format(x) for x in ax[1,0].get_yticks()])

shock['h'].plot(title = 'Marginal propensity to invest', ax=ax[1,1], legend = False, color = "darkred", lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[1,1].axhline(y = df['h'].iloc[-1], ls ='--', color = "gray")

sns.despine()
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle('Increase in autonomous growth rate ($g_z$)')
plt.show()

# %% [markdown]
# ## Increase in interest rates

# %%
base = model()
df = SolveSFC(base, time=700)
shock = ShockModel(base_model=base, create_function=model(), variable='rm', increase=0.01, time = 700)
shock.transpose()

# %%
fig, ax = plt.subplots(2,2)

shock[["Y", "K", "I_h", "I_f"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[0,0].set_ylim(0.04,0.06)
ax[0,0].set_yticklabels(['{:,.1%}'.format(x) for x in ax[0,0].get_yticks()])
ax[0,0].axhline(y=shock["gz"].iloc[-1], color = "black", ls = "--", lw=1)

shock['tau'].plot(color = "darkred", title = "Capacity generating capital as % of total capital", label = "$\\tau$", legend = False, ax = ax[0,1], lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[0,1].set_yticklabels(['{:,.0%}'.format(x) for x in ax[0,1].get_yticks()])
ax[0,1].axhline(y = df['tau'].iloc[-1], ls ='--', color = "gray")


shock['u'].plot(title = 'Capacity utilization ratio', ax=ax[1,0], legend = False, color = "darkred", lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[1,0].axhline(y = shock['un'].iloc[-1], ls ='--', color = "gray")
ax[1,0].set_yticklabels(['{:,.2%}'.format(x) for x in ax[1,0].get_yticks()])

shock['h'].plot(title = 'Marginal propensity to invest', ax=ax[1,1], legend = False, color = "darkred", lw = 3, path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
ax[1,1].axhline(y = df['h'].iloc[-1], ls ='--', color = "gray")

sns.despine()
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle('Increase in autonomous growth rate ($g_z$)')
plt.show()

# %% [markdown]
# # Finishing

# %%
print("Running time: ", datetime.now() - t1)
