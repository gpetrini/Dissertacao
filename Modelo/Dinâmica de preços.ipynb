# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
t = [i/6 for i in range(0,200)]

# %%
def Dyn(t):
    P_t = np.sin(1*t) + np.cos(1.5*t)
    return P_t
P_t = [Dyn(t[i]) for i in range(len(t))]

# %%
plt.plot(P_t[0:100])
plt.show()
