# %% [markdown]
# Time checking:

# %%
from datetime import datetime
t1 = datetime.now()

# %% [markdown]
# # Changes
#
# $$
# g_Z = \sin(\Xi)/100
# $$
# wich $\Xi$ is a parameter.

# %% [markdown]
# # Introduction
#
# Jupyter notebook for the simplest model scratch. By convention, all exogenous variables are presented with a overline line (*e.g.* $\overline a$) and the parameters are represented by greek letters (*e.g.* $\alpha$). The code in this document is executable and is strongly recommend to do the follow to ensure that the output is corrected and updated:
#
# Run time > Restart and run all...

# %% [markdown]
# ## Variables list
#
# - $C$ Consumption
# - $CG$: Capital gains
# - $FT$: Total profits
# - $FD$: Distributed profits
# - $FU$: Retained profits
# - $g_i$: Growth rate of variable $i$
# - $g^e_i$: Expected growth rate of variable $i$
# - $h$: Marginal propensity to invest
# - $I$: Total investment
# - $I_f$: Non-residential investment
# - $I_h$: Residential investment
# - $K_f$: Non-residential fixed capital
# - $K_h$: Residential capital
# - $K_{HD}$: Demand for houses
# - $K_{HU}$: Unsold houses
# - $K_H$: Houses supply
# - $L$: Loans
# - $morp$: Mortgages repayments
# - $M$: Money deposits
# - $MO$: Mortgages
# - $p_h$ Housing prices
# - $r_l$: Interest rates on Loans
# - $r_m$: Interest rates on money deposits
# - $r_H$: Housing own interest rates
# - $S_i$: Sector $i$ savings
# - $u$: Capacity utilization ratio
# - $v$: Capacity-Output ratio
# - $V_i$: Net financial Wealth of sector $i$
# - $W$ Total Wage bill
# - $Y$: GDP
# - $Y_K$: Capacity
# - $YD$: Household disposable income
# - $Z$: Autonomous expenditures

# %% [markdown]
# ## Parameters list
#
# - $\alpha$: Propensity to consume out of wages
# - $\beta$: Expectation adjustment parameter
# - $\gamma_F$: % of distributed profits
# - $\gamma_u$: Adjustment parameter for the marginal propensity to invest

# %% [markdown]
# ## Exogenous variables
#
# - $g_Z$: Autonomous grouth rate
# - $\omega$: Wage share
# - $rm$: Interest rates on money deposits
# - $spread_l$: Spread for loans
# - $spread_{mo}$: Spread for mortgages
# - $un$: Normal capacity utilization ratio
# - $v$: Capitl-Output ratio

# %% [markdown]
# # Assumptions

# %% [markdown]
# ## General
#
# - No inflation
# - Two kinds of capital: Residential and non-Residential
# - No depeciation
# - Non-residential investment is induced

# %% [markdown]
# ## Households
#
# - All savings are accumulated in bank deposits
# - Households do not have access to Loans

# %% [markdown]
# ## Firms

# %% [markdown]
# ## Banks
#
# - Have any net worth

# %% [markdown]
# # Matrix

# %% [markdown]
# ## Balance sheet
#
# |                	| Households 	|  Firms 	| Banks 	| $\sum$ 	|
# |----------------	|:----------:	|:------:	|:-----:	|:------:	|
# | Money Deposits 	|    $+M$    	|        	|  $-M$ 	|   $0$  	|
# | Loans          	|            	|  $-L$  	|  $+L$ 	|   $0$  	|
# | Mortgages          	| $-MO$           	|   	|  $+MO$ 	|   $0$  	|
# | Capital        	|    |  $K_f$ 	|       	|   $K_f$  	|
# | Houses 	|    $K_{HD}$    	| |  	|   $K_H$  	|
# | Net Worth      	|   $V_h$   	| $V_f$ 	| $V_b$      	|  $K$  	|

# %% [markdown]
# ## Transactions and flow  of funds matrix
#
# |                            	|Households             	| Households  	| Firms                  	| Firms       	| Banks                  	|  Sum    	|
# |----------------------------	|------------------------	|-------------	|------------------------	|-------------	|------------------------	|-------------	|
# |                            	| Current                	| Capital     	| Current                	| Capital     	| Current                	| $\sum$ 	|
# | Consumption                	| $-C$                   	|             	| $+C$                   	|             	|                        	|             	$0$    	|
# | Investment                 	|                  	|             	| $+I_f$                    	| $-I_f$      	|                        	|             	$0$    	|
# | Residential Investment                 	|                  	| $-I_h$            	| $+I_h$                    	|       	|                        	|             	 $0$    	|
# | **[Production]**               	|                        	|             	| **[$Y$]**                  	|             	|                        	|             	$[Y]$    	|
# | Wages                      	| $+W$                    	|             	| $-W$                   	|             	|                        	|             	$0$    	|
# | Profits                      	| $+FD$                    	|             	| $-FT$                   	| $+FU$	|                        	|             	$0$    	|
# | Interests on loans         	|                        	|             	| $-r_{l-1}\cdot L_{-1}$ 	|             	| $+r_{l-1}\cdot L_{-1}$ 	|             	$0$    	|
# | Interests on Bank deposits 	| $+r_{m-1}\cdot M_{-1}$ 	|             	|                        	|             	| $-r_{m-1}\cdot M_{-1}$ 	|             	$0$    	|
# | Interests on Mortgage 	| $-r_{mo-1}\cdot MO_{-1}$ 	|             	|                        	|             	| $+r_{mo-1}\cdot MO_{-1}$  	|             	$0$    	|
# | **Subtotal** 	| $+S_h$ 	| $-I_h$|                        	|  $+NFW_f$           	|  +$NFW_b$	|             	 $0$    	|
# | Change in Loans            	|                        	|             	|                        	| $+\Delta L$ 	|                        	 $-\Delta L$ 	|$0$    	|
# | Change in Bank deposits    	| $-\Delta M$                       	|  	|                        	|             	|                        	$+\Delta M$ 	| $0$    	|
# | Change in Mortgages    	|                        	| $+\Delta MO$ 	|                        	|             	|                        	$-\Delta MO$ 	| $0$    	|
# | Sum    	| $0$                        	| $0$ 	| $0$| $0$| $0$| $0$|

# %% [markdown]
# # Equations

# %% [markdown]
# ## General Equations
#
# $$
# Y = C + I
# \tag{1}
# $$
#
# $$
# I = I_f + I_h
# \tag{2}
# $$
#
# $$
# \omega = \overline \omega
# \tag{3}
# $$
#
# $$
# W = \omega \cdot  Y
# \tag{4}
# $$
#
# $$
# Y_K = \frac{K_f}{\overline v}
# \tag{5}
# $$
#
# $$
# u = \frac{Y}{Y_K}
# \tag{6}
# $$
#
# $$
# g_k = \frac{h\cdot u}{v}
# \tag{7}
# $$
#
# $$
# Z = I_h
# \tag{8}
# $$
#
# $$
# K = K_f + K_{HD}
# \tag{9}
# $$

# %% [markdown]
# ## Households
#
# $$
# YD = W + FD + \overline r_{m-1}\cdot M_{-1} - \overline r_{mo-1}\cdot MO
# \tag{10}
# $$
#
# $$
# S_h = YD - C = \Delta M
# \tag{11}
# $$
#
# $$
# \Delta MO = I_h
# \tag{12}
# $$
#
# $$
# C = \alpha\cdot W
# \tag{13}
# $$
#
# $$
# V_h = M + K_H - MO
# \tag{14}
# $$
#
# $$
# NFW_h = S_h - I_h
# $$

# %% [markdown]
# ## Firms
#
# $$
# \Delta L = I_f - FU
# \tag{15}
# $$
#
# $$
# FT = Y - W = FU+ FD
# \tag{16}
# $$
#
# $$
# FU = \gamma_F\cdot (FT - r_{L_{-1}}\cdot L_{-1})
# \tag{17}
# $$
#
#
# $$
# FD = (1 - \gamma_F)\cdot (FT - r_{L_{-1}}\cdot L_{-1})
# \tag{18}
# $$
#
# $$
# I_f = h\cdot Y
# \tag{19}
# $$
#
# $$
# \Delta K_f = I_f
# \tag{20}
# $$
#
# $$
# \Delta h =
# h_{-1}\cdot \gamma_u\cdot (u - \overline u_n)
# \tag{21}
# $$
#
# $$
# V_f = K_f  - L
# \tag{22}
# $$
#
# $$
# NFW_f = FU - I_f
# \tag{23}
# $$

# %% [markdown]
# ## Banks
#
# $$
# \Delta M = \Delta L + \Delta MO
# \tag{24}
# $$
#
# $$
# NFW_b = rl_{-1}\cdot L_{-1} + rmo_{-1}\cdot MO_{-1} - rm_{-1}\cdot M_{-1}
# \tag{25}
# $$
#
# $$
# r_l = r_m + spread_l (=0)
# \tag{26}
# $$
#
# $$
# r_{mo} = r_m + spread_{mo} (=0)
# \tag{27}
# $$
#
# $$
# V_b = L + MO - M
# \tag{28}
# $$

# %% [markdown]
# ## Residential Investment
#
#
# $$
# K_{HS} = K_{HD}
# \tag{29}
# $$
#
# $$
# I_h^S = I_h
# $$
#
# $$
# \Delta K_{HD} = I_h
# \tag{30}
# $$
#
# $$
# I_h = (1+g_{Ih_{t-1}})\cdot I_{h_{t-1}}
# \tag{31}
# $$
#
# $$
# g_{I_h} = \overline g_{I_h}
# \tag{32}
# $$
#
# $$
# \tau = \frac{K_f}{K}
# $$

# %% [markdown]
# # Simulation setup

# %% [markdown]
# ## Installing required packages

# %%
# !pip install pysolve3
# Out:
# Requirement already satisfied: pysolve3 in /usr/local/lib/python3.6/dist-packages (0.1.5)
# Requirement already satisfied: sympy>=1.4 in /usr/local/lib/python3.6/dist-packages (from pysolve3) (1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pysolve3) (1.16.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pysolve3) (0.24.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy>=1.4->pysolve3) (1.1.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->pysolve3) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas->pysolve3) (2.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.5.0->pandas->pysolve3) (1.12.0)

# %% [markdown]
# ## Loading libraries

# %%
# %config InlineBackend.figure_format = 'retina'

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import matplotlib.patheffects as pe
import seaborn as sns
from pysolve3.utils import ShockModel, SFCTable, SolveSFC, SummaryShock
from pysolve3.model import Model
import sympy as sp
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# # Creating model function

# %%
def model():
  model = Model()
  model.set_var_default(0) 
  model.var('C', desc='Consumption')
  model.var('FD', desc='Distributed profits')
  model.var('Fn', desc='Net profits')
  model.var('FT', desc='Total Profits')
  model.var('FU', desc='Retained profits')
  model.var('gk', desc='Capital growth rate', default=0.01)
  model.var('g_Ih', desc='Residential investment growth rate (Demand)', default = 0.05)
  model.var('g_Z', desc='Autonomous growth rate', default = 0.025)
  model.var('h', desc='Marginal propensity to invest (non-residential)', default=0.30)
  model.var('I_t', desc='Investment', default = 100) # 200
  model.var('I_f', desc='Non-residential investment') # 100
  model.var('I_h', desc='Residential investment', default = 100) # 100
  model.var('Is', desc='Residential investment (Supply)', default = 100) # 100
  model.var('K_HS', desc='Houses supply', default=500) # 500
  model.var('K_HD', desc='Houses demand', default=500) # 500
  model.var('K_f', desc='Non-residential capital', default = 1000) # 10000
  model.var('K', desc='Capital', default=1500)
  model.var('L', desc='Loans') # 100
  model.var('M', desc='Money deposits', default = 305) # 300
  model.var('MO', desc='Mortgages', default = 305) # 200
  model.var('NFW_h', desc='Households Net Financial Wealth')
  model.var('NFW_f', desc='Firms Net Financial Wealth')
  model.var('NFW_b', desc='Banks Net Financial Wealth')
  model.var('omega', desc='Wage-share', default = 0.5)
  model.var('rl', desc='Interests rates on loans')
  model.var('rmo', desc='Interests rates on mortgages')
  model.var('S_h', desc='Households savings', default = 100)
  model.var('tau', desc="% of Kf in total")
  model.var('u', desc='Capacity utilization ratio', default=0.7)
  model.var('V_h', desc='Household net financial wealth', default = 500)
  model.var('V_f', desc='Firms net financial wealth', default = 1000)
  model.var('V_b', desc='Banks net financial wealth')
  model.var('W', desc='Wages')
  model.var('Xi', desc='Autonomous grouth rate parameter', default=0.0005)
  model.var('Y', desc='GDP')
  model.var('Yk', desc='Capacity')
  model.var('YD', desc='Household disposable income')
  model.var('Z', desc='Autonomous expenditures')
  
  model.var('Debt_H', desc='Housesold indebtness')
  model.var('Debt_F', desc='Firm indebtness')
  model.var('Depo', desc='Households deposits income')
  
  model.param('alpha', desc='Propensity to consume out of wages', default=1) # 0.7
  model.param('gamma_F', desc='% of undistributed profits', default=0.4) # 0.4
  model.param('gamma_u', desc='Adjustment parameter for the marginal propensity to invest', default=0.01) # 0.01
  model.param('omegapar', desc='Wage-share', default=0.5) # 0.5
  model.param('rm', desc='Interest rates on money deposits', default=0.02) # 0.02
  model.param('spread_l', desc='Spread for loans', default=0) # 0.01
  model.param('spread_mo', desc='Spread for mortgages', default=0) # 0.005
  model.param('un', desc='Normal capacity utilization ratio', default=0.8) # 0.8
  model.param('v', desc='Capitl-Output ratio', default=2.5) # 2.5
  
  
  # General equations
  model.add('Y = C + I_t') # Eq1
  model.add('I_t = I_f + I_h') # Eq2
  model.add('omega = omegapar') # Eq 3
  model.add('Yk = K_f(-1)/v') # Eq 4
  model.add('u = Y/Yk') # Eq 5
  model.add('W = omega*Y') # Eq 6
  model.add('gk = h*u/v') # Eq 7
  model.add('K = K_HD + K_f') # Eq 8
  model.add('Z = I_h') # Eq 9
  
  # Household equations
  model.add('YD = W + FD + rm*M(-1) - rmo*MO(-1)') # Eq 10
  model.add('S_h = YD - C') # Eq 11
  model.add('d(MO) = I_h') # Eq 12
  model.add('C = alpha*W') # Eq 13
  model.add('V_h = M + K_HD - MO') # Eq 14
  model.add('NFW_h = S_h - I_h')
  
  # Firms
  model.add('d(L) = I_f - FU') # Eq 15
  model.add('FT = (1-omega)*Y') # Eq 16
  model.add('Fn = FT -rl*L(-1)')
  model.add('FU = gamma_F*(Fn)') # Eq 17
  model.add('FD = (1 - gamma_F)*(Fn)') # Eq 18
  model.add('I_f = h*Y') # Eq 19
  model.add('d(K_f) = I_f') # 20
  model.add('h = h(-1)*gamma_u*(u-un) + h(-1)') # Eq 21 # Version without corridor
  model.add('V_f = K_f - L') # Eq 22
  model.add('NFW_f = FU - I_f') # Eq 23
  
  # Banks
  model.add('d(M) = d(L) + d(MO)') # Eq 24
  model.add('rmo = rm + spread_mo') # Eq 25
  model.add('rl = rm + spread_l') # Eq 26
  model.add('V_b = L + MO - M') # Eq 27
  model.add('NFW_b = rl*L(-1) + rmo*MO(-1) - rm*M(-1)') # Eq 28
  
  # Residential investment
  model.add('K_HS = K_HD') # Eq 29
  model.add('Is = I_h')
  model.add('d(K_HD) = I_h') # Eq 30
  model.add('I_h = (1+g_Ih(-1))*I_h(-1)') # Eq 31
  model.add('g_Ih = g_Z') # Eq 32
  model.add('tau = K_f(-1)/K(-1)')
  
  # Cycle
  model.add('Xi = sin(Xi(-1)*100000)')
  model.add('g_Z = Xi/10 + 0.05')
  
  # Aditionals
  model.add('Debt_H = rmo*MO(-1)/YD')
  model.add('Debt_F = rl*L(-1)/FU')
  model.add('Depo = rm*M(-1)/YD')
  return model

# %% [markdown]
# # Evaluating consistenty

# %%
test = model()
SolveSFC(test, time=500, table = False)
evaldf = pd.DataFrame({
    'Households' : test.evaluate('M - MO + K_HD - V_h'),
    'Firms' : test.evaluate('K_f - L - V_f'),
    'Banks' : test.evaluate('L + MO - M - V_b'),
    'Mortgages' : test.evaluate('MO(-1) - MO(-2) - I_h(-1)'),
    'Financial assets' : test.evaluate('d(MO) + d(L) - d(M)'),
    '[Total Financial Wealth - K]' : test.evaluate('V_f + V_h + V_b - K'),
    "Firm's Funds" : test.evaluate('L(-1) - L(-2) - I_f(-1) + FU(-1)'),
    "Housing" : test.evaluate('K_HD - K_HS'),
    "[Net Financial Wealth]" : test.evaluate('NFW_h + NFW_f + NFW_b'),
    "Investment" : test.evaluate('I_t - I_h - I_f'),
    "Profits" : test.evaluate('FT(-1) - rl*L(-2) - FU(-1) - FD(-1)'),
    "Wages" : test.evaluate('W - omega*Y')
}, index = ['Sum'])
evaldf = evaldf.transpose()
evaldf.round(5)
# Out:
#                                   Sum
# Households                   -0.00047
# Firms                         0.00000
# Banks                         0.00000
# Mortgages                     0.00000
# Financial assets              0.00000
# [Total Financial Wealth - K]  0.00048
# Firm's Funds                  0.00024
# Housing                       0.00000
# [Net Financial Wealth]       -0.00041
# Investment                   -0.00001
# Profits                      -0.00000
# Wages                         0.00000

# %% [markdown]
# # Solving

# %%
base = model()
df = SolveSFC(base, time=50)
df.transpose()
# Out:
#                   0            1   ...            49            50
# C             0.0000   274.241024  ...  4.095529e+02  4.211338e+02
# Debt_F        0.0000     0.000000  ...  4.231029e-01  4.032006e-01
# Debt_H        0.0000     0.013902  ...  2.911355e-01  2.923970e-01
# Depo          0.0000     0.013902  ...  3.784416e-01  3.762853e-01
# FD            0.0000   164.544614  ...  2.101634e+02  2.175877e+02
# FT            0.0000   274.241024  ...  4.095529e+02  4.211338e+02
# FU            0.0000   109.696409  ...  1.401090e+02  1.450585e+02
# Fn            0.0000   274.241024  ...  3.502724e+02  3.626461e+02
# I_f           0.0000   169.244000  ...  1.004663e+02  1.001609e+02
# I_h         100.0000   105.000000  ...  3.090883e+02  3.209748e+02
# I_t         100.0000   274.243183  ...  4.095543e+02  4.211354e+02
# Is          100.0000   105.000000  ...  3.090883e+02  3.209748e+02
# K          1500.0000  1774.243183  ...  2.141824e+04  2.183938e+04
# K_HD        500.0000   605.000000  ...  1.038808e+04  1.070906e+04
# K_HS        500.0000   605.000000  ...  1.038808e+04  1.070906e+04
# K_f        1000.0000  1169.244000  ...  1.103016e+04  1.113032e+04
# L             0.0000    59.547266  ...  2.924383e+03  2.879485e+03
# M           305.0000   469.547266  ...  1.311747e+04  1.339354e+04
# MO          305.0000   410.000000  ...  1.019308e+04  1.051406e+04
# NFW_b         0.0000     0.000000  ...  0.000000e+00 -5.684342e-14
# NFW_f         0.0000   -59.547590  ...  3.964267e+01  4.489751e+01
# NFW_h         0.0000    59.545106  ... -3.964394e+01 -4.489897e+01
# S_h         100.0000   164.545106  ...  2.694444e+02  2.760758e+02
# V_b           0.0000     0.000000  ... -1.818989e-12  0.000000e+00
# V_f        1000.0000  1109.696734  ...  8.105775e+03  8.250833e+03
# V_h         500.0000   664.546896  ...  1.331247e+04  1.358854e+04
# W             0.0000   274.241024  ...  4.095529e+02  4.211338e+02
# Xi            0.0005    -0.262375  ... -1.154337e-01 -9.145952e-01
# Y             0.0000   548.482047  ...  8.191058e+02  8.422676e+02
# YD            0.0000   438.784900  ...  6.789962e+02  6.972084e+02
# Yk            0.0000   400.000000  ...  4.371876e+03  4.412063e+03
# Z             0.0000   105.000000  ...  3.090883e+02  3.209748e+02
# _I_h__1     100.0000   100.000000  ...  3.042739e+02  3.090883e+02
# _K_HD__1    500.0000   500.000000  ...  1.007899e+04  1.038808e+04
# _K__1      1500.0000  1500.000000  ...  2.100869e+04  2.141824e+04
# _K_f__1    1000.0000  1000.000000  ...  1.092969e+04  1.103016e+04
# _L__1         0.0000     0.000000  ...  2.964025e+03  2.924383e+03
# _MO__1      305.0000   305.000000  ...  9.883994e+03  1.019308e+04
# _M__1       305.0000   305.000000  ...  1.284802e+04  1.311747e+04
# _Xi__1        0.0005     0.000500  ... -3.417727e-01 -1.154337e-01
# _g_Ih__1      0.0500     0.050000  ...  1.582273e-02  3.845663e-02
# _h__1         0.3000     0.300000  ...  1.265295e-01  1.226536e-01
# alpha         1.0000     1.000000  ...  1.000000e+00  1.000000e+00
# g_Ih          0.0500     0.023763  ...  3.845663e-02 -4.145952e-02
# g_Z           0.0250     0.023763  ...  3.845663e-02 -4.145952e-02
# gamma_F       0.4000     0.400000  ...  4.000000e-01  4.000000e-01
# gamma_u       0.0500     0.050000  ...  5.000000e-02  5.000000e-02
# gk            0.0100     0.169244  ...  9.192051e-03  9.080645e-03
# h             0.3000     0.308568  ...  1.226536e-01  1.189182e-01
# omega         0.5000     0.500000  ...  5.000000e-01  5.000000e-01
# omegapar      0.5000     0.500000  ...  5.000000e-01  5.000000e-01
# rl            0.0000     0.020000  ...  2.000000e-02  2.000000e-02
# rm            0.0200     0.020000  ...  2.000000e-02  2.000000e-02
# rmo           0.0000     0.020000  ...  2.000000e-02  2.000000e-02
# spread_l      0.0000     0.000000  ...  0.000000e+00  0.000000e+00
# spread_mo     0.0000     0.000000  ...  0.000000e+00  0.000000e+00
# tau           0.0000     0.666667  ...  5.202463e-01  5.149890e-01
# u             0.7000     1.371205  ...  1.873579e-01  1.909011e-01
# un            0.8000     0.800000  ...  8.000000e-01  8.000000e-01
# v             2.5000     2.500000  ...  2.500000e+00  2.500000e+00
#
# [60 rows x 51 columns]

# %%
df[["K"]].pct_change().rolling(12).mean().plot()

# %%
fig, ax = plt.subplots(1,2)

(df['I_t']/df['Y']).plot(title = 'Investment share\nBase line', color = 'black', ax = ax[0])
ax[0].set_ylim(.45,.55)
(1 - df['omega']).plot(title = 'Marginal propensity to save\nBase line', color = 'black', ax = ax[1])
ax[1].set_ylim(.45,.55)

sns.despine()
plt.show()

# %% [markdown]
# # Baseline Plots

# %%
ax = df['K_HD'][10:].pct_change().plot(color = "black", title = "Houses growth rate", label = "$K_{HD}$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
plt.xlabel("Period")
sns.despine()
plt.show()

# %%
ax = df['tau'].plot(color = "black", title = "Capacity generating capital as % of total capital", label = "$\\tau$", legend = True)
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
plt.xlabel("Period")
sns.despine()
plt.show()

# %%
ax = df[['C', 'I_t']].apply(lambda x: x/df['Y']).plot(kind = 'area', stacked = True, legend = True, title = "Consumption and total investiment as % of GDP")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['I_f', 'I_h']].apply(lambda x: x/df['I_t']).plot(kind = 'area', stacked = True, legend = True, title = "Residential and Non-residential Investiment (as % of total investment)")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['W', 'FT']].apply(lambda x: x/df['Y']).plot(kind = 'area', stacked = True, legend = True, title = "Wage and profit share (as % of GDP)")
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[['V_b', 'V_h', 'V_f']].apply(lambda x: np.abs(x)/df['K']).plot(kind = 'area', stacked = True, title = "Net financial wealth (as % K)")
ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=1, color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
sns.despine()
plt.show()

# %%
df[["NFW_b", "NFW_h", "NFW_f"]].plot(title = "Net Financial Wealth")
sns.despine()
plt.show()

# %%
df['NFW_b'].plot(title = "Banks Net Financial Wealth")
sns.despine()
plt.show()

# %%
ax = df[["FU", "FD"]].apply(lambda x: x/df["Fn"]).plot(kind = "area", stacked = True, title = "Profits (as % net profits)")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.axhline(y = 1, color = "black", ls = "--")
sns.despine()
plt.show()

# %%
ax = df[["MO", "L"]].apply(lambda x: x/df["M"]).plot(kind = "area",stacked = False ,title = "Credit (as % Deposits)")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.axhline(y = 1, color = "blue", ls = "--")
ax.axhline(y = 0, color = "black", ls = "--")
sns.despine()
plt.show()

# %%
df["M"].plot(title = "Deposits")
sns.despine()
plt.show()

# %%
ax = df['Y'].pct_change().rolling(4).mean().plot(color = "black", title = "GDP growth rate", label = "$Y_t$", legend = True)
ax.set_yticklabels(['{:,.2%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=df["g_Z"].mean(), color = "red", ls = "--", lw=1, label = "Autonomous growth rate")
sns.despine()
plt.show()

# %%
ax = df['u'].plot(color = "black", title = "Capacity utilization ratio", label = "$u_t$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
ax = df['un'].plot(color = "red", ls="--",  title = "Capacity utilization ratio", label = "$un$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df['h'].plot(color = "black", ls="-",  title = "Marginal propensity to invest", label = "$h_t$", legend = True)
ax.set_yticklabels(['{:,.1%}'.format(x) for x in ax.get_yticks()])
sns.despine()
plt.show()

# %%
ax = df[["Y", "K", "I_h", "I_f"]][40:].pct_change().plot(title = "Growth rates")
ax.set_yticklabels(['{:,.2%}'.format(x) for x in ax.get_yticks()])
ax.axhline(y=df["g_Z"][0], color = "black", ls = "--", lw=1)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
sns.despine()
plt.show()

# %% [markdown]
# # Analytical solution

# %%
base_eq = model()
SolveSFC(base_eq, time=1, table = False)
t = sp.Symbol('t')
initials = {
    key: base_eq.evaluate(key) for key in base_eq.parameters
}
initials.update({key: base_eq.evaluate(key) for key in base_eq.variables})

# %% [markdown]
# Model variables

# %%
for i in base_eq.variables:
  globals()["_" + i] = sp.Function(i)

# %% [markdown]
# Model parameters

# %%
for i in base_eq.parameters:
  globals()[i] = sp.symbols(i, positive=True)

# %% [markdown]
# Defining equations

# %% [markdown]
# ## General equations

# %%
Y = _C(t) + _I_t(t)
I = _I_f(t) + _I_h(t)
Yk = _K_f(t-1)/v
u = _Y(t)/_Yk(t)
Z = _I_h(t)
W = _omega(t)*_Y(t)
K = _K_HD(t) + _K_f(t)

# %% [markdown]
# ## Households

# %%
C = alpha*_W(t)
YD = _W(t) + _FD(t) + rm*_M(t-1) - _rmo(t)*_MO(t-1)
S_h = _YD(t) - _C(t)
dMO = _I_h(t)
V_h = _M(t) + _K_HD(t) - _MO(t)
NFW_h = _S_h(t) - _I_h(t)

# %% [markdown]
# ## Firms

# %%
I_f = _h(t)*_Y(t)
dK_f = _I_f(t)
L = _I_f(t) - _FU(t) + _L(t-1)
FT = _FU(t) + _FD(t)
FU = gamma_F*(_FT(t) - _rl(t)*_L(t-1))
FD = (1 - gamma_F)*(_FT(t) - _rl(t)*_L(t-1))
h = _h(t-1)*gamma_u*(_u(t)-un) + _h(t-1)
NFW_f = _FU(t) - _I_f(t)
V_f = _K_f(t) - _L(t)

# %% [markdown]
# ## Banks

# %%
M = (_L(t) - _L(t-1)) + (_MO(t) - _MO(t-1)) + _M(t-1)
rmo = rm + spread_mo
rl = rm + spread_l
V_b = _L(t) + _MO(t) - _M(t)
NFW_b = _rl(t)*_L(t-1) + _rmo(t)*_MO(t-1) - rm*_M(t-1)

# %% [markdown]
# ## Residential Investment

# %%
K_HS = _K_HD(t)
Is = _I_h(t)
dK_HD = _I_h(t)
I_h = _I_h(t-1)*(1+_g_Ih(-1))
g_Ih = _g_Z(t)

# %% [markdown]
# # Rearranging

# %% [markdown]
# ## Level of GDP

# %%
EqY = Y - _Y(t)
EqY = EqY.subs(_C(t), C).subs(_I_t(t), I)
EqY = EqY.subs(_I_f(t), I_f)
EqY = EqY.subs(_W(t), W)
EqY = sp.solve(EqY, _Y(t))[0].collect(alpha).collect(omegapar)
solY = EqY
print('Y = ', solY)
print('dY/d alpha = ', EqY.diff(alpha))
print('dY/d omega = ', EqY.diff(_omega(t)))

print("\nReplacing the initial values.....")
EqY = EqY.subs(_h(t), h)
EqY = EqY.subs(alpha, df.loc[2, 'alpha']).subs(_omega(t), df.loc[2, 'omega'])
EqY = EqY.subs(un, df.loc[2, 'un']).subs(gamma_u, df.loc[1, 'gamma_u'])
EqY = EqY.subs(_u(t), df.loc[2, 'u']).subs(_h(t-1), df.loc[1, 'h'])
EqY = EqY.subs(_I_h(t), df.loc[2, 'I_h'])
print('Y0 = ', df.loc[1, 'Y'])
print('Y1 = ', EqY)
print('hat Y - Y1 = ', df.loc[2, "Y"] - EqY)
# Out:
# Y =  -I_h(t)/(alpha*omega(t) + h(t) - 1)
# dY/d alpha =  I_h(t)*omega(t)/(alpha*omega(t) + h(t) - 1)**2
# dY/d omega =  alpha*I_h(t)/(alpha*omega(t) + h(t) - 1)**2
#
# Replacing the initial values.....
# Y0 =  529.1361556137123
# Y1 =  530.533455987080
# hat Y - Y1 =  -0.0128021362378377

# %% [markdown]
# $$
# Y_{SR} =  \frac{-I_h(t)}{\alpha\cdot \omega + h(t) - 1}
# $$
#
# Rearranging
#
# $$
# Y_{SR} =  \frac{I_h(t)}{1 - \alpha\cdot \omega - h(t)}
# $$

# %% [markdown]
# ## Growth rate

# %%
gY, h_, g_Z = sp.symbols('gY h g_Z')
gY_ = omegapar*gY + h_*gY + h + (_Z(t)/_Y(t))*g_Z - gY - _h(t-1)
print(gY_)
gY_ = gY_.subs(_Y(t), _Z(t)*solY/_I_h(t))
print(gY_)
gY_ = gY_.collect(g_Z)
print("gY = ", sp.solve(gY_, gY)[0])
# Out:
# gY*h + gY*omegapar - gY + g_Z*Z(t)/Y(t) + gamma_u*(-un + u(t))*h(t - 1)
# gY*h + gY*omegapar - gY - g_Z*(alpha*omega(t) + h(t) - 1) + gamma_u*(-un + u(t))*h(t - 1)
# gY =  (alpha*g_Z*omega(t) + g_Z*h(t) - g_Z + gamma_u*un*h(t - 1) - gamma_u*h(t - 1)*u(t))/(h + omegapar - 1)

# %% [markdown]
# ## Capacity output ratio (short-run)

# %% [markdown]
# $$
# \frac{Y}{K(-1)} = \frac{Y}{K(-1)}\frac{Yk}{Yk} = \frac{u}{v}
# $$
#
# $$
# \therefore u = \frac{Y}{K(-1)}v
# $$
#
# $$
# i_{h_t} = \frac{I_h}{K_{t-1}}
# $$
#
# $$
# K(-1) = (1+g_K(-1))\cdot K(-2)
# $$

# %%
Equ = Y - _Y(t)
Equ = Equ.subs(_C(t), _C(t)*v/_K_f(t-1)).subs(_I_t(t), _I_t(t)*v/_K_f(t-1)).subs(_Y(t), _u(t))
Equ = Equ.subs(_C(t), C).subs(_I_t(t), I)
Equ = Equ.subs(_I_f(t), I_f)
Equ = Equ.subs(_W(t), W)
Equ = Equ.expand()
Equ = Equ.subs(_Y(t)/_K_f(t-1), _u(t)/v)
i_h = sp.Function('i_h')
Equ = Equ.subs(_I_h(t)/_K_f(t-1), i_h(t))
Equ = Equ.collect(_u(t))
Equ = Equ.subs(_W(t), W)
Equ = sp.solve(Equ, _u(t))[0].factor().collect(alpha*omegapar).collect(_h(t)).collect(1+_gk(t-1))
Equ = Equ.subs(_I_h(t)/_K_f(t-1), i_h(t))
solu = Equ.collect(alpha**2).collect(omegapar).collect(_YD(t)).collect(alpha)
Equ = Equ.subs(_Y(t), EqY)
print('u = ', solu)
print('\nDerivatives')
print('du/d alpha = ', Equ.diff(alpha))
print('du/d omega = ', Equ.diff(omegapar))

print("\nReplacing the initial values.....")
Equ = Equ.subs(alpha, df.loc[1,'alpha']).subs(_omega(t), df.loc[1,'omega']).subs(alpha, df.loc[1,'alpha'])
Equ = Equ.subs(_gk(t-1), df.loc[0,'gk']).subs(_h(t), df.loc[1,'h']).subs(v, df.loc[1,'v'])
Equ = Equ.subs(i_h(t), df.loc[1,'I_h']/df.loc[0,'K_f']).subs(_YD(t), df.loc[1, 'YD'])

print('u0 = ', df.loc[0,'u'].round(3))
print('u1 = ', Equ)
print("hat u - u1 = ", (df.loc[1,'u'] - Equ))
# Out:
# u =  -v*i_h(t)/(alpha*omega(t) + h(t) - 1)
#
# Derivatives
# du/d alpha =  v*i_h(t)*omega(t)/(alpha*omega(t) + h(t) - 1)**2
# du/d omega =  0
#
# Replacing the initial values.....
# u0 =  0.7
# u1 =  1.32287478551251
# hat u - u1 =  -3.43964782343331e-5

# %%
sp.latex(solu).replace("omegapar", "\\omega")
solu
# Out:
# -v*i_h(t)/(alpha*omega(t) + h(t) - 1)

# %% [markdown]
# $$
# u_{SR} =
# - \frac{v \operatorname{i_{h}}{\left (t \right )}}{\alpha \omega + h{\left (t \right )} - 1}
# $$

# %% [markdown]
# Rerranging
#
# $$
# u_{SR} =  \frac{v\cdot i_h(t)}{1 - \alpha\cdot \omega - h(t)}
# $$

# %% [markdown]
# Consider $\tau$ as the fraction between capacity generating capital and total capital (including households' capital):
#
# $$
# \tau = \frac{K_f}{K}
# $$
#
# The capacity utilization ration can be definede as:
#
# $$
# u = \frac{Y\cdot v}{K \cdot \tau}
# $$

# %% [markdown]
# So, dividing Y by houseolds' capital is the same as:
#
# $$
# \frac{Y}{(1-\tau)\cdot K}
# $$
#
# Multiplying by $v$:
#
#
# $$
# \frac{Y}{(1-\tau)\cdot K}\cdot v = \frac{Y\cdot v}{K}\cdot \left(\frac{1}{1-\tau}\right)
# $$
#
# Multiplying and dividing by $\tau$:
#
# $$
# \frac{Y\cdot v}{K\cdot \tau}\cdot \left(\frac{\tau}{1-\tau}\right) = u \cdot \left(\frac{\tau}{1-\tau}\right)
# $$
#
# Therefore,
#
# $$
# Y\frac{v}{K_h} =  u \cdot \left(\frac{\tau}{1-\tau}\right)
# $$

# %%
tau = sp.Symbol('tau')
solY = solY.subs(_I_h(t), _I_h(t)*v/_K_HD(t)).subs(_I_h(t)/_K_HD(t), g_Z)
solY = solY - _u(t)*((tau)/(1-tau))

# %%
u_SR = sp.solve(solY, _u(t))[0]
print(sp.latex(u_SR))
# Out:
# \frac{g_{Z} v \left(\tau - 1\right)}{\tau \left(\alpha \omega{\left(t \right)} + h{\left(t \right)} - 1\right)}

# %% [markdown]
# $$
# u_{SR} = \frac{g_Z v \left(\tau - 1\right)}{\tau \left(\alpha \omega{\left (t \right )} + h{\left (t \right )} - 1\right)}
# $$

# %% [markdown]
# $$
# \tau = \frac{g_Z v \left(\tau - 1\right)}{u_{SR} \left(\alpha \omega{\left (t \right )} + h{\left (t \right )} - 1\right)}
# $$
#
# $$
# \frac{\tau}{1-\tau} = \frac{g_Z v}{u_{SR} \left(1-\alpha \omega{\left (t \right )} - h{\left (t \right )}\right)}
# $$
#
# $$
# \frac{K_f}{K_H} = \frac{g_Z v}{u_{SR} \left(1-\alpha \omega{\left (t \right )} - h{\left (t \right )}\right)}
# $$

# %%
Equ = u_SR
print('u = ', Equ)
print('\nDerivatives')
print('du/d alpha = ', Equ.diff(alpha))
print('du/d omega = ', Equ.diff(omegapar))
print('du/d tau = ', Equ.diff(tau))

print("\nReplacing the initial values.....")
Equ = Equ.subs(alpha, df.loc[20,'alpha']).subs(_omega(t), df.loc[20,'omega']).subs(alpha, df.loc[20,'alpha'])
Equ = Equ.subs(_h(t), df.loc[20,'h']).subs(v, df.loc[20,'v'])
Equ = Equ.subs(tau, df.loc[20,'tau']).subs(g_Z, df.loc[19, 'g_Z'])

print('u0 = ', df.loc[0,'u'].round(3))
print('u1 = ', Equ)
print("hat u - u1 = ", (df.loc[21,'u'] - Equ))
# Out:
# u =  g_Z*v*(tau - 1)/(tau*(alpha*omega(t) + h(t) - 1))
#
# Derivatives
# du/d alpha =  -g_Z*v*(tau - 1)*omega(t)/(tau*(alpha*omega(t) + h(t) - 1)**2)
# du/d omega =  0
# du/d tau =  g_Z*v/(tau*(alpha*omega(t) + h(t) - 1)) - g_Z*v*(tau - 1)/(tau**2*(alpha*omega(t) + h(t) - 1))
#
# Replacing the initial values.....
# u0 =  0.7
# u1 =  -0.0661385850888514
# hat u - u1 =  0.350876785159445

# %% [markdown]
# # Medium run
#
# $$
# \Delta h_t = h_{t-1}\cdot \gamma_u\cdot (u_t - un)
# $$

# %%
Y_MR = solY
Y_MR = Y_MR.subs(_h(t), h).collect(_h(t-1))
print("Y_MR = ", sp.latex(Y_MR))
# Out:
# Y_MR =  - \frac{g_{Z} v}{\alpha \omega{\left(t \right)} + \left(\gamma_{u} \left(- un + u{\left(t \right)}\right) + 1\right) h{\left(t - 1 \right)} - 1} - \frac{\tau u{\left(t \right)}}{1 - \tau}

# %% [markdown]
# $$
# Y_{MR} =  - \frac{g_Z v}{\alpha \omega{\left (t \right )} + \gamma_{u} \left(- un + u{\left (t \right )}\right) h{\left (t - 1 \right )} + h{\left (t - 1 \right )} - 1} - \frac{\tau u{\left (t \right )}}{- \tau + 1}
# $$

# %%
u_MR = Y_MR
soluMR = sp.solve(u_MR, _u(t))[0]
soluMR
# Out:
# (tau*(-alpha*omega(t) + gamma_u*un*h(t - 1) - h(t - 1) + 1) - sqrt(tau*(alpha**2*tau*omega(t)**2 - 2*alpha*gamma_u*tau*un*h(t - 1)*omega(t) + 2*alpha*tau*h(t - 1)*omega(t) - 2*alpha*tau*omega(t) + 4*g_Z*gamma_u*tau*v*h(t - 1) - 4*g_Z*gamma_u*v*h(t - 1) + gamma_u**2*tau*un**2*h(t - 1)**2 - 2*gamma_u*tau*un*h(t - 1)**2 + 2*gamma_u*tau*un*h(t - 1) + tau*h(t - 1)**2 - 2*tau*h(t - 1) + tau)))/(2*gamma_u*tau*h(t - 1))

# %% [markdown]
# $$
# u_{MR} =
# \frac{1}{2 \gamma_{u} h{\left (t - 1 \right )}} \left(- \alpha \omega{\left (t \right )} + \gamma_{u} un h{\left (t - 1 \right )} - \sqrt{\alpha^{2} \omega^{2}{\left (t \right )} - 2 \alpha \gamma_{u} un h{\left (t - 1 \right )} \omega{\left (t \right )} + 2 \alpha h{\left (t - 1 \right )} \omega{\left (t \right )} - 2 \alpha \omega{\left (t \right )} + \gamma_{u}^{2} un^{2} h^{2}{\left (t - 1 \right )} - 2 \gamma_{u} un h^{2}{\left (t - 1 \right )} + 2 \gamma_{u} un h{\left (t - 1 \right )} - 4 \gamma_{u} v h{\left (t - 1 \right )} \operatorname{i_{h}}{\left (t \right )} + h^{2}{\left (t - 1 \right )} - 2 h{\left (t - 1 \right )} + 1} - h{\left (t - 1 \right )} + 1\right)
# $$

# %% [markdown]
# # Long run

# %%
Y_LR = Y_MR.subs(_u(t), un)
Y_LR = Y_LR.subs(_h(t-1), _h(t))
Y_LR
# Out:
# -g_Z*v/(alpha*omega(t) + h(t) - 1) - tau*un/(1 - tau)

# %% [markdown]
# $$- \frac{\operatorname{I_{h}}{\left (t \right )}}{\alpha \omega{\left (t \right )} + h{\left (t \right )} - 1}$$

# %%
u_LR = u_MR.subs(_h(t), h)
u_LR = u_LR.subs(_u(t), un)
u_LR
# Out:
# -g_Z*v/(alpha*omega(t) + h(t - 1) - 1) - tau*un/(1 - tau)

# %% [markdown]
# $$- un - \frac{v \operatorname{i_{h}}{\left (t \right )}}{\alpha \omega{\left (t \right )} + h{\left (t - 1 \right )} - 1}$$

# %% [markdown]
# # Sensibility test

# %% [markdown]
# ## Test for $\gamma_u$

# %%
gamma_ufor = [i/1000 for i in range(5,1000,5)]

parametric = True
if parametric == True:
  for i in gamma_ufor:
    gamma_model = model()
    try:
      gamma_model.set_values({
          'gamma_u' : i
      })

      gammadf = SolveSFC(gamma_model, time = 1000)
      print("For gamma_u = {}, GDP value is".format(i), gammadf['Y'].iloc[-1])
      print("\n Ploting...\n")
      fig, ax = plt.subplots()
      gammadf['u'].plot(ax = ax)
      ax.axhline(y = gammadf['u'].mean(), color = 'red')
      sns.despine()
      plt.show()
      plt.clf()

      if (gammadf['Y'].iloc[-1] < 0):
        break
        print("GDP is negative")

      print("Continuing ...")
    except Exception as e:
      print("For gamma_u = {},",e)
      pass
else: pass
# Out:
# For gamma_u = 0.005, GDP value is 2.6483093115753485e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.01, GDP value is 2.577665805293746e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.015, GDP value is 2.5311056619172596e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.02, GDP value is 2.484326481394455e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.025, GDP value is 2.4385761970769845e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.03, GDP value is 2.401785260569033e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.035, GDP value is 2.379103905153947e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.04, GDP value is 2.3724280163072486e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.045, GDP value is 2.383137519724726e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.05, GDP value is 2.4140319819379025e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.055, GDP value is 2.469912769091532e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = 0.06, GDP value is 2.5561453946503535e+21
#
#  Ploting...
# Continuing ...
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, NFW_h have not converged
# For gamma_u = {}, L, NFW_h, NFW_f have not converged
# For gamma_u = {}, C, FD, Fn, FT, I_f, L, NFW_h, NFW_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, L, M, NFW_h, NFW_f, S_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, L, M, NFW_h, NFW_f, S_h, V_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD, Debt_H, Depo have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD, Debt_H, Depo have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD, Debt_H, Depo have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD, Debt_H, Depo have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, gk, h, I_t, I_f, K_f, K, L, M, NFW_h, NFW_f, S_h, u, V_h, V_f, W, Y, YD have not converged
# For gamma_u = {}, C, FD, Fn, FT, FU, h, NFW_h, NFW_f, S_h, u, V_h, V_f, V_b, W, Y, YD have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged
# For gamma_u = {}, L, M, NFW_h, NFW_f, S_h, V_h, V_f, V_b have not converged

# %% [markdown]
# ## Test for $\alpha$

# %%
alpha_for = [i/100 for i in range(5,100,5)]

parametric = False
if parametric == True:
  for i in alpha_for:
    mod = model()
    try:
      mod.set_values({
          'alpha' : i
      })

      df = SolveSFC(mod)
      print("For alpha = {}, GDP value is".format(i), df['Y'].iloc[-1])
      print("\n Ploting...\n")
      df['u'].plot()
      plt.show()
      plt.clf()

      if (df['Y'].iloc[-1] < 0):
        break
        print("GDP is negative")

      print("Continuing ...")
    except Exception as e:
      print("For alpha = {},", e)
      pass
else: pass

# %% [markdown]
# ## Testing for $\alpha$ and $\gamma_u$

# %%
#parametric = False
#if parametric == True:
#  alpha_for = [i/100 for i in range(5,105,5)]
#  gamma_ufor = [i/1000 for i in range(5,1000,5)]
#
#  for i in alpha_for:
#    for j in gamma_ufor:
#      mod = model()
#      try:
#        mod.set_values({
#            'alpha' : i,
#            'gamma_u': j
#        })
#
#        df = SolveSFC(mod)
#        print("For alpha = {} and gamma_u = {}, u value is ".format(i,j), df['u'].iloc[-1])
#
#        if (df['Y'].iloc[-1] < 0):
#          break
#          print("GDP is negative")
#
#        print("Continuing ...")
#      except Exception as e:
#        print("For alpha = {} and gamma_u = {},".format(i,j), e)
#        pass
#else: pass

# %% [markdown]
# # Shocks

# %% [markdown]
# ## Increase in autonomous growth rate ($g_z$)

# %% [markdown]
# ## Increase in wage-share ($\omega$)

# %%
base = model()
df = SolveSFC(base, time=700)
shock = ShockModel(base_model=base, create_function=model(), variable='omegapar', increase=0.07, time = 900)
shock.transpose()
# Out:
#                     0             1    ...           949           950
# C          8.797086e+01  8.884601e+01  ...  1.337193e+02  1.350343e+02
# Debt_F    -2.609450e+00 -2.609709e+00  ... -2.500065e+00 -2.500065e+00
# Debt_H     1.208744e+00  1.200933e+00  ...  1.786757e-03  1.773867e-03
# Depo       3.349568e+00  3.341061e+00  ...  2.501473e+00  2.501460e+00
# FD        -1.205626e+03 -1.214750e+03  ... -2.324556e+06 -2.343152e+06
# FT         8.797086e+01  8.884601e+01  ...  1.008760e+02  1.018680e+02
# FU        -8.037510e+02 -8.098332e+02  ... -1.549704e+06 -1.562101e+06
# Fn        -2.009377e+03 -2.024583e+03  ... -3.874260e+06 -3.905253e+06
# I_f        2.897162e-01  2.903443e-01  ...  2.568712e-04  2.574243e-04
# I_h        8.768202e+01  8.855657e+01  ...  1.008747e+02  1.018689e+02
# I_t        8.797174e+01  8.884691e+01  ...  1.008750e+02  1.018692e+02
# Is         8.768202e+01  8.855657e+01  ...  1.008747e+02  1.018689e+02
# K          7.449308e+04  7.458193e+04  ...  1.538037e+05  1.539056e+05
# K_HD       5.949255e+04  5.958111e+04  ...  1.387640e+05  1.388659e+05
# K_HS       5.949255e+04  5.958111e+04  ...  1.387640e+05  1.388659e+05
# K_f        1.500053e+04  1.500082e+04  ...  1.503967e+04  1.503967e+04
# L          1.056715e+05  1.064816e+05  ...  1.952678e+08  1.968299e+08
# M          1.649690e+05  1.658677e+05  ...  1.954063e+08  1.969685e+08
# MO         5.929755e+04  5.938611e+04  ...  1.385690e+05  1.386709e+05
# NFW_b      0.000000e+00  0.000000e+00  ...  4.656613e-10  0.000000e+00
# NFW_f     -8.040407e+02 -8.101236e+02  ... -1.549704e+06 -1.562101e+06
# NFW_h      8.040402e+02  8.101230e+02  ...  1.549704e+06  1.562101e+06
# S_h        8.917222e+02  8.986796e+02  ...  1.549805e+06  1.562203e+06
# V_b       -7.275958e-12  1.455192e-11  ... -4.802132e-09  3.288733e-09
# V_f       -9.067092e+04 -9.148076e+04  ... -1.952527e+08 -1.968148e+08
# V_h        1.651640e+05  1.660627e+05  ...  1.954065e+08  1.969687e+08
# W          8.797086e+01  8.884601e+01  ...  1.337193e+02  1.350343e+02
# Xi         9.974001e-01  6.652886e-01  ...  9.855663e-01 -9.873804e-01
# Y          1.759417e+02  1.776920e+02  ...  2.345953e+02  2.369023e+02
# YD         9.796922e+02  9.875247e+02  ...  1.549939e+06  1.562338e+06
# Yk         6.000096e+03  6.000212e+03  ...  6.015867e+03  6.015867e+03
# Z          8.768202e+01  8.855657e+01  ...  1.008747e+02  1.018689e+02
# _I_h__1    8.768202e+01  8.768202e+01  ...  1.017241e+02  1.008747e+02
# _K_HD__1   5.949255e+04  5.949255e+04  ...  1.386632e+05  1.387640e+05
# _K__1      7.449308e+04  7.449308e+04  ...  1.537028e+05  1.538037e+05
# _K_f__1    1.500053e+04  1.500053e+04  ...  1.503967e+04  1.503967e+04
# _L__1      1.056715e+05  1.056715e+05  ...  1.937181e+08  1.952678e+08
# _MO__1     5.929755e+04  5.929755e+04  ...  1.384682e+05  1.385690e+05
# _M__1      1.649690e+05  1.649690e+05  ...  1.938565e+08  1.954063e+08
# _Xi__1     9.974001e-01  9.974001e-01  ... -8.349585e-01  9.855663e-01
# _g_Ih__1   9.974001e-03  9.974001e-03  ... -8.349585e-03  9.855663e-03
# _h__1      1.646660e-03  1.646660e-03  ...  1.103351e-06  1.094955e-06
# alpha      1.000000e+00  1.000000e+00  ...  1.000000e+00  1.000000e+00
# g_Ih       9.974001e-03  6.652886e-03  ...  9.855663e-03 -9.873804e-03
# g_Z        9.974001e-03  6.652886e-03  ...  9.855663e-03 -9.873804e-03
# gamma_F    4.000000e-01  4.000000e-01  ...  4.000000e-01  4.000000e-01
# gamma_u    1.000000e-02  1.000000e-02  ...  1.000000e-02  1.000000e-02
# gk         1.931411e-05  1.935560e-05  ...  1.707958e-08  1.711635e-08
# h          1.646660e-03  1.633975e-03  ...  1.094955e-06  1.086626e-06
# omega      5.000000e-01  5.000000e-01  ...  5.700000e-01  5.700000e-01
# omegapar   5.000000e-01  5.000000e-01  ...  5.700000e-01  5.700000e-01
# rl         2.000000e-02  2.000000e-02  ...  2.000000e-02  2.000000e-02
# rm         2.000000e-02  2.000000e-02  ...  2.000000e-02  2.000000e-02
# rmo        2.000000e-02  2.000000e-02  ...  2.000000e-02  2.000000e-02
# spread_l   0.000000e+00  0.000000e+00  ...  0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00  0.000000e+00  ...  0.000000e+00  0.000000e+00
# tau        2.016023e-01  2.013681e-01  ...  9.784899e-02  9.778482e-02
# u          2.932315e-02  2.961429e-02  ...  3.899609e-02  3.937958e-02
# un         8.000000e-01  8.000000e-01  ...  8.000000e-01  8.000000e-01
# v          2.500000e+00  2.500000e+00  ...  2.500000e+00  2.500000e+00
#
# [60 rows x 951 columns]

# %%
fig, ax = plt.subplots(2,2)

shock[["Y"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                  ls = ('--'),
                                                  )
shock[["K"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                  ls = ('-'),
                                                  )
shock[["I_h"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                  ls = (':'),
                                                  )
shock[["I_f"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                  ls = ('-.'),
                                                  )
ax[0,0].set_ylim(0.04,0.065)
ax[0,0].axhline(y=shock["g_Z"].iloc[-1], color = "black", ls = "--", lw=1)
#ax[0,0].set_yticklabels(['{:,.1%}'.format(x) for x in ax[0,0].get_yticks()])
ax[0,0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.06),
               labels = ["$Y$", "$K$", "$I_h$", "$I_f$"],
          fancybox=True, shadow=True, ncol=2)

shock['tau'].plot(color = "darkred", title = "Capacity generating capital \nas % of total capital", label = "$\\tau$", legend = False, ax = ax[0,1], lw = 3, )
ax[0,1].set_ylim(0.30,0.40)
ax[0,1].axhline(y = df['tau'].iloc[-1], ls ='--', color = "gray")
#ax[0,1].set_yticklabels(['{:,.3%}'.format(x) for x in ax[0,1].get_yticks()])


shock['u'].plot(title = 'Capacity utilization ratio', ax=ax[1,0], legend = False, color = "darkred", lw = 3, )
ax[1,0].axhline(y = shock['un'].iloc[-1], ls ='--', color = "gray")
ax[1,0].set_ylim(0.75,0.95)
#ax[1,0].set_yticklabels(['{:,.2%}'.format(x) for x in ax[1,0].get_yticks()])

shock['h'].plot(title = 'Marginal propensity to invest', ax=ax[1,1], legend = False, color = "darkred", lw = 3, )
ax[1,1].axhline(y = df['h'].iloc[-1], ls ='--', color = "gray")
ax[1,1].set_ylim(0.15,0.25)
sns.despine()
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
#fig.suptitle('Increase in wage-share ($\omega$)')
plt.show()



fig.savefig('Shock_2.png', dpi = 300)

# %%
fig, ax = plt.subplots(1,2)

(shock['I_t']/shock['Y']).plot(title = 'Investment share\nShock in $\omega$', color = 'black', ax = ax[0])
ax[0].set_ylim(.4,.5)
(1 - shock['omega']).plot(title = 'Marginal propensity to save\nShock in $\omega$', color = 'black', ax = ax[1])
ax[1].set_ylim(.4,.5)

sns.despine()
plt.show()

# %% [markdown]
# ## Increase in interest rates

# %%
base = model()
df = SolveSFC(base, time=1000)
shock = ShockModel(base_model=base, create_function=model(), variable='rm', increase=0.005, time = 1000)
shock.transpose()
# Out:
#                    0             1     ...          1049          1050
# C          7.609899e+01  7.592441e+01  ...  1.209878e+02  1.219557e+02
# Debt_F    -2.508650e+00 -2.508561e+00  ... -2.500000e+00 -2.500000e+00
# Debt_H     1.875190e-01  1.862303e-01  ...  1.351579e-05  1.339079e-05
# Depo       2.653509e+00  2.652562e+00  ...  2.500012e+00  2.500012e+00
# FD        -1.319692e+04 -1.330260e+04  ... -5.090897e+08 -5.141806e+08
# FT         7.609899e+01  7.592441e+01  ...  1.209878e+02  1.219557e+02
# FU        -8.797947e+03 -8.868400e+03  ... -3.393931e+08 -3.427870e+08
# Fn        -2.199487e+04 -2.217100e+04  ... -8.484828e+08 -8.569676e+08
# I_f        2.446473e-02  2.421950e-02  ...  1.190301e-05  1.190712e-05
# I_h        7.607377e+01  7.589950e+01  ...  1.209869e+02  1.219566e+02
# I_t        7.609824e+01  7.592372e+01  ...  1.209869e+02  1.219566e+02
# Is         7.607377e+01  7.589950e+01  ...  1.209869e+02  1.219566e+02
# K          9.921974e+04  9.929566e+04  ...  1.988385e+05  1.989605e+05
# K_HD       8.418718e+04  8.426307e+04  ...  1.838027e+05  1.839247e+05
# K_HS       8.418718e+04  8.426307e+04  ...  1.838027e+05  1.839247e+05
# K_f        1.503256e+04  1.503259e+04  ...  1.503575e+04  1.503575e+04
# L          1.112346e+06  1.121215e+06  ...  3.427871e+10  3.462150e+10
# M          1.196338e+06  1.205283e+06  ...  3.427889e+10  3.462168e+10
# MO         8.399218e+04  8.406807e+04  ...  1.836077e+05  1.837297e+05
# NFW_b      0.000000e+00 -3.637979e-12  ...  0.000000e+00  0.000000e+00
# NFW_f     -8.797971e+03 -8.868425e+03  ... -3.393931e+08 -3.427870e+08
# NFW_h      8.797972e+03  8.868425e+03  ...  3.393931e+08  3.427870e+08
# S_h        8.874045e+03  8.944324e+03  ...  3.393932e+08  3.427872e+08
# V_b       -1.018634e-10  4.365575e-11  ... -2.381305e-06 -3.107940e-06
# V_f       -1.097314e+06 -1.106182e+06  ... -3.427869e+10 -3.462148e+10
# V_h        1.196533e+06  1.205478e+06  ...  3.427889e+10  3.462168e+10
# W          7.609899e+01  7.592441e+01  ...  1.209878e+02  1.219557e+02
# Xi        -2.290820e-01  2.866264e-01  ...  8.015228e-01 -7.348761e-01
# Y          1.521980e+02  1.518488e+02  ...  2.419756e+02  2.439114e+02
# YD         8.950145e+03  9.020250e+03  ...  3.393934e+08  3.427873e+08
# Yk         6.013016e+03  6.013025e+03  ...  6.014300e+03  6.014300e+03
# Z          7.607377e+01  7.589950e+01  ...  1.209869e+02  1.219566e+02
# _I_h__1    7.607377e+01  7.607377e+01  ...  1.218987e+02  1.209869e+02
# _K_HD__1   8.418718e+04  8.418718e+04  ...  1.836818e+05  1.838027e+05
# _K__1      9.921974e+04  9.921974e+04  ...  1.987175e+05  1.988385e+05
# _K_f__1    1.503256e+04  1.503256e+04  ...  1.503575e+04  1.503575e+04
# _L__1      1.112346e+06  1.112346e+06  ...  3.393932e+10  3.427871e+10
# _MO__1     8.399218e+04  8.399218e+04  ...  1.834868e+05  1.836077e+05
# _M__1      1.196338e+06  1.196338e+06  ...  3.393950e+10  3.427889e+10
# _Xi__1    -2.290820e-01 -2.290820e-01  ... -7.480039e-01  8.015228e-01
# _g_Ih__1  -2.290820e-03 -2.290820e-03  ... -7.480039e-03  8.015228e-03
# _h__1      1.607428e-04  1.607428e-04  ...  4.956757e-08  4.919097e-08
# alpha      1.000000e+00  1.000000e+00  ...  1.000000e+00  1.000000e+00
# g_Ih      -2.290820e-03  2.866264e-03  ...  8.015228e-03 -7.348761e-03
# g_Z       -2.290820e-03  2.866264e-03  ...  8.015228e-03 -7.348761e-03
# gamma_F    4.000000e-01  4.000000e-01  ...  4.000000e-01  4.000000e-01
# gamma_u    1.000000e-02  1.000000e-02  ...  1.000000e-02  1.000000e-02
# gk         1.627452e-06  1.611136e-06  ...  7.916476e-10  7.919206e-10
# h          1.607428e-04  1.594975e-04  ...  4.919097e-08  4.881740e-08
# omega      5.000000e-01  5.000000e-01  ...  5.000000e-01  5.000000e-01
# omegapar   5.000000e-01  5.000000e-01  ...  5.000000e-01  5.000000e-01
# rl         2.000000e-02  2.000000e-02  ...  2.500000e-02  2.500000e-02
# rm         2.000000e-02  2.000000e-02  ...  2.500000e-02  2.500000e-02
# rmo        2.000000e-02  2.000000e-02  ...  2.500000e-02  2.500000e-02
# spread_l   0.000000e+00  0.000000e+00  ...  0.000000e+00  0.000000e+00
# spread_mo  0.000000e+00  0.000000e+00  ...  0.000000e+00  0.000000e+00
# tau        1.516238e-01  1.515078e-01  ...  7.566394e-02  7.561790e-02
# u          2.531142e-02  2.525331e-02  ...  4.023338e-02  4.055524e-02
# un         8.000000e-01  8.000000e-01  ...  8.000000e-01  8.000000e-01
# v          2.500000e+00  2.500000e+00  ...  2.500000e+00  2.500000e+00
#
# [60 rows x 1051 columns]

# %%
fig, ax = plt.subplots(2,2)

shock[["Y"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                  ls = ('--'),
                                                  )
shock[["K"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                  ls = ('-'),
                                                  )
shock[["I_h"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                  ls = (':'),
                                                  )
shock[["I_f"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                  ls = ('-.'),
                                                  )

ax[0,0].set_ylim(0.04,0.065)
ax[0,0].axhline(y=shock["g_Z"].iloc[-1], color = "black", ls = "--", lw=1)
#ax[0,0].set_yticklabels(['{:,.1%}'.format(x) for x in ax[0,0].get_yticks()])
ax[0,0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.06),
               labels = ["$Y$", "$K$", "$I_h$", "$I_f$"],
          fancybox=True, shadow=True, ncol=2)

shock['tau'].plot(color = "darkred", title = "Capacity generating capital \nas % of total capital", label = "$\\tau$", legend = False, ax = ax[0,1], lw = 3, )
ax[0,1].set_ylim(0.30,0.40)
ax[0,1].axhline(y = df['tau'].iloc[-1], ls ='--', color = "gray")
#ax[0,1].set_yticklabels(['{:,.3%}'.format(x) for x in ax[0,1].get_yticks()])


shock['u'].plot(title = 'Capacity utilization ratio', ax=ax[1,0], legend = False, color = "darkred", lw = 3, )
ax[1,0].axhline(y = shock['un'].iloc[-1], ls ='--', color = "gray")
ax[1,0].set_ylim(0.75,0.95)
#ax[1,0].set_yticklabels(['{:,.2%}'.format(x) for x in ax[1,0].get_yticks()])

#shock['h'].plot(title = 'Marginal propensity to invest', ax=ax[1,1], legend = False, color = "darkred", lw = 3, )
(shock["Debt_H"] - shock["Depo"]).plot(title = "Household's debt - Deposits ratio\n as % of Disposable Income",
                                      ax=ax[1,1], legend = False, color = "darkred", lw = 3, )
ax[1,1].set_ylim(0.,0.05)

sns.despine()
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
#fig.suptitle('Increase in interest rates')
plt.show()

fig.savefig('Shock_3.png', dpi = 300)

# %%
fig, ax = plt.subplots(1,2)

(shock['I_t']/shock['Y']).plot(title = 'Investment share\nShock in $rm$', color = 'black', ax = ax[0])
ax[0].set_ylim(.45,.55)
(1 - shock['omega']).plot(title = 'Marginal propensity to save\nShock in $rm$', color = 'black', ax = ax[1])
ax[1].set_ylim(.45,.55)

sns.despine()
plt.show()

# %%
shock[['Debt_H', 'Debt_F', "Depo"]].plot(title = "Household's and Firms' indebtedness")
sns.despine()
plt.show()

# %%
(shock["Debt_H"] - shock["Depo"]).plot(title = "Household's debt - Deposits ratio\n as % of Disposable Income")
sns.despine()
plt.show()

# %% [markdown]
# # Shock yourself

# %%
df_ = df

# %%
@interact(variable = df_.transpose().loc['alpha':,:].index, increase = (-1,1,0.01))
def shock_yourself(variable, increase):
  shock = ShockModel(base_model = base, create_function = model(), variable = variable, increase = increase)
  fig, ax = plt.subplots(2,2)

  shock[["Y"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                    ls = ('--'),
                                                    )
  shock[["K"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                    ls = ('-'),
                                                    )
  shock[["I_h"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                    ls = (':'),
                                                    )
  shock[["I_f"]].pct_change().plot(title = "Growth rates", ax = ax[0,0], 
                                                    ls = ('-.'),
                                                    )

  ax[0,0].set_ylim(0.04,0.065)
  ax[0,0].axhline(y=shock["g_Z"].iloc[-1], color = "black", ls = "--", lw=1)
  #ax[0,0].set_yticklabels(['{:,.1%}'.format(x) for x in ax[0,0].get_yticks()])
  ax[0,0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.06),
                 labels = ["$Y$", "$K$", "$I_h$", "$I_f$"],
            fancybox=True, shadow=True, ncol=2)

  shock['tau'].plot(color = "darkred", title = "Capacity generating capital \nas % of total capital", label = "$\\tau$", legend = False, ax = ax[0,1], lw = 3, )
  ax[0,1].set_ylim(0.30,0.40)
  ax[0,1].axhline(y = df_['tau'].iloc[-1], ls ='--', color = "gray")
  #ax[0,1].set_yticklabels(['{:,.3%}'.format(x) for x in ax[0,1].get_yticks()])


  shock['u'].plot(title = 'Capacity utilization ratio', ax=ax[1,0], legend = False, color = "darkred", lw = 3, )
  ax[1,0].axhline(y = shock['un'].iloc[-1], ls ='--', color = "gray")
  ax[1,0].set_ylim(0.75,0.95)
  #ax[1,0].set_yticklabels(['{:,.2%}'.format(x) for x in ax[1,0].get_yticks()])

  shock['h'].plot(title = 'Marginal propensity to invest', ax=ax[1,1], legend = False, color = "darkred", lw = 3, )
  ax[1,1].axhline(y = df_['h'].iloc[-1], ls ='--', color = "gray")
  ax[1,1].set_ylim(0.15,0.25)

  sns.despine()
  plt.tight_layout(rect=[0, 0.03, 1, 0.95])
  fig.suptitle('Increase in interest rates')
  plt.show()
# Out:
# interactive(children=(Dropdown(description='variable', options=('alpha', 'g_Ih', 'g_Z', 'gamma_F', 'gamma_u', …

# %% [markdown]
# # Finishing

# %%
print("Running time: ", datetime.now() - t1)
# Out:
# Running time:  0:00:40.131666
