# %% [markdown]
# # Capacity utilization
#
# Following [econ_data](https://github.com/gpetrini/econ_data/blob/master/APIs/FRED.ipynb)

# %%
import requests
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
from statsmodels.tsa.arima_model import ARIMA
import numpy as np
import APIs
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('paper')
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
fred_key = APIs.fred_api

# %% [markdown]
# Defining function to get fred data: fredData

# %%
def fredData(request_dict, start_date, end_date, api_key, freq = 'Q'):
    """ download some data from fred """
    import pandas as pd
    import numpy as np
    import requests
    base = 'https://api.stlouisfed.org/fred/series/observations?series_id='
    dates = '&observation_start={}&observation_end={}'.format(start_date, end_date)
    api_key = '&api_key={}'.format(api_key)
    ftype = '&file_type=json'
    
    dataFrame = pd.DataFrame()
    for code, name in request_dict.items():
        url = '{}{}{}{}{}'.format(base, code, dates, api_key, ftype)
        r = requests.get(url).json()['observations']
        dataFrame[name[0]] = [i['value'] for i in r]

    dataFrame = dataFrame.replace('.', np.nan)    
    dataFrame = dataFrame.astype(float)

    sectors = pd.MultiIndex.from_tuples(list(zip([i[1] for i in request_dict.values()],[i[0] for i in request_dict.values()])))
    dataFrame.columns = sectors

    dates = pd.date_range(start_date, periods=dataFrame.shape[0], freq=freq)
    dataFrame.index = dates
    return dataFrame

"""
# usage 
df = fredData(request_dict=q_dict, start_date=start_date, end_date=end_date, api_key=fred_key)
df
"""
# Out:
# '\n# usage \ndf = fredData(request_dict=q_dict, start_date=start_date, end_date=end_date, api_key=fred_key)\ndf\n'

# %%
recessions = pd.read_html('https://www.nber.org/cycles/cyclesmain.html')

peak = recessions[0][0][4]
peak = peak.replace('(I)', '/')
peak = peak.replace('(II)', '/')
peak = peak.replace('(III)', '/')
peak = peak.replace('(IV)', '/')
peak = peak.split('/ ')
peak[-1] = peak[-1].replace(" /", "")
peak = [datetime.strptime(i, '%B %Y') for i in peak]
peak = peak[-8:]

trough = recessions[0][1][4]
trough = trough.replace('(I)', '/')
trough = trough.replace('(II)', '/')
trough = trough.replace('(III)', '/')
trough = trough.replace('(IV)', '/')
trough = trough.replace('March 1991/  November 2001', 'March 1991 / November 2001', )
trough = trough.split(' / ')
trough[-1] = trough[-1].replace(" /", "")
trough = [datetime.strptime(i, '%B %Y') for i in trough[1:]]
trough = trough[-8:]

crisis = pd.DataFrame({'peak': peak, 'trough': trough})

# %% [markdown]
# # Monthly data

# %%
m_dict = {'TCU' : ['Total Industry', 'Total'],
          'MCUMFN' : ['Manufacturing', 'Total'],
          'CAPUTLG3311A2S' : ['Iron and steel products', 'Total'],
          'CAPUTLG33611S' : ['Automobile and light duty motor vehicle', 'Total'],
          'CAPUTLG2211S' : ['Electric power generation, transmission, and distribution', 'Total'],
          'CAPUTLG211S' : ['Oil and gas extraction', 'Total'],
          'CAPUTLG325S' : ['Chemical', 'Total'],
          'CAPUTLG21S' : ['Mining', 'Total'],
          'CAPUTLG3361T3S' : ['Motor vehicles and parts', 'Total'],
          'CAPUTLG311A2S' : ['Food, beverage, and tobacco', 'Total'],
          'CAPUTLHITEK2S' : ['Computers, communications equipment, and semiconductors', 'Total'],
          'CAPUTLG326S' : ['Plastics and rubber products', 'Total'],
          'CAPUTLG333S' : ['Machinery', 'Total'],
          'CAPUTLGMFDS' : ['Durable manufacturing', 'Total'],
          'CAPUTLG3364T9S' : ['Aerospace and miscellaneous transportation equipment', 'Total'],
          'CAPUTLN325211S' : ['Plastics material and resin', 'Total'],
          'CAPUTLG331S' : ['Primary metal', 'Total'],
          'CAPUTLB5610CS' : ['Crude processing', 'Total'],
          'CAPUTLN2121S' : ['Coal mining', 'Total'],
          'CAPUTLG334S' : ['Computer and electronic product', 'Total'],
          'CAPUTLG323S' : ['Printing and related support activities', 'Total'],
          'CAPUTLG322S' : ['Paper', 'Total'],
          }

monthly = fredData(request_dict=m_dict, start_date='1979-12-01', end_date='2017-12-01', api_key=fred_key, freq='M')

# %%
monthly.head()
# Out:
#                     Total                                        \
#            Total Industry Manufacturing Iron and steel products
# 1979-12-31        84.1242       82.8226                 86.8399
# 1980-01-31        84.3388       82.9826                 89.3541
# 1980-02-29        84.1830       82.6395                 87.7637
# 1980-03-31        83.7374       81.8394                 90.3419
# 1980-04-30        81.8654       79.8931                 84.2032
#
#                                                     \
#            Automobile and light duty motor vehicle
# 1979-12-31                                 64.5943
# 1980-01-31                                 60.4304
# 1980-02-29                                 65.3956
# 1980-03-31                                 60.9987
# 1980-04-30                                 54.7393
#
#                                                                       \
#            Electric power generation, transmission, and distribution
# 1979-12-31                                            84.9132
# 1980-01-31                                            82.9628
# 1980-02-29                                            85.7570
# 1980-03-31                                            87.6006
# 1980-04-30                                            85.5857
#
#                                                                               \
#            Oil and gas extraction Chemical   Mining Motor vehicles and parts
# 1979-12-31                94.5272  81.7119  92.4786                  69.3570
# 1980-01-31                95.0935  81.3318  94.0539                  64.8029
# 1980-02-29                94.3290  80.4115  92.8757                  68.3728
# 1980-03-31                95.1245  79.3469  93.5895                  65.0141
# 1980-04-30                94.0480  78.5555  92.3143                  59.2269
#
#                                          ...               \
#            Food, beverage, and tobacco   ...    Machinery
# 1979-12-31                     81.1173   ...      86.9357
# 1980-01-31                     81.3397   ...      90.0937
# 1980-02-29                     81.6460   ...      88.5919
# 1980-03-31                     80.8844   ...      88.0798
# 1980-04-30                     80.5464   ...      86.4711
#
#                                   \
#            Durable manufacturing
# 1979-12-31               82.6577
# 1980-01-31               82.7526
# 1980-02-29               82.5087
# 1980-03-31               81.7317
# 1980-04-30               79.2962
#
#                                                                  \
#            Aerospace and miscellaneous transportation equipment
# 1979-12-31                                            85.0687
# 1980-01-31                                            84.8074
# 1980-02-29                                            86.4272
# 1980-03-31                                            85.8442
# 1980-04-30                                            84.4970
#
#                                                                        \
#            Plastics material and resin Primary metal Crude processing
# 1979-12-31                     88.5510       83.5674          91.2209
# 1980-01-31                     91.6247       84.9906          91.8535
# 1980-02-29                     88.0099       83.6631          90.9985
# 1980-03-31                     85.4742       84.9125          91.2812
# 1980-04-30                     80.3779       81.6139          90.3088
#
#                                                         \
#            Coal mining Computer and electronic product
# 1979-12-31     86.6674                         87.6727
# 1980-01-31     97.8310                         88.5029
# 1980-02-29     94.8426                         88.9722
# 1980-03-31     94.2117                         88.9754
# 1980-04-30     92.7103                         88.7627
#
#
#            Printing and related support activities    Paper
# 1979-12-31                                 85.0833  92.5896
# 1980-01-31                                 84.9896  92.5939
# 1980-02-29                                 85.4736  90.4483
# 1980-03-31                                 85.2283  90.4055
# 1980-04-30                                 84.0587  88.4926
#
# [5 rows x 22 columns]

# %%
monthly['Total'][['Total Industry', 'Manufacturing','Machinery','Durable manufacturing']].plot()
sns.despine()
plt.show()

# %% [markdown]
# Smoothing

# %%
series = monthly['Total']['Total Industry']
model = ARIMA(series, order=(4,0,0))
results = model.fit()
print(results.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:         Total Industry   No. Observations:                  457
# Model:                     ARMA(4, 0)   Log Likelihood                -313.876
# Method:                       css-mle   S.D. of innovations              0.479
# Date:                Mon, 11 Feb 2019   AIC                            639.753
# Time:                        19:12:15   BIC                            664.501
# Sample:                    12-31-1979   HQIC                           649.501
#                          - 12-31-2017
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   79.2874      1.095     72.412      0.000      77.141      81.433
# ar.L1.Total Industry     1.1577      0.046     25.245      0.000       1.068       1.248
# ar.L2.Total Industry     0.0224      0.071      0.315      0.753      -0.117       0.162
# ar.L3.Total Industry    -0.0138      0.071     -0.195      0.846      -0.153       0.126
# ar.L4.Total Industry    -0.1859      0.046     -4.028      0.000      -0.276      -0.095
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0556           -0.0000j            1.0556           -0.0000
# AR.2            1.2543           -0.0000j            1.2543           -0.0000
# AR.3           -1.1922           -1.6254j            2.0157           -0.3507
# AR.4           -1.1922           +1.6254j            2.0157            0.3507
# -----------------------------------------------------------------------------

# %%
results.plot_predict()

# %%
start = datetime(1967, 1, 1)
end = datetime(2015, 1, 1)

Ihudf = web.DataReader(['HNOREMQ027S', 'PRFI','DPI', 'TCU'], 'fred', start, end, access_key=fred_key)
Ihudf.columns = [
    'real estate at market value',
    'Private Residential Fixed Investment',
    'Disposable Personal Income (DPI)',
    'Capacity utilizarion'
]
Ihudf = Ihudf.resample('Q').mean()

# %%
sns.lineplot(x = Ihudf['Capacity utilizarion'], y = Ihudf['Private Residential Fixed Investment'])
